# %% [markdown]
# # **TFG**
#
# ***Use of Machine Learning and SNOMED CT encoded Health Problems to Predict Hospital Discharge Diagnoses***
#
# Cindy Chen
#
# Universitat de Barcelona
#
# 2024-2025

# %%
# Import modules 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display 
import gradio as gr
import os
from pycaret.classification import *
from pycaret.classification import plot_model
from pycaret.classification import predict_model, pull, load_model

# %matplotlib inline

# %% [markdown]
# ## **Data Importation**
#
# Import Subset 7 to find the best model, train the model, tune it and evaluate.

# %%
# Import data
data = pd.read_csv("C:/Users/Cindy Chen/Desktop/TFG/data/04_data/subset_7.csv")
data
# Out:
#          adm_drug_dose_mean  adm_given  adm_prn  adm_route_ref   age  \
# 0                       1.2        1.0      0.0          150.0  81.0
# 1                     100.0        0.0      1.0          150.0  47.0
# 2                     500.0        1.0      0.0          350.0  73.0
# 3                       2.0        1.0      0.0          150.0  74.0
# 4                       1.0        0.0      0.0          100.0  74.0
# ...                     ...        ...      ...            ...   ...
# 1045979               100.0        1.0      0.0          150.0  67.0
# 1045980                 1.0        0.0      0.0          150.0  77.0
# 1045981                 1.0        1.0      0.0          100.0  45.0
# 1045982                 2.0        1.0      0.0          150.0  54.0
# 1045983                 0.9        0.0      0.0          100.0  73.0
#
#          care_level_duration  clinical_records_result_num_mean  \
# 0                 706.924438                         94.131577
# 1                 146.750000                         68.900002
# 2                1703.783569                        110.247528
# 3                 433.244171                         36.254166
# 4                 481.936676                         55.170731
# ...                      ...                               ...
# 1045979             2.855278                         91.694443
# 1045980            94.935280                         67.321426
# 1045981           107.043053                         77.400002
# 1045982          1306.877197                         96.349998
# 1045983            55.612221                         80.052635
#
#          cr_meas_type_ref  death  diag_class_ref_H  ...  icd10_capitulo  \
# 0                     1.0    1.0               0.0  ...              17
# 1                     0.0    0.0               0.0  ...              17
# 2                     1.0    0.0               0.0  ...               1
# 3                     0.0    0.0               0.0  ...               9
# 4                     0.0    0.0               0.0  ...              16
# ...                   ...    ...               ...  ...             ...
# 1045979               0.0    1.0               0.0  ...              14
# 1045980               2.0    0.0               0.0  ...              14
# 1045981               0.0    0.0               0.0  ...               1
# 1045982               0.0    0.0               1.0  ...              15
# 1045983               2.0    0.0               0.0  ...              13
#
#          lab_result_num_mean  no_administration_reason_ref  num_health_issues  \
# 0                   0.000000                           3.0                3.0
# 1                  97.176926                           0.0                3.0
# 2                   1.740909                           5.0                5.0
# 3                   0.050000                           6.0                8.0
# 4                   0.966667                           0.0                8.0
# ...                      ...                           ...                ...
# 1045979            75.750000                           3.0                4.0
# 1045980             1.483333                           0.0                2.0
# 1045981            78.501724                           5.0                3.0
# 1045982           100.199997                           6.0                1.0
# 1045983             0.283333                           0.0                5.0
#
#          ongoing  prescription_drug_dose_mean  prescription_freq_ref  \
# 0            1.0                   100.000000              10.653915
# 1            1.0                     0.666667              10.653915
# 2            1.0                   491.333344              10.653915
# 3            1.0                   500.000000              10.764504
# 4            1.0                     4.800000              10.158386
# ...          ...                          ...                    ...
# 1045979      1.0                   491.166656              10.764504
# 1045980      1.0                     1.000000              10.844777
# 1045981      1.0                     1.000000              10.844777
# 1045982      1.0                     2.000000              10.653915
# 1045983      0.0                    10.000000              10.653915
#
#          rc_sap_ref_PRESN_SIS  sex_atr  snomed_code
# 0                         0.0      2.0  240131006.0
# 1                         0.0      1.0  109989006.0
# 2                         1.0      1.0  439740005.0
# 3                         0.0      2.0  433146000.0
# 4                         0.0      2.0  307496006.0
# ...                       ...      ...          ...
# 1045979                   0.0      2.0  409623005.0
# 1045980                   0.0      1.0  230690007.0
# 1045981                   0.0      2.0  307651005.0
# 1045982                   0.0      2.0   77493009.0
# 1045983                   0.0      2.0   51387008.0
#
# [1045984 rows x 30 columns]

# %% [markdown]
# Setup the pycaret environment and select the target column, in our case is the 'icd10_capitulo' column. This function also splits the data into training (70%) and testing set (30%).

# %%
# setup PyCaret
clf = setup(data=data, target='icd10_capitulo', session_id=123, verbose=True)
# Out:
# <style type="text/css">
# #T_b7349_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b7349">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7349_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b7349_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7349_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b7349_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b7349_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b7349_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b7349_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b7349_row1_col1" class="data row1 col1" >icd10_capitulo</td>
#     </tr>
#     <tr>
#       <th id="T_b7349_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b7349_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_b7349_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_b7349_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b7349_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_b7349_row3_col1" class="data row3 col1" >(1045984, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_b7349_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b7349_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_b7349_row4_col1" class="data row4 col1" >(1045984, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_b7349_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b7349_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_b7349_row5_col1" class="data row5 col1" >(732188, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_b7349_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b7349_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_b7349_row6_col1" class="data row6 col1" >(313796, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_b7349_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b7349_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_b7349_row7_col1" class="data row7 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_b7349_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b7349_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_b7349_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b7349_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b7349_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_b7349_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b7349_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b7349_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_b7349_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b7349_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b7349_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_b7349_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_b7349_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b7349_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_b7349_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_b7349_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b7349_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_b7349_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b7349_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b7349_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_b7349_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b7349_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b7349_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_b7349_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b7349_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b7349_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_b7349_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b7349_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b7349_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_b7349_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b7349_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b7349_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_b7349_row18_col1" class="data row18 col1" >32f9</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Get preprocessing pipeline
get_config('pipeline')
# Out:
# Pipeline(memory=FastMemory(location=C:\Users\CINDYC~1\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['adm_drug_dose_mean', 'adm_given',
#                                              'adm_prn', 'adm_route_ref', 'age',
#                                              'care_level_duration',
#                                              'clinical_records_result_num_mean',
#                                              'cr_meas_type_ref', 'death',
#                                              'diag_class_ref_H',
#                                              'diag_class_ref_P',
#                                              'diag_class_r...
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='mean'))),
#                 ('categorical_imputer',
#                  TransformerWrapper(exclude=None, include=[],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='most_frequent')))],
#          verbose=False)

# %% [markdown]
# ## **Model Comparison**
#
# Using the ```compare_models``` function to compare the selected models: Logistic Regression, Decision Trees, Random Forest, XGBoost, SVM, KNN and MLP.
#
# This function trains and evaluates the performance of all estimators available in the model library using cross-validation. The output of this function is a scoring grid with average cross-validated scores.

# %%
# Compare models
model_comparison = compare_models(include=["lr", 'dt', 'rf', 'xgboost', 'svm', 'knn', 'mlp'])
# Out:
# <style type="text/css">
# #T_a9364 th {
#   text-align: left;
# }
# #T_a9364_row0_col0, #T_a9364_row0_col2, #T_a9364_row1_col0, #T_a9364_row1_col1, #T_a9364_row1_col3, #T_a9364_row1_col4, #T_a9364_row1_col5, #T_a9364_row1_col6, #T_a9364_row1_col7, #T_a9364_row2_col0, #T_a9364_row2_col1, #T_a9364_row2_col2, #T_a9364_row2_col3, #T_a9364_row2_col4, #T_a9364_row2_col5, #T_a9364_row2_col6, #T_a9364_row2_col7, #T_a9364_row3_col0, #T_a9364_row3_col1, #T_a9364_row3_col2, #T_a9364_row3_col3, #T_a9364_row3_col4, #T_a9364_row3_col5, #T_a9364_row3_col6, #T_a9364_row3_col7, #T_a9364_row4_col0, #T_a9364_row4_col1, #T_a9364_row4_col2, #T_a9364_row4_col3, #T_a9364_row4_col4, #T_a9364_row4_col5, #T_a9364_row4_col6, #T_a9364_row4_col7, #T_a9364_row5_col0, #T_a9364_row5_col1, #T_a9364_row5_col2, #T_a9364_row5_col3, #T_a9364_row5_col4, #T_a9364_row5_col5, #T_a9364_row5_col6, #T_a9364_row5_col7 {
#   text-align: left;
# }
# #T_a9364_row0_col1, #T_a9364_row0_col3, #T_a9364_row0_col4, #T_a9364_row0_col5, #T_a9364_row0_col6, #T_a9364_row0_col7, #T_a9364_row1_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a9364_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_a9364_row1_col8, #T_a9364_row2_col8, #T_a9364_row3_col8, #T_a9364_row4_col8, #T_a9364_row5_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a9364">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9364_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a9364_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a9364_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a9364_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a9364_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a9364_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a9364_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a9364_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_a9364_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9364_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_a9364_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_a9364_row0_col1" class="data row0 col1" >0.6644</td>
#       <td id="T_a9364_row0_col2" class="data row0 col2" >0.8185</td>
#       <td id="T_a9364_row0_col3" class="data row0 col3" >0.6644</td>
#       <td id="T_a9364_row0_col4" class="data row0 col4" >0.6648</td>
#       <td id="T_a9364_row0_col5" class="data row0 col5" >0.6646</td>
#       <td id="T_a9364_row0_col6" class="data row0 col6" >0.6286</td>
#       <td id="T_a9364_row0_col7" class="data row0 col7" >0.6286</td>
#       <td id="T_a9364_row0_col8" class="data row0 col8" >1.8460</td>
#     </tr>
#     <tr>
#       <th id="T_a9364_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_a9364_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_a9364_row1_col1" class="data row1 col1" >0.4555</td>
#       <td id="T_a9364_row1_col2" class="data row1 col2" >0.9065</td>
#       <td id="T_a9364_row1_col3" class="data row1 col3" >0.4555</td>
#       <td id="T_a9364_row1_col4" class="data row1 col4" >0.4675</td>
#       <td id="T_a9364_row1_col5" class="data row1 col5" >0.4584</td>
#       <td id="T_a9364_row1_col6" class="data row1 col6" >0.4022</td>
#       <td id="T_a9364_row1_col7" class="data row1 col7" >0.4027</td>
#       <td id="T_a9364_row1_col8" class="data row1 col8" >54.4670</td>
#     </tr>
#     <tr>
#       <th id="T_a9364_level0_row2" class="row_heading level0 row2" >knn</th>
#       <td id="T_a9364_row2_col0" class="data row2 col0" >K Neighbors Classifier</td>
#       <td id="T_a9364_row2_col1" class="data row2 col1" >0.3360</td>
#       <td id="T_a9364_row2_col2" class="data row2 col2" >0.7811</td>
#       <td id="T_a9364_row2_col3" class="data row2 col3" >0.3360</td>
#       <td id="T_a9364_row2_col4" class="data row2 col4" >0.3448</td>
#       <td id="T_a9364_row2_col5" class="data row2 col5" >0.3369</td>
#       <td id="T_a9364_row2_col6" class="data row2 col6" >0.2662</td>
#       <td id="T_a9364_row2_col7" class="data row2 col7" >0.2668</td>
#       <td id="T_a9364_row2_col8" class="data row2 col8" >127.2350</td>
#     </tr>
#     <tr>
#       <th id="T_a9364_level0_row3" class="row_heading level0 row3" >mlp</th>
#       <td id="T_a9364_row3_col0" class="data row3 col0" >MLP Classifier</td>
#       <td id="T_a9364_row3_col1" class="data row3 col1" >0.2026</td>
#       <td id="T_a9364_row3_col2" class="data row3 col2" >0.5000</td>
#       <td id="T_a9364_row3_col3" class="data row3 col3" >0.2026</td>
#       <td id="T_a9364_row3_col4" class="data row3 col4" >0.0411</td>
#       <td id="T_a9364_row3_col5" class="data row3 col5" >0.0683</td>
#       <td id="T_a9364_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_a9364_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_a9364_row3_col8" class="data row3 col8" >15.5610</td>
#     </tr>
#     <tr>
#       <th id="T_a9364_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_a9364_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_a9364_row4_col1" class="data row4 col1" >0.2007</td>
#       <td id="T_a9364_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_a9364_row4_col3" class="data row4 col3" >0.2007</td>
#       <td id="T_a9364_row4_col4" class="data row4 col4" >0.0410</td>
#       <td id="T_a9364_row4_col5" class="data row4 col5" >0.0679</td>
#       <td id="T_a9364_row4_col6" class="data row4 col6" >-0.0017</td>
#       <td id="T_a9364_row4_col7" class="data row4 col7" >-0.0122</td>
#       <td id="T_a9364_row4_col8" class="data row4 col8" >111.6450</td>
#     </tr>
#     <tr>
#       <th id="T_a9364_level0_row5" class="row_heading level0 row5" >svm</th>
#       <td id="T_a9364_row5_col0" class="data row5 col0" >SVM - Linear Kernel</td>
#       <td id="T_a9364_row5_col1" class="data row5 col1" >0.1186</td>
#       <td id="T_a9364_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_a9364_row5_col3" class="data row5 col3" >0.1186</td>
#       <td id="T_a9364_row5_col4" class="data row5 col4" >0.0176</td>
#       <td id="T_a9364_row5_col5" class="data row5 col5" >0.0301</td>
#       <td id="T_a9364_row5_col6" class="data row5 col6" >-0.0000</td>
#       <td id="T_a9364_row5_col7" class="data row5 col7" >-0.0002</td>
#       <td id="T_a9364_row5_col8" class="data row5 col8" >140.3990</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Save results table
model_comparison_df = pull()
model_comparison_df.to_csv('S7_model_comparison_df.csv', index=False)

# Save best_model
save_model(model_comparison, 'S7_model_comparison')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['adm_drug_dose_mean', 'adm_given',
#                                               'adm_prn', 'adm_route_ref', 'age',
#                                               'care_level_duration',
#                                               'clinical_records_result_num_mean',
#                                               'cr_meas_type_ref', 'death',
#                                               'diag_class_ref_H',
#                                               'diag_class_ref_P',
#                                               'diag_class_ref_S', 'drg_mdc_ref',
#                                               'drg_ref', 'drg_rom_ref'...
#                                                                missing_values=nan,
#                                                                strategy='most_frequent'))),
#                  ('trained_model',
#                   DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                          criterion='gini', max_depth=None,
#                                          max_features=None, max_leaf_nodes=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          monotonic_cst=None, random_state=123,
#                                          splitter='best'))],
#           verbose=False),
#  'S7_model_comparison.pkl')

# %% [markdown]
# ## **Best Model**
#
# Once we have compared the different models, we select the best one. Then using the ```create_model``` function we train and evaluate the performance of the model using cross-validation. By default, it uses the 10 fold.

# %%
# Model evaluation: cross validation 10 folds
decision_tree_model = create_model('dt')  
evaluate_model(decision_tree_model)
# Out:
# <style type="text/css">
# #T_d04f5_row10_col0, #T_d04f5_row10_col1, #T_d04f5_row10_col2, #T_d04f5_row10_col3, #T_d04f5_row10_col4, #T_d04f5_row10_col5, #T_d04f5_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_d04f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d04f5_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_d04f5_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_d04f5_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_d04f5_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_d04f5_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_d04f5_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_d04f5_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d04f5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d04f5_row0_col0" class="data row0 col0" >0.6640</td>
#       <td id="T_d04f5_row0_col1" class="data row0 col1" >0.8182</td>
#       <td id="T_d04f5_row0_col2" class="data row0 col2" >0.6640</td>
#       <td id="T_d04f5_row0_col3" class="data row0 col3" >0.6643</td>
#       <td id="T_d04f5_row0_col4" class="data row0 col4" >0.6641</td>
#       <td id="T_d04f5_row0_col5" class="data row0 col5" >0.6282</td>
#       <td id="T_d04f5_row0_col6" class="data row0 col6" >0.6282</td>
#     </tr>
#     <tr>
#       <th id="T_d04f5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d04f5_row1_col0" class="data row1 col0" >0.6643</td>
#       <td id="T_d04f5_row1_col1" class="data row1 col1" >0.8182</td>
#       <td id="T_d04f5_row1_col2" class="data row1 col2" >0.6643</td>
#       <td id="T_d04f5_row1_col3" class="data row1 col3" >0.6646</td>
#       <td id="T_d04f5_row1_col4" class="data row1 col4" >0.6644</td>
#       <td id="T_d04f5_row1_col5" class="data row1 col5" >0.6284</td>
#       <td id="T_d04f5_row1_col6" class="data row1 col6" >0.6284</td>
#     </tr>
#     <tr>
#       <th id="T_d04f5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d04f5_row2_col0" class="data row2 col0" >0.6651</td>
#       <td id="T_d04f5_row2_col1" class="data row2 col1" >0.8190</td>
#       <td id="T_d04f5_row2_col2" class="data row2 col2" >0.6651</td>
#       <td id="T_d04f5_row2_col3" class="data row2 col3" >0.6650</td>
#       <td id="T_d04f5_row2_col4" class="data row2 col4" >0.6650</td>
#       <td id="T_d04f5_row2_col5" class="data row2 col5" >0.6294</td>
#       <td id="T_d04f5_row2_col6" class="data row2 col6" >0.6294</td>
#     </tr>
#     <tr>
#       <th id="T_d04f5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d04f5_row3_col0" class="data row3 col0" >0.6655</td>
#       <td id="T_d04f5_row3_col1" class="data row3 col1" >0.8188</td>
#       <td id="T_d04f5_row3_col2" class="data row3 col2" >0.6655</td>
#       <td id="T_d04f5_row3_col3" class="data row3 col3" >0.6657</td>
#       <td id="T_d04f5_row3_col4" class="data row3 col4" >0.6656</td>
#       <td id="T_d04f5_row3_col5" class="data row3 col5" >0.6297</td>
#       <td id="T_d04f5_row3_col6" class="data row3 col6" >0.6297</td>
#     </tr>
#     <tr>
#       <th id="T_d04f5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d04f5_row4_col0" class="data row4 col0" >0.6650</td>
#       <td id="T_d04f5_row4_col1" class="data row4 col1" >0.8192</td>
#       <td id="T_d04f5_row4_col2" class="data row4 col2" >0.6650</td>
#       <td id="T_d04f5_row4_col3" class="data row4 col3" >0.6657</td>
#       <td id="T_d04f5_row4_col4" class="data row4 col4" >0.6653</td>
#       <td id="T_d04f5_row4_col5" class="data row4 col5" >0.6293</td>
#       <td id="T_d04f5_row4_col6" class="data row4 col6" >0.6293</td>
#     </tr>
#     <tr>
#       <th id="T_d04f5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d04f5_row5_col0" class="data row5 col0" >0.6659</td>
#       <td id="T_d04f5_row5_col1" class="data row5 col1" >0.8195</td>
#       <td id="T_d04f5_row5_col2" class="data row5 col2" >0.6659</td>
#       <td id="T_d04f5_row5_col3" class="data row5 col3" >0.6666</td>
#       <td id="T_d04f5_row5_col4" class="data row5 col4" >0.6662</td>
#       <td id="T_d04f5_row5_col5" class="data row5 col5" >0.6303</td>
#       <td id="T_d04f5_row5_col6" class="data row5 col6" >0.6303</td>
#     </tr>
#     <tr>
#       <th id="T_d04f5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d04f5_row6_col0" class="data row6 col0" >0.6646</td>
#       <td id="T_d04f5_row6_col1" class="data row6 col1" >0.8182</td>
#       <td id="T_d04f5_row6_col2" class="data row6 col2" >0.6646</td>
#       <td id="T_d04f5_row6_col3" class="data row6 col3" >0.6647</td>
#       <td id="T_d04f5_row6_col4" class="data row6 col4" >0.6646</td>
#       <td id="T_d04f5_row6_col5" class="data row6 col5" >0.6287</td>
#       <td id="T_d04f5_row6_col6" class="data row6 col6" >0.6287</td>
#     </tr>
#     <tr>
#       <th id="T_d04f5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d04f5_row7_col0" class="data row7 col0" >0.6653</td>
#       <td id="T_d04f5_row7_col1" class="data row7 col1" >0.8192</td>
#       <td id="T_d04f5_row7_col2" class="data row7 col2" >0.6653</td>
#       <td id="T_d04f5_row7_col3" class="data row7 col3" >0.6657</td>
#       <td id="T_d04f5_row7_col4" class="data row7 col4" >0.6654</td>
#       <td id="T_d04f5_row7_col5" class="data row7 col5" >0.6296</td>
#       <td id="T_d04f5_row7_col6" class="data row7 col6" >0.6296</td>
#     </tr>
#     <tr>
#       <th id="T_d04f5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d04f5_row8_col0" class="data row8 col0" >0.6625</td>
#       <td id="T_d04f5_row8_col1" class="data row8 col1" >0.8170</td>
#       <td id="T_d04f5_row8_col2" class="data row8 col2" >0.6625</td>
#       <td id="T_d04f5_row8_col3" class="data row8 col3" >0.6627</td>
#       <td id="T_d04f5_row8_col4" class="data row8 col4" >0.6625</td>
#       <td id="T_d04f5_row8_col5" class="data row8 col5" >0.6263</td>
#       <td id="T_d04f5_row8_col6" class="data row8 col6" >0.6263</td>
#     </tr>
#     <tr>
#       <th id="T_d04f5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d04f5_row9_col0" class="data row9 col0" >0.6622</td>
#       <td id="T_d04f5_row9_col1" class="data row9 col1" >0.8173</td>
#       <td id="T_d04f5_row9_col2" class="data row9 col2" >0.6622</td>
#       <td id="T_d04f5_row9_col3" class="data row9 col3" >0.6629</td>
#       <td id="T_d04f5_row9_col4" class="data row9 col4" >0.6625</td>
#       <td id="T_d04f5_row9_col5" class="data row9 col5" >0.6261</td>
#       <td id="T_d04f5_row9_col6" class="data row9 col6" >0.6261</td>
#     </tr>
#     <tr>
#       <th id="T_d04f5_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_d04f5_row10_col0" class="data row10 col0" >0.6644</td>
#       <td id="T_d04f5_row10_col1" class="data row10 col1" >0.8185</td>
#       <td id="T_d04f5_row10_col2" class="data row10 col2" >0.6644</td>
#       <td id="T_d04f5_row10_col3" class="data row10 col3" >0.6648</td>
#       <td id="T_d04f5_row10_col4" class="data row10 col4" >0.6646</td>
#       <td id="T_d04f5_row10_col5" class="data row10 col5" >0.6286</td>
#       <td id="T_d04f5_row10_col6" class="data row10 col6" >0.6286</td>
#     </tr>
#     <tr>
#       <th id="T_d04f5_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_d04f5_row11_col0" class="data row11 col0" >0.0012</td>
#       <td id="T_d04f5_row11_col1" class="data row11 col1" >0.0008</td>
#       <td id="T_d04f5_row11_col2" class="data row11 col2" >0.0012</td>
#       <td id="T_d04f5_row11_col3" class="data row11 col3" >0.0012</td>
#       <td id="T_d04f5_row11_col4
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# Save model
save_model(decision_tree_model, 'S7_best_model_dt')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['adm_drug_dose_mean', 'adm_given',
#                                               'adm_prn', 'adm_route_ref', 'age',
#                                               'care_level_duration',
#                                               'clinical_records_result_num_mean',
#                                               'cr_meas_type_ref', 'death',
#                                               'diag_class_ref_H',
#                                               'diag_class_ref_P',
#                                               'diag_class_ref_S', 'drg_mdc_ref',
#                                               'drg_ref', 'drg_rom_ref'...
#                                                                missing_values=nan,
#                                                                strategy='most_frequent'))),
#                  ('trained_model',
#                   DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                          criterion='gini', max_depth=None,
#                                          max_features=None, max_leaf_nodes=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          monotonic_cst=None, random_state=123,
#                                          splitter='best'))],
#           verbose=False),
#  'S7_best_model_dt.pkl')

# %%
# Load model
decision_tree_model = load_model("C:/Users/Cindy Chen/Desktop/TFG/plots/04/S7/S7_best_model_dt")
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# ## **Optimize and Tune Model**
#
# The ```tune_model``` function tunes the hyperparameters of the model. The output of this function is a scoring grid with cross-validated scores by fold.
#
# By default, it uses RandomGridSearch from the sklearn and the number of iterations (n_iter) is set to 10.

# %%
# Optimize and tune model using Random Grid Search 
decision_tree_model_tuned = tune_model(decision_tree_model) # chose_better=False
# Out:
# <style type="text/css">
# #T_29978_row10_col0, #T_29978_row10_col1, #T_29978_row10_col2, #T_29978_row10_col3, #T_29978_row10_col4, #T_29978_row10_col5, #T_29978_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_29978">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29978_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_29978_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_29978_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_29978_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_29978_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_29978_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_29978_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29978_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29978_row0_col0" class="data row0 col0" >0.4083</td>
#       <td id="T_29978_row0_col1" class="data row0 col1" >0.8942</td>
#       <td id="T_29978_row0_col2" class="data row0 col2" >0.4083</td>
#       <td id="T_29978_row0_col3" class="data row0 col3" >0.4110</td>
#       <td id="T_29978_row0_col4" class="data row0 col4" >0.4076</td>
#       <td id="T_29978_row0_col5" class="data row0 col5" >0.3476</td>
#       <td id="T_29978_row0_col6" class="data row0 col6" >0.3479</td>
#     </tr>
#     <tr>
#       <th id="T_29978_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_29978_row1_col0" class="data row1 col0" >0.4113</td>
#       <td id="T_29978_row1_col1" class="data row1 col1" >0.8954</td>
#       <td id="T_29978_row1_col2" class="data row1 col2" >0.4113</td>
#       <td id="T_29978_row1_col3" class="data row1 col3" >0.4077</td>
#       <td id="T_29978_row1_col4" class="data row1 col4" >0.4070</td>
#       <td id="T_29978_row1_col5" class="data row1 col5" >0.3479</td>
#       <td id="T_29978_row1_col6" class="data row1 col6" >0.3482</td>
#     </tr>
#     <tr>
#       <th id="T_29978_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_29978_row2_col0" class="data row2 col0" >0.4039</td>
#       <td id="T_29978_row2_col1" class="data row2 col1" >0.8962</td>
#       <td id="T_29978_row2_col2" class="data row2 col2" >0.4039</td>
#       <td id="T_29978_row2_col3" class="data row2 col3" >0.4037</td>
#       <td id="T_29978_row2_col4" class="data row2 col4" >0.4019</td>
#       <td id="T_29978_row2_col5" class="data row2 col5" >0.3399</td>
#       <td id="T_29978_row2_col6" class="data row2 col6" >0.3400</td>
#     </tr>
#     <tr>
#       <th id="T_29978_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_29978_row3_col0" class="data row3 col0" >0.4098</td>
#       <td id="T_29978_row3_col1" class="data row3 col1" >0.8960</td>
#       <td id="T_29978_row3_col2" class="data row3 col2" >0.4098</td>
#       <td id="T_29978_row3_col3" class="data row3 col3" >0.4106</td>
#       <td id="T_29978_row3_col4" class="data row3 col4" >0.4077</td>
#       <td id="T_29978_row3_col5" class="data row3 col5" >0.3459</td>
#       <td id="T_29978_row3_col6" class="data row3 col6" >0.3461</td>
#     </tr>
#     <tr>
#       <th id="T_29978_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_29978_row4_col0" class="data row4 col0" >0.4037</td>
#       <td id="T_29978_row4_col1" class="data row4 col1" >0.8934</td>
#       <td id="T_29978_row4_col2" class="data row4 col2" >0.4037</td>
#       <td id="T_29978_row4_col3" class="data row4 col3" >0.4356</td>
#       <td id="T_29978_row4_col4" class="data row4 col4" >0.4094</td>
#       <td id="T_29978_row4_col5" class="data row4 col5" >0.3490</td>
#       <td id="T_29978_row4_col6" class="data row4 col6" >0.3512</td>
#     </tr>
#     <tr>
#       <th id="T_29978_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_29978_row5_col0" class="data row5 col0" >0.4019</td>
#       <td id="T_29978_row5_col1" class="data row5 col1" >0.8938</td>
#       <td id="T_29978_row5_col2" class="data row5 col2" >0.4019</td>
#       <td id="T_29978_row5_col3" class="data row5 col3" >0.4031</td>
#       <td id="T_29978_row5_col4" class="data row5 col4" >0.3995</td>
#       <td id="T_29978_row5_col5" class="data row5 col5" >0.3406</td>
#       <td id="T_29978_row5_col6" class="data row5 col6" >0.3410</td>
#     </tr>
#     <tr>
#       <th id="T_29978_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_29978_row6_col0" class="data row6 col0" >0.4098</td>
#       <td id="T_29978_row6_col1" class="data row6 col1" >0.8952</td>
#       <td id="T_29978_row6_col2" class="data row6 col2" >0.4098</td>
#       <td id="T_29978_row6_col3" class="data row6 col3" >0.4258</td>
#       <td id="T_29978_row6_col4" class="data row6 col4" >0.4150</td>
#       <td id="T_29978_row6_col5" class="data row6 col5" >0.3497</td>
#       <td id="T_29978_row6_col6" class="data row6 col6" >0.3501</td>
#     </tr>
#     <tr>
#       <th id="T_29978_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_29978_row7_col0" class="data row7 col0" >0.4046</td>
#       <td id="T_29978_row7_col1" class="data row7 col1" >0.8954</td>
#       <td id="T_29978_row7_col2" class="data row7 col2" >0.4046</td>
#       <td id="T_29978_row7_col3" class="data row7 col3" >0.4165</td>
#       <td id="T_29978_row7_col4" class="data row7 col4" >0.4010</td>
#       <td id="T_29978_row7_col5" class="data row7 col5" >0.3413</td>
#       <td id="T_29978_row7_col6" class="data row7 col6" >0.3426</td>
#     </tr>
#     <tr>
#       <th id="T_29978_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_29978_row8_col0" class="data row8 col0" >0.4044</td>
#       <td id="T_29978_row8_col1" class="data row8 col1" >0.8933</td>
#       <td id="T_29978_row8_col2" class="data row8 col2" >0.4044</td>
#       <td id="T_29978_row8_col3" class="data row8 col3" >0.4147</td>
#       <td id="T_29978_row8_col4" class="data row8 col4" >0.4067</td>
#       <td id="T_29978_row8_col5" class="data row8 col5" >0.3430</td>
#       <td id="T_29978_row8_col6" class="data row8 col6" >0.3435</td>
#     </tr>
#     <tr>
#       <th id="T_29978_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_29978_row9_col0" class="data row9 col0" >0.4099</td>
#       <td id="T_29978_row9_col1" class="data row9 col1" >0.8965</td>
#       <td id="T_29978_row9_col2" class="data row9 col2" >0.4099</td>
#       <td id="T_29978_row9_col3" class="data row9 col3" >0.4256</td>
#       <td id="T_29978_row9_col4" class="data row9 col4" >0.4134</td>
#       <td id="T_29978_row9_col5" class="data row9 col5" >0.3481</td>
#       <td id="T_29978_row9_col6" class="data row9 col6" >0.3487</td>
#     </tr>
#     <tr>
#       <th id="T_29978_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_29978_row10_col0" class="data row10 col0" >0.4068</td>
#       <td id="T_29978_row10_col1" class="data row10 col1" >0.8949</td>
#       <td id="T_29978_row10_col2" class="data row10 col2" >0.4068</td>
#       <td id="T_29978_row10_col3" class="data row10 col3" >0.4154</td>
#       <td id="T_29978_row10_col4" class="data row10 col4" >0.4069</td>
#       <td id="T_29978_row10_col5" class="data row10 col5" >0.3453</td>
#       <td id="T_29978_row10_col6" class="data row10 col6" >0.3459</td>
#     </tr>
#     <tr>
#       <th id="T_29978_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_29978_row11_col0" class="data row11 col0" >0.0032</td>
#       <td id="T_29978_row11_col1" class="data row11 col1" >0.0011</td>
#       <td id="T_29978_row11_col2" class="data row11 col2" >0.0032</td>
#       <td id="T_29978_row11_col3" class="data row11 col3" >0.0101</td>
#       <td id="T_29978_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# As we can see, the Random Grid Search didn't obtain better results than the original model, so let's try increasing the number of iterations to 100.

# %%
# Optimize and tune model using Random Grid Search and increasing the number of iterations
decision_tree_model_tuned = tune_model(decision_tree_model, n_iter=100) # chose_better=False
# Out:
# <style type="text/css">
# #T_6a431_row10_col0, #T_6a431_row10_col1, #T_6a431_row10_col2, #T_6a431_row10_col3, #T_6a431_row10_col4, #T_6a431_row10_col5, #T_6a431_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_6a431">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a431_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_6a431_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_6a431_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_6a431_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_6a431_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_6a431_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_6a431_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a431_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a431_row0_col0" class="data row0 col0" >0.4570</td>
#       <td id="T_6a431_row0_col1" class="data row0 col1" >0.9099</td>
#       <td id="T_6a431_row0_col2" class="data row0 col2" >0.4570</td>
#       <td id="T_6a431_row0_col3" class="data row0 col3" >0.4616</td>
#       <td id="T_6a431_row0_col4" class="data row0 col4" >0.4590</td>
#       <td id="T_6a431_row0_col5" class="data row0 col5" >0.4000</td>
#       <td id="T_6a431_row0_col6" class="data row0 col6" >0.4000</td>
#     </tr>
#     <tr>
#       <th id="T_6a431_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6a431_row1_col0" class="data row1 col0" >0.4545</td>
#       <td id="T_6a431_row1_col1" class="data row1 col1" >0.9095</td>
#       <td id="T_6a431_row1_col2" class="data row1 col2" >0.4545</td>
#       <td id="T_6a431_row1_col3" class="data row1 col3" >0.4616</td>
#       <td id="T_6a431_row1_col4" class="data row1 col4" >0.4561</td>
#       <td id="T_6a431_row1_col5" class="data row1 col5" >0.3985</td>
#       <td id="T_6a431_row1_col6" class="data row1 col6" >0.3988</td>
#     </tr>
#     <tr>
#       <th id="T_6a431_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6a431_row2_col0" class="data row2 col0" >0.4544</td>
#       <td id="T_6a431_row2_col1" class="data row2 col1" >0.9101</td>
#       <td id="T_6a431_row2_col2" class="data row2 col2" >0.4544</td>
#       <td id="T_6a431_row2_col3" class="data row2 col3" >0.4580</td>
#       <td id="T_6a431_row2_col4" class="data row2 col4" >0.4557</td>
#       <td id="T_6a431_row2_col5" class="data row2 col5" >0.3967</td>
#       <td id="T_6a431_row2_col6" class="data row2 col6" >0.3967</td>
#     </tr>
#     <tr>
#       <th id="T_6a431_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6a431_row3_col0" class="data row3 col0" >0.4603</td>
#       <td id="T_6a431_row3_col1" class="data row3 col1" >0.9107</td>
#       <td id="T_6a431_row3_col2" class="data row3 col2" >0.4603</td>
#       <td id="T_6a431_row3_col3" class="data row3 col3" >0.4624</td>
#       <td id="T_6a431_row3_col4" class="data row3 col4" >0.4607</td>
#       <td id="T_6a431_row3_col5" class="data row3 col5" >0.4035</td>
#       <td id="T_6a431_row3_col6" class="data row3 col6" >0.4036</td>
#     </tr>
#     <tr>
#       <th id="T_6a431_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6a431_row4_col0" class="data row4 col0" >0.4561</td>
#       <td id="T_6a431_row4_col1" class="data row4 col1" >0.9099</td>
#       <td id="T_6a431_row4_col2" class="data row4 col2" >0.4561</td>
#       <td id="T_6a431_row4_col3" class="data row4 col3" >0.4644</td>
#       <td id="T_6a431_row4_col4" class="data row4 col4" >0.4591</td>
#       <td id="T_6a431_row4_col5" class="data row4 col5" >0.4006</td>
#       <td id="T_6a431_row4_col6" class="data row4 col6" >0.4008</td>
#     </tr>
#     <tr>
#       <th id="T_6a431_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6a431_row5_col0" class="data row5 col0" >0.4565</td>
#       <td id="T_6a431_row5_col1" class="data row5 col1" >0.9095</td>
#       <td id="T_6a431_row5_col2" class="data row5 col2" >0.4565</td>
#       <td id="T_6a431_row5_col3" class="data row5 col3" >0.4647</td>
#       <td id="T_6a431_row5_col4" class="data row5 col4" >0.4595</td>
#       <td id="T_6a431_row5_col5" class="data row5 col5" >0.4000</td>
#       <td id="T_6a431_row5_col6" class="data row5 col6" >0.4002</td>
#     </tr>
#     <tr>
#       <th id="T_6a431_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6a431_row6_col0" class="data row6 col0" >0.4557</td>
#       <td id="T_6a431_row6_col1" class="data row6 col1" >0.9094</td>
#       <td id="T_6a431_row6_col2" class="data row6 col2" >0.4557</td>
#       <td id="T_6a431_row6_col3" class="data row6 col3" >0.4588</td>
#       <td id="T_6a431_row6_col4" class="data row6 col4" >0.4565</td>
#       <td id="T_6a431_row6_col5" class="data row6 col5" >0.3986</td>
#       <td id="T_6a431_row6_col6" class="data row6 col6" >0.3987</td>
#     </tr>
#     <tr>
#       <th id="T_6a431_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6a431_row7_col0" class="data row7 col0" >0.4550</td>
#       <td id="T_6a431_row7_col1" class="data row7 col1" >0.9101</td>
#       <td id="T_6a431_row7_col2" class="data row7 col2" >0.4550</td>
#       <td id="T_6a431_row7_col3" class="data row7 col3" >0.4562</td>
#       <td id="T_6a431_row7_col4" class="data row7 col4" >0.4550</td>
#       <td id="T_6a431_row7_col5" class="data row7 col5" >0.3973</td>
#       <td id="T_6a431_row7_col6" class="data row7 col6" >0.3974</td>
#     </tr>
#     <tr>
#       <th id="T_6a431_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6a431_row8_col0" class="data row8 col0" >0.4536</td>
#       <td id="T_6a431_row8_col1" class="data row8 col1" >0.9089</td>
#       <td id="T_6a431_row8_col2" class="data row8 col2" >0.4536</td>
#       <td id="T_6a431_row8_col3" class="data row8 col3" >0.4593</td>
#       <td id="T_6a431_row8_col4" class="data row8 col4" >0.4558</td>
#       <td id="T_6a431_row8_col5" class="data row8 col5" >0.3969</td>
#       <td id="T_6a431_row8_col6" class="data row8 col6" >0.3970</td>
#     </tr>
#     <tr>
#       <th id="T_6a431_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6a431_row9_col0" class="data row9 col0" >0.4551</td>
#       <td id="T_6a431_row9_col1" class="data row9 col1" >0.9091</td>
#       <td id="T_6a431_row9_col2" class="data row9 col2" >0.4551</td>
#       <td id="T_6a431_row9_col3" class="data row9 col3" >0.4565</td>
#       <td id="T_6a431_row9_col4" class="data row9 col4" >0.4555</td>
#       <td id="T_6a431_row9_col5" class="data row9 col5" >0.3975</td>
#       <td id="T_6a431_row9_col6" class="data row9 col6" >0.3976</td>
#     </tr>
#     <tr>
#       <th id="T_6a431_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6a431_row10_col0" class="data row10 col0" >0.4558</td>
#       <td id="T_6a431_row10_col1" class="data row10 col1" >0.9097</td>
#       <td id="T_6a431_row10_col2" class="data row10 col2" >0.4558</td>
#       <td id="T_6a431_row10_col3" class="data row10 col3" >0.4604</td>
#       <td id="T_6a431_row10_col4" class="data row10 col4" >0.4573</td>
#       <td id="T_6a431_row10_col5" class="data row10 col5" >0.3990</td>
#       <td id="T_6a431_row10_col6" class="data row10 col6" >0.3991</td>
#     </tr>
#     <tr>
#       <th id="T_6a431_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_6a431_row11_col0" class="data row11 col0" >0.0018</td>
#       <td id="T_6a431_row11_col1" class="data row11 col1" >0.0005</td>
#       <td id="T_6a431_row11_col2" class="data row11 col2" >0.0018</td>
#       <td id="T_6a431_row11_col3" class="data row11 col3" >0.0029</td>
#       <td id="T_6a431_row11_col4
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# Even when we increase the number of iterations the model doesn't improve. So let's customise the grid and parameters using custom_grid.
#
# For decision trees, the hyperparameters decided to use are:
# - max_depth
# - min_samples_split
# - min_samples_leaf
# - criterion

# %%
# Optimize and tune model using custom grid and Random Grid Search
params = {'max_depth': [None, 3, 5, 10, 15],
          'min_samples_split': [2, 5, 10],
          'min_samples_leaf': [1, 2, 5],
          'criterion': ['gini', 'entropy', 'log_loss']
} 

decision_tree_model_tuned = tune_model(decision_tree_model, custom_grid=params) # chose_better=False
# Out:
# <style type="text/css">
# #T_ac196_row10_col0, #T_ac196_row10_col1, #T_ac196_row10_col2, #T_ac196_row10_col3, #T_ac196_row10_col4, #T_ac196_row10_col5, #T_ac196_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_ac196">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac196_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_ac196_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_ac196_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_ac196_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_ac196_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_ac196_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_ac196_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac196_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ac196_row0_col0" class="data row0 col0" >0.6697</td>
#       <td id="T_ac196_row0_col1" class="data row0 col1" >0.8213</td>
#       <td id="T_ac196_row0_col2" class="data row0 col2" >0.6697</td>
#       <td id="T_ac196_row0_col3" class="data row0 col3" >0.6703</td>
#       <td id="T_ac196_row0_col4" class="data row0 col4" >0.6699</td>
#       <td id="T_ac196_row0_col5" class="data row0 col5" >0.6345</td>
#       <td id="T_ac196_row0_col6" class="data row0 col6" >0.6345</td>
#     </tr>
#     <tr>
#       <th id="T_ac196_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ac196_row1_col0" class="data row1 col0" >0.6707</td>
#       <td id="T_ac196_row1_col1" class="data row1 col1" >0.8220</td>
#       <td id="T_ac196_row1_col2" class="data row1 col2" >0.6707</td>
#       <td id="T_ac196_row1_col3" class="data row1 col3" >0.6713</td>
#       <td id="T_ac196_row1_col4" class="data row1 col4" >0.6709</td>
#       <td id="T_ac196_row1_col5" class="data row1 col5" >0.6355</td>
#       <td id="T_ac196_row1_col6" class="data row1 col6" >0.6355</td>
#     </tr>
#     <tr>
#       <th id="T_ac196_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ac196_row2_col0" class="data row2 col0" >0.6708</td>
#       <td id="T_ac196_row2_col1" class="data row2 col1" >0.8222</td>
#       <td id="T_ac196_row2_col2" class="data row2 col2" >0.6708</td>
#       <td id="T_ac196_row2_col3" class="data row2 col3" >0.6707</td>
#       <td id="T_ac196_row2_col4" class="data row2 col4" >0.6707</td>
#       <td id="T_ac196_row2_col5" class="data row2 col5" >0.6356</td>
#       <td id="T_ac196_row2_col6" class="data row2 col6" >0.6356</td>
#     </tr>
#     <tr>
#       <th id="T_ac196_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ac196_row3_col0" class="data row3 col0" >0.6711</td>
#       <td id="T_ac196_row3_col1" class="data row3 col1" >0.8220</td>
#       <td id="T_ac196_row3_col2" class="data row3 col2" >0.6711</td>
#       <td id="T_ac196_row3_col3" class="data row3 col3" >0.6716</td>
#       <td id="T_ac196_row3_col4" class="data row3 col4" >0.6713</td>
#       <td id="T_ac196_row3_col5" class="data row3 col5" >0.6359</td>
#       <td id="T_ac196_row3_col6" class="data row3 col6" >0.6359</td>
#     </tr>
#     <tr>
#       <th id="T_ac196_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ac196_row4_col0" class="data row4 col0" >0.6693</td>
#       <td id="T_ac196_row4_col1" class="data row4 col1" >0.8212</td>
#       <td id="T_ac196_row4_col2" class="data row4 col2" >0.6693</td>
#       <td id="T_ac196_row4_col3" class="data row4 col3" >0.6699</td>
#       <td id="T_ac196_row4_col4" class="data row4 col4" >0.6695</td>
#       <td id="T_ac196_row4_col5" class="data row4 col5" >0.6339</td>
#       <td id="T_ac196_row4_col6" class="data row4 col6" >0.6339</td>
#     </tr>
#     <tr>
#       <th id="T_ac196_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ac196_row5_col0" class="data row5 col0" >0.6721</td>
#       <td id="T_ac196_row5_col1" class="data row5 col1" >0.8229</td>
#       <td id="T_ac196_row5_col2" class="data row5 col2" >0.6721</td>
#       <td id="T_ac196_row5_col3" class="data row5 col3" >0.6730</td>
#       <td id="T_ac196_row5_col4" class="data row5 col4" >0.6725</td>
#       <td id="T_ac196_row5_col5" class="data row5 col5" >0.6371</td>
#       <td id="T_ac196_row5_col6" class="data row5 col6" >0.6371</td>
#     </tr>
#     <tr>
#       <th id="T_ac196_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ac196_row6_col0" class="data row6 col0" >0.6694</td>
#       <td id="T_ac196_row6_col1" class="data row6 col1" >0.8211</td>
#       <td id="T_ac196_row6_col2" class="data row6 col2" >0.6694</td>
#       <td id="T_ac196_row6_col3" class="data row6 col3" >0.6697</td>
#       <td id="T_ac196_row6_col4" class="data row6 col4" >0.6695</td>
#       <td id="T_ac196_row6_col5" class="data row6 col5" >0.6341</td>
#       <td id="T_ac196_row6_col6" class="data row6 col6" >0.6341</td>
#     </tr>
#     <tr>
#       <th id="T_ac196_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ac196_row7_col0" class="data row7 col0" >0.6715</td>
#       <td id="T_ac196_row7_col1" class="data row7 col1" >0.8227</td>
#       <td id="T_ac196_row7_col2" class="data row7 col2" >0.6715</td>
#       <td id="T_ac196_row7_col3" class="data row7 col3" >0.6719</td>
#       <td id="T_ac196_row7_col4" class="data row7 col4" >0.6716</td>
#       <td id="T_ac196_row7_col5" class="data row7 col5" >0.6365</td>
#       <td id="T_ac196_row7_col6" class="data row7 col6" >0.6365</td>
#     </tr>
#     <tr>
#       <th id="T_ac196_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ac196_row8_col0" class="data row8 col0" >0.6665</td>
#       <td id="T_ac196_row8_col1" class="data row8 col1" >0.8195</td>
#       <td id="T_ac196_row8_col2" class="data row8 col2" >0.6665</td>
#       <td id="T_ac196_row8_col3" class="data row8 col3" >0.6672</td>
#       <td id="T_ac196_row8_col4" class="data row8 col4" >0.6668</td>
#       <td id="T_ac196_row8_col5" class="data row8 col5" >0.6309</td>
#       <td id="T_ac196_row8_col6" class="data row8 col6" >0.6309</td>
#     </tr>
#     <tr>
#       <th id="T_ac196_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ac196_row9_col0" class="data row9 col0" >0.6670</td>
#       <td id="T_ac196_row9_col1" class="data row9 col1" >0.8199</td>
#       <td id="T_ac196_row9_col2" class="data row9 col2" >0.6670</td>
#       <td id="T_ac196_row9_col3" class="data row9 col3" >0.6681</td>
#       <td id="T_ac196_row9_col4" class="data row9 col4" >0.6675</td>
#       <td id="T_ac196_row9_col5" class="data row9 col5" >0.6316</td>
#       <td id="T_ac196_row9_col6" class="data row9 col6" >0.6316</td>
#     </tr>
#     <tr>
#       <th id="T_ac196_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_ac196_row10_col0" class="data row10 col0" >0.6698</td>
#       <td id="T_ac196_row10_col1" class="data row10 col1" >0.8215</td>
#       <td id="T_ac196_row10_col2" class="data row10 col2" >0.6698</td>
#       <td id="T_ac196_row10_col3" class="data row10 col3" >0.6704</td>
#       <td id="T_ac196_row10_col4" class="data row10 col4" >0.6700</td>
#       <td id="T_ac196_row10_col5" class="data row10 col5" >0.6346</td>
#       <td id="T_ac196_row10_col6" class="data row10 col6" >0.6346</td>
#     </tr>
#     <tr>
#       <th id="T_ac196_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_ac196_row11_col0" class="data row11 col0" >0.0018</td>
#       <td id="T_ac196_row11_col1" class="data row11 col1" >0.0011</td>
#       <td id="T_ac196_row11_col2" class="data row11 col2" >0.0018</td>
#       <td id="T_ac196_row11_col3" class="data row11 col3" >0.0017</td>
#       <td id="T_ac196_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
# Optimize and tune model using custom grid and GridSearchCV
params = {'max_depth': [None, 3, 5, 10, 15],
          'min_samples_split': [2, 5, 10],
          'min_samples_leaf': [1, 2, 5],
          'criterion': ['gini', 'entropy', 'log_loss']
}

decision_tree_model_tuned = tune_model(decision_tree_model, custom_grid=params, search_library='scikit-learn', search_algorithm='grid')
# Out:
# <style type="text/css">
# #T_433c0_row10_col0, #T_433c0_row10_col1, #T_433c0_row10_col2, #T_433c0_row10_col3, #T_433c0_row10_col4, #T_433c0_row10_col5, #T_433c0_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_433c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_433c0_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_433c0_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_433c0_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_433c0_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_433c0_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_433c0_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_433c0_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_433c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_433c0_row0_col0" class="data row0 col0" >0.6697</td>
#       <td id="T_433c0_row0_col1" class="data row0 col1" >0.8213</td>
#       <td id="T_433c0_row0_col2" class="data row0 col2" >0.6697</td>
#       <td id="T_433c0_row0_col3" class="data row0 col3" >0.6703</td>
#       <td id="T_433c0_row0_col4" class="data row0 col4" >0.6699</td>
#       <td id="T_433c0_row0_col5" class="data row0 col5" >0.6345</td>
#       <td id="T_433c0_row0_col6" class="data row0 col6" >0.6345</td>
#     </tr>
#     <tr>
#       <th id="T_433c0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_433c0_row1_col0" class="data row1 col0" >0.6707</td>
#       <td id="T_433c0_row1_col1" class="data row1 col1" >0.8220</td>
#       <td id="T_433c0_row1_col2" class="data row1 col2" >0.6707</td>
#       <td id="T_433c0_row1_col3" class="data row1 col3" >0.6713</td>
#       <td id="T_433c0_row1_col4" class="data row1 col4" >0.6709</td>
#       <td id="T_433c0_row1_col5" class="data row1 col5" >0.6355</td>
#       <td id="T_433c0_row1_col6" class="data row1 col6" >0.6355</td>
#     </tr>
#     <tr>
#       <th id="T_433c0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_433c0_row2_col0" class="data row2 col0" >0.6708</td>
#       <td id="T_433c0_row2_col1" class="data row2 col1" >0.8222</td>
#       <td id="T_433c0_row2_col2" class="data row2 col2" >0.6708</td>
#       <td id="T_433c0_row2_col3" class="data row2 col3" >0.6707</td>
#       <td id="T_433c0_row2_col4" class="data row2 col4" >0.6707</td>
#       <td id="T_433c0_row2_col5" class="data row2 col5" >0.6356</td>
#       <td id="T_433c0_row2_col6" class="data row2 col6" >0.6356</td>
#     </tr>
#     <tr>
#       <th id="T_433c0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_433c0_row3_col0" class="data row3 col0" >0.6711</td>
#       <td id="T_433c0_row3_col1" class="data row3 col1" >0.8220</td>
#       <td id="T_433c0_row3_col2" class="data row3 col2" >0.6711</td>
#       <td id="T_433c0_row3_col3" class="data row3 col3" >0.6716</td>
#       <td id="T_433c0_row3_col4" class="data row3 col4" >0.6713</td>
#       <td id="T_433c0_row3_col5" class="data row3 col5" >0.6359</td>
#       <td id="T_433c0_row3_col6" class="data row3 col6" >0.6359</td>
#     </tr>
#     <tr>
#       <th id="T_433c0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_433c0_row4_col0" class="data row4 col0" >0.6693</td>
#       <td id="T_433c0_row4_col1" class="data row4 col1" >0.8212</td>
#       <td id="T_433c0_row4_col2" class="data row4 col2" >0.6693</td>
#       <td id="T_433c0_row4_col3" class="data row4 col3" >0.6699</td>
#       <td id="T_433c0_row4_col4" class="data row4 col4" >0.6695</td>
#       <td id="T_433c0_row4_col5" class="data row4 col5" >0.6339</td>
#       <td id="T_433c0_row4_col6" class="data row4 col6" >0.6339</td>
#     </tr>
#     <tr>
#       <th id="T_433c0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_433c0_row5_col0" class="data row5 col0" >0.6721</td>
#       <td id="T_433c0_row5_col1" class="data row5 col1" >0.8229</td>
#       <td id="T_433c0_row5_col2" class="data row5 col2" >0.6721</td>
#       <td id="T_433c0_row5_col3" class="data row5 col3" >0.6730</td>
#       <td id="T_433c0_row5_col4" class="data row5 col4" >0.6725</td>
#       <td id="T_433c0_row5_col5" class="data row5 col5" >0.6371</td>
#       <td id="T_433c0_row5_col6" class="data row5 col6" >0.6371</td>
#     </tr>
#     <tr>
#       <th id="T_433c0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_433c0_row6_col0" class="data row6 col0" >0.6694</td>
#       <td id="T_433c0_row6_col1" class="data row6 col1" >0.8211</td>
#       <td id="T_433c0_row6_col2" class="data row6 col2" >0.6694</td>
#       <td id="T_433c0_row6_col3" class="data row6 col3" >0.6697</td>
#       <td id="T_433c0_row6_col4" class="data row6 col4" >0.6695</td>
#       <td id="T_433c0_row6_col5" class="data row6 col5" >0.6341</td>
#       <td id="T_433c0_row6_col6" class="data row6 col6" >0.6341</td>
#     </tr>
#     <tr>
#       <th id="T_433c0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_433c0_row7_col0" class="data row7 col0" >0.6715</td>
#       <td id="T_433c0_row7_col1" class="data row7 col1" >0.8227</td>
#       <td id="T_433c0_row7_col2" class="data row7 col2" >0.6715</td>
#       <td id="T_433c0_row7_col3" class="data row7 col3" >0.6719</td>
#       <td id="T_433c0_row7_col4" class="data row7 col4" >0.6716</td>
#       <td id="T_433c0_row7_col5" class="data row7 col5" >0.6365</td>
#       <td id="T_433c0_row7_col6" class="data row7 col6" >0.6365</td>
#     </tr>
#     <tr>
#       <th id="T_433c0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_433c0_row8_col0" class="data row8 col0" >0.6665</td>
#       <td id="T_433c0_row8_col1" class="data row8 col1" >0.8195</td>
#       <td id="T_433c0_row8_col2" class="data row8 col2" >0.6665</td>
#       <td id="T_433c0_row8_col3" class="data row8 col3" >0.6672</td>
#       <td id="T_433c0_row8_col4" class="data row8 col4" >0.6668</td>
#       <td id="T_433c0_row8_col5" class="data row8 col5" >0.6309</td>
#       <td id="T_433c0_row8_col6" class="data row8 col6" >0.6309</td>
#     </tr>
#     <tr>
#       <th id="T_433c0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_433c0_row9_col0" class="data row9 col0" >0.6670</td>
#       <td id="T_433c0_row9_col1" class="data row9 col1" >0.8199</td>
#       <td id="T_433c0_row9_col2" class="data row9 col2" >0.6670</td>
#       <td id="T_433c0_row9_col3" class="data row9 col3" >0.6681</td>
#       <td id="T_433c0_row9_col4" class="data row9 col4" >0.6675</td>
#       <td id="T_433c0_row9_col5" class="data row9 col5" >0.6316</td>
#       <td id="T_433c0_row9_col6" class="data row9 col6" >0.6316</td>
#     </tr>
#     <tr>
#       <th id="T_433c0_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_433c0_row10_col0" class="data row10 col0" >0.6698</td>
#       <td id="T_433c0_row10_col1" class="data row10 col1" >0.8215</td>
#       <td id="T_433c0_row10_col2" class="data row10 col2" >0.6698</td>
#       <td id="T_433c0_row10_col3" class="data row10 col3" >0.6704</td>
#       <td id="T_433c0_row10_col4" class="data row10 col4" >0.6700</td>
#       <td id="T_433c0_row10_col5" class="data row10 col5" >0.6346</td>
#       <td id="T_433c0_row10_col6" class="data row10 col6" >0.6346</td>
#     </tr>
#     <tr>
#       <th id="T_433c0_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_433c0_row11_col0" class="data row11 col0" >0.0018</td>
#       <td id="T_433c0_row11_col1" class="data row11 col1" >0.0011</td>
#       <td id="T_433c0_row11_col2" class="data row11 col2" >0.0018</td>
#       <td id="T_433c0_row11_col3" class="data row11 col3" >0.0017</td>
#       <td id="T_433c0_row11_col4
# Fitting 10 folds for each of 135 candidates, totalling 1350 fits

# %% [markdown]
# As we can see, the model improved a little bit, compared to the original one and the first two tunings.

# %%
# Save tuned model
save_model(decision_tree_model_tuned, 'S7_best_model_dt_tuned')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['adm_drug_dose_mean', 'adm_given',
#                                               'adm_prn', 'adm_route_ref', 'age',
#                                               'care_level_duration',
#                                               'clinical_records_result_num_mean',
#                                               'cr_meas_type_ref', 'death',
#                                               'diag_class_ref_H',
#                                               'diag_class_ref_P',
#                                               'diag_class_ref_S', 'drg_mdc_ref',
#                                               'drg_ref', 'drg_rom_ref'...
#                                                                missing_values=nan,
#                                                                strategy='most_frequent'))),
#                  ('trained_model',
#                   DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                          criterion='log_loss', max_depth=None,
#                                          max_features=None, max_leaf_nodes=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          monotonic_cst=None, random_state=123,
#                                          splitter='best'))],
#           verbose=False),
#  'S7_best_model_dt_tunned.pkl')

# %%
# Load tuned model
decision_tree_model_tuned = load_model("C:/Users/Cindy Chen/Desktop/TFG/plots/04/S7/S7_best_model_dt_tuned")
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
# Hyperparameters before tunning
print(decision_tree_model)
# Out:
# Pipeline(memory=FastMemory(location=C:\Users\CINDYC~1\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['adm_drug_dose_mean', 'adm_given',
#                                              'adm_prn', 'adm_route_ref', 'age',
#                                              'care_level_duration',
#                                              'clinical_records_result_num_mean',
#                                              'cr_meas_type_ref', 'death',
#                                              'diag_class_ref_H',
#                                              'diag_class_ref_P',
#                                              'diag_class_r...
#                                                               missing_values=nan,
#                                                               strategy='most_frequent'))),
#                 ('trained_model',
#                  DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                         criterion='gini', max_depth=None,
#                                         max_features=None, max_leaf_nodes=None,
#                                         min_impurity_decrease=0.0,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         monotonic_cst=None, random_state=123,
#                                         splitter='best'))],
#          verbose=False)

# %%
# Hyperparameters after tunning
print(decision_tree_model_tuned)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='log_loss',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, random_state=123, splitter='best')

# %% [markdown]
# In this case, the hyperparameter of criterion changed from gini to log_loss.

# %% [markdown]
# ## **Predictions**
#
# Using the ```predict_model``` function, we can predicts the performance of the model on the test set.

# %%
# Predict on the test set
predict_model(decision_tree_model_tuned)
# Out:
#          adm_drug_dose_mean  adm_given  adm_prn  adm_route_ref   age  \
# 218191                  1.0        0.0      0.0          100.0  74.0
# 863976                100.0        1.0      0.0          150.0  79.0
# 961023                100.0        0.0      1.0          150.0  56.0
# 916955                100.0        1.0      0.0          150.0  51.0
# 1013913                 5.0        0.0      1.0          150.0  74.0
# ...                     ...        ...      ...            ...   ...
# 842210                100.0        1.0      0.0          150.0  41.0
# 999667                495.0        0.0      0.0          350.0  45.0
# 323441                  2.0        0.0      1.0          100.0  74.0
# 882856                  2.0        1.0      0.0          150.0  73.0
# 586894                  1.0        0.0      0.0          100.0  69.0
#
#          care_level_duration  clinical_records_result_num_mean  \
# 218191            181.709442                         17.965517
# 863976            789.266663                         89.620689
# 961023            219.366394                        132.425919
# 916955             46.750000                        156.122452
# 1013913           481.936676                         86.611115
# ...                      ...                               ...
# 842210            937.500000                         35.799999
# 999667            116.433334                         36.165573
# 323441            481.936676                         55.170731
# 882856             29.608889                         95.695656
# 586894            571.786133                         20.179487
#
#          cr_meas_type_ref  death  diag_class_ref_H  ...  num_health_issues  \
# 218191                1.0    0.0               0.0  ...                8.0
# 863976                1.0    0.0               0.0  ...                9.0
# 961023                0.0    0.0               0.0  ...                7.0
# 916955                0.0    0.0               0.0  ...                3.0
# 1013913               2.0    0.0               0.0  ...                8.0
# ...                   ...    ...               ...  ...                ...
# 842210                0.0    1.0               0.0  ...                8.0
# 999667                0.0    0.0               0.0  ...                3.0
# 323441                0.0    0.0               0.0  ...                8.0
# 882856                2.0    0.0               0.0  ...                5.0
# 586894                0.0    0.0               0.0  ...                7.0
#
#          ongoing  prescription_drug_dose_mean  prescription_freq_ref  \
# 218191       1.0                   495.399994              10.653914
# 863976       1.0                   100.000000              10.653914
# 961023       0.0                   500.000000              10.764503
# 916955       1.0                     1.000000              10.844776
# 1013913      0.0                   500.000000              10.764503
# ...          ...                          ...                    ...
# 842210       1.0                     2.000000              10.653914
# 999667       1.0                     1.333333              10.653914
# 323441       1.0                   495.399994              10.764503
# 882856       1.0                     2.000000              10.844776
# 586894       1.0                     6.000000              10.645352
#
#          rc_sap_ref_PRESN_SIS  sex_atr   snomed_code  icd10_capitulo  \
# 218191                    0.0      2.0  6.540401e+07               1
# 863976                    0.0      2.0  6.004601e+07              12
# 961023                    1.0      1.0  9.532600e+07              14
# 916955                    1.0      2.0  1.162900e+08              14
# 1013913                   0.0      2.0  2.147484e+09              16
# ...                       ...      ...           ...             ...
# 842210                    0.0      1.0  1.392001e+07              14
# 999667                    0.0      2.0  8.238501e+07              14
# 323441                    0.0      2.0  3.074960e+08               1
# 882856                    0.0      1.0  3.121040e+08              15
# 586894                    0.0      2.0  7.377401e+07              13
#
#          prediction_label  prediction_score
# 218191                 15               1.0
# 863976                 17               1.0
# 961023                 14               1.0
# 916955                 14               1.0
# 1013913                16               1.0
# ...                   ...               ...
# 842210                  0               1.0
# 999667                  1               1.0
# 323441                  1               1.0
# 882856                 12               0.5
# 586894                 13               1.0
#
# [313796 rows x 32 columns]

# %%
# Get the performance metrics
pull()
# Out:
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# 0  Decision Tree Classifier    0.6889  0.8327  0.6889  0.6895  0.6891  0.6556
#
#       MCC
# 0  0.6556

# %% [markdown]
# ## **Analyse Model**
#
# Plots to analyse the performance of the model on the test set.

# %% [markdown]
# ### **Confusion Matrix**

# %%
# Confusion Matrix
plt.figure(figsize=(25, 25))
plot_model(decision_tree_model_tuned, plot = 'confusion_matrix') # save=True, use_train_data=False

# %% [markdown]
# ### **Area Under the Curve (AUC)**

# %%
# Area Under the Curve (AUC)
plt.figure(figsize=(25, 25))
plot_model(decision_tree_model_tuned, plot = 'auc') # save=True

# %% [markdown]
# ### **Class Prediction Error**

# %%
# Class Prediction Error
plt.figure(figsize=(10, 5))
plot_model(decision_tree_model_tuned, plot = 'error') # save=True

# %% [markdown]
# ### **Classification Report**

# %%
# Classification Report
plt.figure(figsize=(10, 10))
plot_model(decision_tree_model_tuned, plot = 'class_report') # save=True

# %% [markdown]
# ### **Feature Importance**

# %%
# Feature importance
plt.figure(figsize=(10, 10))
plot_model(decision_tree_model_tuned, plot = 'feature') # save=True
