# %% [markdown]
# # **TFG**
#
# ***Machine Learning-Based Classification of Hospital Discharge Diagnoses Using SNOMED-CT Encoded Health Problems and Clinical Data***
#
# Cindy Chen
#
# Universitat de Barcelona
#
# 2024-2025

# %%
# Import modules 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display 
import gradio as gr
import os
from pycaret.classification import *
from pycaret.classification import plot_model
from pycaret.classification import predict_model, pull, load_model

# %matplotlib inline

# %% [markdown]
# ## **Data Importation**
#
# Import Subset 2 to find the best model, train the model, tune it and evaluate.

# %%
# Import data
data = pd.read_csv("C:/Users/Cindy Chen/Desktop/TFG/data/04_data/subset_2.csv")
data
# Out:
#          episode_duration  care_level_duration  no_administration_reason_ref  \
# 0              706.924438           706.924438                           3.0
# 1              287.425842           146.750000                           0.0
# 2             2222.074951          1703.783569                           5.0
# 3             1358.753296           433.244171                           6.0
# 4             1358.753296           481.936676                           0.0
# ...                   ...                  ...                           ...
# 1045979       1842.586670             2.855278                           3.0
# 1045980        163.000000            94.935280                           0.0
# 1045981       1512.166626           107.043053                           5.0
# 1045982       1311.468872          1306.877197                           6.0
# 1045983        904.000000            55.612221                           0.0
#
#          drg_mdc_ref   age  snomed_code  drg_ref  prescription_freq_ref  \
# 0               11.0  81.0  240131006.0    469.0              10.653915
# 1               16.0  47.0  109989006.0    662.0              10.653915
# 2                7.0  73.0  439740005.0    260.0              10.653915
# 3                6.0  74.0  433146000.0    231.0              10.764504
# 4                6.0  74.0  307496006.0    231.0              10.158386
# ...              ...   ...          ...      ...                    ...
# 1045979         18.0  67.0  409623005.0    710.0              10.764504
# 1045980          7.0  77.0  230690007.0    260.0              10.844777
# 1045981         17.0  45.0  307651005.0      7.0              10.844777
# 1045982          8.0  54.0   77493009.0    320.0              10.653915
# 1045983         17.0  73.0   51387008.0      7.0              10.653915
#
#          drg_weight  adm_drug_dose_mean  ...  num_health_issues  \
# 0            1.7913                 1.2  ...                3.0
# 1            0.9884               100.0  ...                3.0
# 2            5.9280               500.0  ...                5.0
# 3            2.3206                 2.0  ...                8.0
# 4            2.3206                 1.0  ...                8.0
# ...             ...                 ...  ...                ...
# 1045979      4.4717               100.0  ...                4.0
# 1045980      2.0237                 1.0  ...                2.0
# 1045981     17.9363                 1.0  ...                3.0
# 1045982      1.3415                 2.0  ...                1.0
# 1045983      9.0648                 0.9  ...                5.0
#
#          cr_meas_type_ref  lab_result_num_mean  adm_prn  adm_given  \
# 0                     1.0             0.000000      0.0        1.0
# 1                     0.0            97.176926      1.0        0.0
# 2                     1.0             1.740909      0.0        1.0
# 3                     0.0             0.050000      0.0        1.0
# 4                     0.0             0.966667      0.0        0.0
# ...                   ...                  ...      ...        ...
# 1045979               0.0            75.750000      0.0        1.0
# 1045980               2.0             1.483333      0.0        0.0
# 1045981               0.0            78.501724      0.0        1.0
# 1045982               0.0           100.199997      0.0        1.0
# 1045983               2.0             0.283333      0.0        0.0
#
#          clinical_records_result_num_mean  prescription_drug_dose_mean  \
# 0                               94.131577                   100.000000
# 1                               68.900002                     0.666667
# 2                              110.247528                   491.333344
# 3                               36.254166                   500.000000
# 4                               55.170731                     4.800000
# ...                                   ...                          ...
# 1045979                         91.694443                   491.166656
# 1045980                         67.321426                     1.000000
# 1045981                         77.400002                     1.000000
# 1045982                         96.349998                     2.000000
# 1045983                         80.052635                    10.000000
#
#          adm_route_ref  health_issue_ou_med_ref  icd10_capitulo
# 0                150.0                11.859204              17
# 1                150.0                10.077813              17
# 2                350.0                 9.377647               1
# 3                150.0                10.600160               9
# 4                100.0                10.600160              16
# ...                ...                      ...             ...
# 1045979          150.0                10.965332              14
# 1045980          150.0                12.826443              14
# 1045981          100.0                10.077813               1
# 1045982          150.0                 9.260414              15
# 1045983          100.0                10.077813              13
#
# [1045984 rows x 21 columns]

# %% [markdown]
# Setup the pycaret environment and select the target column, in our case is the 'icd10_capitulo' column. This function also splits the data into training (70%) and testing set (30%).

# %%
# Configuración del entorno de PyCaret
clf = setup(data=data, target='icd10_capitulo', session_id=123, verbose=True)
# Out:
# <style type="text/css">
# #T_f3491_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f3491">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3491_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f3491_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3491_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f3491_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f3491_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f3491_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f3491_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f3491_row1_col1" class="data row1 col1" >icd10_capitulo</td>
#     </tr>
#     <tr>
#       <th id="T_f3491_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f3491_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f3491_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_f3491_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f3491_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f3491_row3_col1" class="data row3 col1" >(1045984, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_f3491_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f3491_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f3491_row4_col1" class="data row4 col1" >(1045984, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_f3491_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f3491_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f3491_row5_col1" class="data row5 col1" >(732188, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_f3491_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f3491_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f3491_row6_col1" class="data row6 col1" >(313796, 21)</td>
#     </tr>
#     <tr>
#       <th id="T_f3491_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f3491_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_f3491_row7_col1" class="data row7 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_f3491_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f3491_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_f3491_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f3491_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f3491_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_f3491_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f3491_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f3491_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_f3491_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f3491_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f3491_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_f3491_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f3491_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f3491_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_f3491_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_f3491_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f3491_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_f3491_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f3491_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f3491_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_f3491_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f3491_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f3491_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_f3491_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f3491_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f3491_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_f3491_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f3491_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f3491_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_f3491_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f3491_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f3491_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_f3491_row18_col1" class="data row18 col1" >d477</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Get preprocessing pipeline
get_config('pipeline')
# Out:
# Pipeline(memory=FastMemory(location=C:\Users\CINDYC~1\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['episode_duration',
#                                              'care_level_duration',
#                                              'no_administration_reason_ref',
#                                              'drg_mdc_ref', 'age',
#                                              'snomed_code', 'drg_ref',
#                                              'prescription_freq_ref',
#                                              'drg_weight', 'adm_drug_dose_mean',
#                                              'diag_class_ref_S',
#                                              'num_he...
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='mean'))),
#                 ('categorical_imputer',
#                  TransformerWrapper(exclude=None, include=[],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='most_frequent')))],
#          verbose=False)

# %% [markdown]
# ## **Model Comparison**
#
# Using the ```compare_models``` function to compare the selected models: Logistic Regression, Decision Trees, Random Forest, XGBoost, SVM, KNN and MLP.
#
# This function trains and evaluates the performance of all estimators available in the model library using cross-validation. The output of this function is a scoring grid with average cross-validated scores.

# %%
# Compare models
model_comparison = compare_models(include=["lr", 'dt', 'rf', 'xgboost', 'svm', 'knn', 'mlp'])
# Out:
# <style type="text/css">
# #T_e6f5e th {
#   text-align: left;
# }
# #T_e6f5e_row0_col0, #T_e6f5e_row0_col2, #T_e6f5e_row1_col0, #T_e6f5e_row1_col1, #T_e6f5e_row1_col3, #T_e6f5e_row1_col4, #T_e6f5e_row1_col5, #T_e6f5e_row1_col6, #T_e6f5e_row1_col7, #T_e6f5e_row2_col0, #T_e6f5e_row2_col1, #T_e6f5e_row2_col2, #T_e6f5e_row2_col3, #T_e6f5e_row2_col4, #T_e6f5e_row2_col5, #T_e6f5e_row2_col6, #T_e6f5e_row2_col7, #T_e6f5e_row3_col0, #T_e6f5e_row3_col1, #T_e6f5e_row3_col2, #T_e6f5e_row3_col3, #T_e6f5e_row3_col4, #T_e6f5e_row3_col5, #T_e6f5e_row3_col6, #T_e6f5e_row3_col7, #T_e6f5e_row4_col0, #T_e6f5e_row4_col1, #T_e6f5e_row4_col2, #T_e6f5e_row4_col3, #T_e6f5e_row4_col4, #T_e6f5e_row4_col5, #T_e6f5e_row4_col6, #T_e6f5e_row4_col7, #T_e6f5e_row5_col0, #T_e6f5e_row5_col1, #T_e6f5e_row5_col2, #T_e6f5e_row5_col3, #T_e6f5e_row5_col4, #T_e6f5e_row5_col5, #T_e6f5e_row5_col6, #T_e6f5e_row5_col7 {
#   text-align: left;
# }
# #T_e6f5e_row0_col1, #T_e6f5e_row0_col3, #T_e6f5e_row0_col4, #T_e6f5e_row0_col5, #T_e6f5e_row0_col6, #T_e6f5e_row0_col7, #T_e6f5e_row1_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e6f5e_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_e6f5e_row1_col8, #T_e6f5e_row2_col8, #T_e6f5e_row3_col8, #T_e6f5e_row4_col8, #T_e6f5e_row5_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e6f5e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6f5e_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e6f5e_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_e6f5e_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_e6f5e_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_e6f5e_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_e6f5e_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_e6f5e_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_e6f5e_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_e6f5e_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6f5e_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_e6f5e_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_e6f5e_row0_col1" class="data row0 col1" >0.6627</td>
#       <td id="T_e6f5e_row0_col2" class="data row0 col2" >0.8175</td>
#       <td id="T_e6f5e_row0_col3" class="data row0 col3" >0.6627</td>
#       <td id="T_e6f5e_row0_col4" class="data row0 col4" >0.6632</td>
#       <td id="T_e6f5e_row0_col5" class="data row0 col5" >0.6629</td>
#       <td id="T_e6f5e_row0_col6" class="data row0 col6" >0.6267</td>
#       <td id="T_e6f5e_row0_col7" class="data row0 col7" >0.6267</td>
#       <td id="T_e6f5e_row0_col8" class="data row0 col8" >1.6850</td>
#     </tr>
#     <tr>
#       <th id="T_e6f5e_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_e6f5e_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_e6f5e_row1_col1" class="data row1 col1" >0.4538</td>
#       <td id="T_e6f5e_row1_col2" class="data row1 col2" >0.9063</td>
#       <td id="T_e6f5e_row1_col3" class="data row1 col3" >0.4538</td>
#       <td id="T_e6f5e_row1_col4" class="data row1 col4" >0.4662</td>
#       <td id="T_e6f5e_row1_col5" class="data row1 col5" >0.4569</td>
#       <td id="T_e6f5e_row1_col6" class="data row1 col6" >0.4003</td>
#       <td id="T_e6f5e_row1_col7" class="data row1 col7" >0.4008</td>
#       <td id="T_e6f5e_row1_col8" class="data row1 col8" >49.2900</td>
#     </tr>
#     <tr>
#       <th id="T_e6f5e_level0_row2" class="row_heading level0 row2" >knn</th>
#       <td id="T_e6f5e_row2_col0" class="data row2 col0" >K Neighbors Classifier</td>
#       <td id="T_e6f5e_row2_col1" class="data row2 col1" >0.3280</td>
#       <td id="T_e6f5e_row2_col2" class="data row2 col2" >0.7748</td>
#       <td id="T_e6f5e_row2_col3" class="data row2 col3" >0.3280</td>
#       <td id="T_e6f5e_row2_col4" class="data row2 col4" >0.3359</td>
#       <td id="T_e6f5e_row2_col5" class="data row2 col5" >0.3287</td>
#       <td id="T_e6f5e_row2_col6" class="data row2 col6" >0.2575</td>
#       <td id="T_e6f5e_row2_col7" class="data row2 col7" >0.2580</td>
#       <td id="T_e6f5e_row2_col8" class="data row2 col8" >117.4860</td>
#     </tr>
#     <tr>
#       <th id="T_e6f5e_level0_row3" class="row_heading level0 row3" >mlp</th>
#       <td id="T_e6f5e_row3_col0" class="data row3 col0" >MLP Classifier</td>
#       <td id="T_e6f5e_row3_col1" class="data row3 col1" >0.2026</td>
#       <td id="T_e6f5e_row3_col2" class="data row3 col2" >0.5000</td>
#       <td id="T_e6f5e_row3_col3" class="data row3 col3" >0.2026</td>
#       <td id="T_e6f5e_row3_col4" class="data row3 col4" >0.0411</td>
#       <td id="T_e6f5e_row3_col5" class="data row3 col5" >0.0683</td>
#       <td id="T_e6f5e_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_e6f5e_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_e6f5e_row3_col8" class="data row3 col8" >15.4230</td>
#     </tr>
#     <tr>
#       <th id="T_e6f5e_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_e6f5e_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_e6f5e_row4_col1" class="data row4 col1" >0.2005</td>
#       <td id="T_e6f5e_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_e6f5e_row4_col3" class="data row4 col3" >0.2005</td>
#       <td id="T_e6f5e_row4_col4" class="data row4 col4" >0.0409</td>
#       <td id="T_e6f5e_row4_col5" class="data row4 col5" >0.0679</td>
#       <td id="T_e6f5e_row4_col6" class="data row4 col6" >-0.0019</td>
#       <td id="T_e6f5e_row4_col7" class="data row4 col7" >-0.0137</td>
#       <td id="T_e6f5e_row4_col8" class="data row4 col8" >109.9540</td>
#     </tr>
#     <tr>
#       <th id="T_e6f5e_level0_row5" class="row_heading level0 row5" >svm</th>
#       <td id="T_e6f5e_row5_col0" class="data row5 col0" >SVM - Linear Kernel</td>
#       <td id="T_e6f5e_row5_col1" class="data row5 col1" >0.1186</td>
#       <td id="T_e6f5e_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_e6f5e_row5_col3" class="data row5 col3" >0.1186</td>
#       <td id="T_e6f5e_row5_col4" class="data row5 col4" >0.0176</td>
#       <td id="T_e6f5e_row5_col5" class="data row5 col5" >0.0301</td>
#       <td id="T_e6f5e_row5_col6" class="data row5 col6" >-0.0000</td>
#       <td id="T_e6f5e_row5_col7" class="data row5 col7" >-0.0002</td>
#       <td id="T_e6f5e_row5_col8" class="data row5 col8" >106.4710</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Save results table
model_comparison_df = pull()
model_comparison_df.to_csv('S2_model_comparison_df.csv', index=False)

# Save best_model
save_model(model_comparison, 'S2_model_comparison')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['episode_duration',
#                                               'care_level_duration',
#                                               'no_administration_reason_ref',
#                                               'drg_mdc_ref', 'age',
#                                               'snomed_code', 'drg_ref',
#                                               'prescription_freq_ref',
#                                               'drg_weight', 'adm_drug_dose_mean',
#                                               'diag_class_ref_S',
#                                               'num_health_issues',
#                                               'cr_meas_type_ref',
#                                               'lab_result...
#                                                                missing_values=nan,
#                                                                strategy='most_frequent'))),
#                  ('trained_model',
#                   DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                          criterion='gini', max_depth=None,
#                                          max_features=None, max_leaf_nodes=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          monotonic_cst=None, random_state=123,
#                                          splitter='best'))],
#           verbose=False),
#  'S2_model_comparison.pkl')

# %% [markdown]
# ## **Best Model**
#
# Once we have compared the different models, we select the best one. Then using the ```create_model``` function we train and evaluate the performance of the model using cross-validation. By default, it uses the 10 fold.

# %%
# Model evaluation: cross validation 10 folds
decision_tree_model = create_model('dt')  
evaluate_model(decision_tree_model)
# Out:
# <style type="text/css">
# #T_fea98_row10_col0, #T_fea98_row10_col1, #T_fea98_row10_col2, #T_fea98_row10_col3, #T_fea98_row10_col4, #T_fea98_row10_col5, #T_fea98_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_fea98">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fea98_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_fea98_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_fea98_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_fea98_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_fea98_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_fea98_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_fea98_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fea98_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fea98_row0_col0" class="data row0 col0" >0.6628</td>
#       <td id="T_fea98_row0_col1" class="data row0 col1" >0.8175</td>
#       <td id="T_fea98_row0_col2" class="data row0 col2" >0.6628</td>
#       <td id="T_fea98_row0_col3" class="data row0 col3" >0.6632</td>
#       <td id="T_fea98_row0_col4" class="data row0 col4" >0.6629</td>
#       <td id="T_fea98_row0_col5" class="data row0 col5" >0.6268</td>
#       <td id="T_fea98_row0_col6" class="data row0 col6" >0.6268</td>
#     </tr>
#     <tr>
#       <th id="T_fea98_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fea98_row1_col0" class="data row1 col0" >0.6624</td>
#       <td id="T_fea98_row1_col1" class="data row1 col1" >0.8173</td>
#       <td id="T_fea98_row1_col2" class="data row1 col2" >0.6624</td>
#       <td id="T_fea98_row1_col3" class="data row1 col3" >0.6628</td>
#       <td id="T_fea98_row1_col4" class="data row1 col4" >0.6625</td>
#       <td id="T_fea98_row1_col5" class="data row1 col5" >0.6263</td>
#       <td id="T_fea98_row1_col6" class="data row1 col6" >0.6263</td>
#     </tr>
#     <tr>
#       <th id="T_fea98_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fea98_row2_col0" class="data row2 col0" >0.6615</td>
#       <td id="T_fea98_row2_col1" class="data row2 col1" >0.8171</td>
#       <td id="T_fea98_row2_col2" class="data row2 col2" >0.6615</td>
#       <td id="T_fea98_row2_col3" class="data row2 col3" >0.6613</td>
#       <td id="T_fea98_row2_col4" class="data row2 col4" >0.6614</td>
#       <td id="T_fea98_row2_col5" class="data row2 col5" >0.6253</td>
#       <td id="T_fea98_row2_col6" class="data row2 col6" >0.6253</td>
#     </tr>
#     <tr>
#       <th id="T_fea98_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fea98_row3_col0" class="data row3 col0" >0.6649</td>
#       <td id="T_fea98_row3_col1" class="data row3 col1" >0.8183</td>
#       <td id="T_fea98_row3_col2" class="data row3 col2" >0.6649</td>
#       <td id="T_fea98_row3_col3" class="data row3 col3" >0.6653</td>
#       <td id="T_fea98_row3_col4" class="data row3 col4" >0.6650</td>
#       <td id="T_fea98_row3_col5" class="data row3 col5" >0.6290</td>
#       <td id="T_fea98_row3_col6" class="data row3 col6" >0.6290</td>
#     </tr>
#     <tr>
#       <th id="T_fea98_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fea98_row4_col0" class="data row4 col0" >0.6628</td>
#       <td id="T_fea98_row4_col1" class="data row4 col1" >0.8179</td>
#       <td id="T_fea98_row4_col2" class="data row4 col2" >0.6628</td>
#       <td id="T_fea98_row4_col3" class="data row4 col3" >0.6637</td>
#       <td id="T_fea98_row4_col4" class="data row4 col4" >0.6632</td>
#       <td id="T_fea98_row4_col5" class="data row4 col5" >0.6269</td>
#       <td id="T_fea98_row4_col6" class="data row4 col6" >0.6269</td>
#     </tr>
#     <tr>
#       <th id="T_fea98_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fea98_row5_col0" class="data row5 col0" >0.6633</td>
#       <td id="T_fea98_row5_col1" class="data row5 col1" >0.8180</td>
#       <td id="T_fea98_row5_col2" class="data row5 col2" >0.6633</td>
#       <td id="T_fea98_row5_col3" class="data row5 col3" >0.6641</td>
#       <td id="T_fea98_row5_col4" class="data row5 col4" >0.6636</td>
#       <td id="T_fea98_row5_col5" class="data row5 col5" >0.6274</td>
#       <td id="T_fea98_row5_col6" class="data row5 col6" >0.6274</td>
#     </tr>
#     <tr>
#       <th id="T_fea98_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fea98_row6_col0" class="data row6 col0" >0.6619</td>
#       <td id="T_fea98_row6_col1" class="data row6 col1" >0.8168</td>
#       <td id="T_fea98_row6_col2" class="data row6 col2" >0.6619</td>
#       <td id="T_fea98_row6_col3" class="data row6 col3" >0.6623</td>
#       <td id="T_fea98_row6_col4" class="data row6 col4" >0.6621</td>
#       <td id="T_fea98_row6_col5" class="data row6 col5" >0.6257</td>
#       <td id="T_fea98_row6_col6" class="data row6 col6" >0.6257</td>
#     </tr>
#     <tr>
#       <th id="T_fea98_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fea98_row7_col0" class="data row7 col0" >0.6650</td>
#       <td id="T_fea98_row7_col1" class="data row7 col1" >0.8190</td>
#       <td id="T_fea98_row7_col2" class="data row7 col2" >0.6650</td>
#       <td id="T_fea98_row7_col3" class="data row7 col3" >0.6656</td>
#       <td id="T_fea98_row7_col4" class="data row7 col4" >0.6652</td>
#       <td id="T_fea98_row7_col5" class="data row7 col5" >0.6293</td>
#       <td id="T_fea98_row7_col6" class="data row7 col6" >0.6293</td>
#     </tr>
#     <tr>
#       <th id="T_fea98_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fea98_row8_col0" class="data row8 col0" >0.6620</td>
#       <td id="T_fea98_row8_col1" class="data row8 col1" >0.8168</td>
#       <td id="T_fea98_row8_col2" class="data row8 col2" >0.6620</td>
#       <td id="T_fea98_row8_col3" class="data row8 col3" >0.6623</td>
#       <td id="T_fea98_row8_col4" class="data row8 col4" >0.6621</td>
#       <td id="T_fea98_row8_col5" class="data row8 col5" >0.6258</td>
#       <td id="T_fea98_row8_col6" class="data row8 col6" >0.6258</td>
#     </tr>
#     <tr>
#       <th id="T_fea98_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fea98_row9_col0" class="data row9 col0" >0.6608</td>
#       <td id="T_fea98_row9_col1" class="data row9 col1" >0.8164</td>
#       <td id="T_fea98_row9_col2" class="data row9 col2" >0.6608</td>
#       <td id="T_fea98_row9_col3" class="data row9 col3" >0.6616</td>
#       <td id="T_fea98_row9_col4" class="data row9 col4" >0.6612</td>
#       <td id="T_fea98_row9_col5" class="data row9 col5" >0.6247</td>
#       <td id="T_fea98_row9_col6" class="data row9 col6" >0.6247</td>
#     </tr>
#     <tr>
#       <th id="T_fea98_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_fea98_row10_col0" class="data row10 col0" >0.6627</td>
#       <td id="T_fea98_row10_col1" class="data row10 col1" >0.8175</td>
#       <td id="T_fea98_row10_col2" class="data row10 col2" >0.6627</td>
#       <td id="T_fea98_row10_col3" class="data row10 col3" >0.6632</td>
#       <td id="T_fea98_row10_col4" class="data row10 col4" >0.6629</td>
#       <td id="T_fea98_row10_col5" class="data row10 col5" >0.6267</td>
#       <td id="T_fea98_row10_col6" class="data row10 col6" >0.6267</td>
#     </tr>
#     <tr>
#       <th id="T_fea98_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_fea98_row11_col0" class="data row11 col0" >0.0013</td>
#       <td id="T_fea98_row11_col1" class="data row11 col1" >0.0008</td>
#       <td id="T_fea98_row11_col2" class="data row11 col2" >0.0013</td>
#       <td id="T_fea98_row11_col3" class="data row11 col3" >0.0014</td>
#       <td id="T_fea98_row11_col4
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# Save model
save_model(decision_tree_model, 'S2_best_model_dt')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['episode_duration',
#                                               'care_level_duration',
#                                               'no_administration_reason_ref',
#                                               'drg_mdc_ref', 'age',
#                                               'snomed_code', 'drg_ref',
#                                               'prescription_freq_ref',
#                                               'drg_weight', 'adm_drug_dose_mean',
#                                               'diag_class_ref_S',
#                                               'num_health_issues',
#                                               'cr_meas_type_ref',
#                                               'lab_result...
#                                                                missing_values=nan,
#                                                                strategy='most_frequent'))),
#                  ('trained_model',
#                   DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                          criterion='gini', max_depth=None,
#                                          max_features=None, max_leaf_nodes=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          monotonic_cst=None, random_state=123,
#                                          splitter='best'))],
#           verbose=False),
#  'S2_best_model_dt.pkl')

# %%
# Load model
decision_tree_model = load_model("C:/Users/Cindy Chen/Desktop/TFG/plots/04/S2/S2_best_model_dt")
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# ## **Optimize and Tune Model**
#
# The ```tune_model``` function tunes the hyperparameters of the model. The output of this function is a scoring grid with cross-validated scores by fold.
#
# By default, it uses RandomGridSearch from the sklearn and the number of iterations (n_iter) is set to 10.

# %%
# Optimize and tune model using Random Grid Search 
decision_tree_model_tuned = tune_model(decision_tree_model)
# Out:
# <style type="text/css">
# #T_42fa8_row10_col0, #T_42fa8_row10_col1, #T_42fa8_row10_col2, #T_42fa8_row10_col3, #T_42fa8_row10_col4, #T_42fa8_row10_col5, #T_42fa8_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_42fa8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42fa8_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_42fa8_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_42fa8_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_42fa8_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_42fa8_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_42fa8_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_42fa8_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42fa8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_42fa8_row0_col0" class="data row0 col0" >0.4090</td>
#       <td id="T_42fa8_row0_col1" class="data row0 col1" >0.8962</td>
#       <td id="T_42fa8_row0_col2" class="data row0 col2" >0.4090</td>
#       <td id="T_42fa8_row0_col3" class="data row0 col3" >0.4283</td>
#       <td id="T_42fa8_row0_col4" class="data row0 col4" >0.4139</td>
#       <td id="T_42fa8_row0_col5" class="data row0 col5" >0.3511</td>
#       <td id="T_42fa8_row0_col6" class="data row0 col6" >0.3520</td>
#     </tr>
#     <tr>
#       <th id="T_42fa8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_42fa8_row1_col0" class="data row1 col0" >0.4067</td>
#       <td id="T_42fa8_row1_col1" class="data row1 col1" >0.8932</td>
#       <td id="T_42fa8_row1_col2" class="data row1 col2" >0.4067</td>
#       <td id="T_42fa8_row1_col3" class="data row1 col3" >0.4064</td>
#       <td id="T_42fa8_row1_col4" class="data row1 col4" >0.4055</td>
#       <td id="T_42fa8_row1_col5" class="data row1 col5" >0.3420</td>
#       <td id="T_42fa8_row1_col6" class="data row1 col6" >0.3421</td>
#     </tr>
#     <tr>
#       <th id="T_42fa8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_42fa8_row2_col0" class="data row2 col0" >0.4111</td>
#       <td id="T_42fa8_row2_col1" class="data row2 col1" >0.8975</td>
#       <td id="T_42fa8_row2_col2" class="data row2 col2" >0.4111</td>
#       <td id="T_42fa8_row2_col3" class="data row2 col3" >0.4159</td>
#       <td id="T_42fa8_row2_col4" class="data row2 col4" >0.4128</td>
#       <td id="T_42fa8_row2_col5" class="data row2 col5" >0.3500</td>
#       <td id="T_42fa8_row2_col6" class="data row2 col6" >0.3501</td>
#     </tr>
#     <tr>
#       <th id="T_42fa8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_42fa8_row3_col0" class="data row3 col0" >0.4042</td>
#       <td id="T_42fa8_row3_col1" class="data row3 col1" >0.8945</td>
#       <td id="T_42fa8_row3_col2" class="data row3 col2" >0.4042</td>
#       <td id="T_42fa8_row3_col3" class="data row3 col3" >0.4191</td>
#       <td id="T_42fa8_row3_col4" class="data row3 col4" >0.4101</td>
#       <td id="T_42fa8_row3_col5" class="data row3 col5" >0.3424</td>
#       <td id="T_42fa8_row3_col6" class="data row3 col6" >0.3427</td>
#     </tr>
#     <tr>
#       <th id="T_42fa8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_42fa8_row4_col0" class="data row4 col0" >0.4031</td>
#       <td id="T_42fa8_row4_col1" class="data row4 col1" >0.8930</td>
#       <td id="T_42fa8_row4_col2" class="data row4 col2" >0.4031</td>
#       <td id="T_42fa8_row4_col3" class="data row4 col3" >0.4126</td>
#       <td id="T_42fa8_row4_col4" class="data row4 col4" >0.4017</td>
#       <td id="T_42fa8_row4_col5" class="data row4 col5" >0.3383</td>
#       <td id="T_42fa8_row4_col6" class="data row4 col6" >0.3392</td>
#     </tr>
#     <tr>
#       <th id="T_42fa8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_42fa8_row5_col0" class="data row5 col0" >0.4018</td>
#       <td id="T_42fa8_row5_col1" class="data row5 col1" >0.8943</td>
#       <td id="T_42fa8_row5_col2" class="data row5 col2" >0.4018</td>
#       <td id="T_42fa8_row5_col3" class="data row5 col3" >0.3994</td>
#       <td id="T_42fa8_row5_col4" class="data row5 col4" >0.3989</td>
#       <td id="T_42fa8_row5_col5" class="data row5 col5" >0.3368</td>
#       <td id="T_42fa8_row5_col6" class="data row5 col6" >0.3371</td>
#     </tr>
#     <tr>
#       <th id="T_42fa8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_42fa8_row6_col0" class="data row6 col0" >0.4015</td>
#       <td id="T_42fa8_row6_col1" class="data row6 col1" >0.8906</td>
#       <td id="T_42fa8_row6_col2" class="data row6 col2" >0.4015</td>
#       <td id="T_42fa8_row6_col3" class="data row6 col3" >0.4057</td>
#       <td id="T_42fa8_row6_col4" class="data row6 col4" >0.4019</td>
#       <td id="T_42fa8_row6_col5" class="data row6 col5" >0.3378</td>
#       <td id="T_42fa8_row6_col6" class="data row6 col6" >0.3380</td>
#     </tr>
#     <tr>
#       <th id="T_42fa8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_42fa8_row7_col0" class="data row7 col0" >0.4052</td>
#       <td id="T_42fa8_row7_col1" class="data row7 col1" >0.8919</td>
#       <td id="T_42fa8_row7_col2" class="data row7 col2" >0.4052</td>
#       <td id="T_42fa8_row7_col3" class="data row7 col3" >0.4027</td>
#       <td id="T_42fa8_row7_col4" class="data row7 col4" >0.4027</td>
#       <td id="T_42fa8_row7_col5" class="data row7 col5" >0.3404</td>
#       <td id="T_42fa8_row7_col6" class="data row7 col6" >0.3405</td>
#     </tr>
#     <tr>
#       <th id="T_42fa8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_42fa8_row8_col0" class="data row8 col0" >0.4130</td>
#       <td id="T_42fa8_row8_col1" class="data row8 col1" >0.8949</td>
#       <td id="T_42fa8_row8_col2" class="data row8 col2" >0.4130</td>
#       <td id="T_42fa8_row8_col3" class="data row8 col3" >0.4262</td>
#       <td id="T_42fa8_row8_col4" class="data row8 col4" >0.4173</td>
#       <td id="T_42fa8_row8_col5" class="data row8 col5" >0.3525</td>
#       <td id="T_42fa8_row8_col6" class="data row8 col6" >0.3528</td>
#     </tr>
#     <tr>
#       <th id="T_42fa8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_42fa8_row9_col0" class="data row9 col0" >0.4023</td>
#       <td id="T_42fa8_row9_col1" class="data row9 col1" >0.8935</td>
#       <td id="T_42fa8_row9_col2" class="data row9 col2" >0.4023</td>
#       <td id="T_42fa8_row9_col3" class="data row9 col3" >0.3984</td>
#       <td id="T_42fa8_row9_col4" class="data row9 col4" >0.3971</td>
#       <td id="T_42fa8_row9_col5" class="data row9 col5" >0.3347</td>
#       <td id="T_42fa8_row9_col6" class="data row9 col6" >0.3351</td>
#     </tr>
#     <tr>
#       <th id="T_42fa8_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_42fa8_row10_col0" class="data row10 col0" >0.4058</td>
#       <td id="T_42fa8_row10_col1" class="data row10 col1" >0.8940</td>
#       <td id="T_42fa8_row10_col2" class="data row10 col2" >0.4058</td>
#       <td id="T_42fa8_row10_col3" class="data row10 col3" >0.4115</td>
#       <td id="T_42fa8_row10_col4" class="data row10 col4" >0.4062</td>
#       <td id="T_42fa8_row10_col5" class="data row10 col5" >0.3426</td>
#       <td id="T_42fa8_row10_col6" class="data row10 col6" >0.3430</td>
#     </tr>
#     <tr>
#       <th id="T_42fa8_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_42fa8_row11_col0" class="data row11 col0" >0.0038</td>
#       <td id="T_42fa8_row11_col1" class="data row11 col1" >0.0019</td>
#       <td id="T_42fa8_row11_col2" class="data row11 col2" >0.0038</td>
#       <td id="T_42fa8_row11_col3" class="data row11 col3" >0.0102</td>
#       <td id="T_42fa8_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# As we can see, the Random Grid Search didn't obtain better results than the original model, so let's try increasing the number of iterations to 100.

# %%
# Optimize and tune model using Random Grid Search and increasing the number of iterations
decision_tree_model_tuned = tune_model(decision_tree_model, n_iter=100) # chose_better=False
# Out:
# <style type="text/css">
# #T_793a5_row10_col0, #T_793a5_row10_col1, #T_793a5_row10_col2, #T_793a5_row10_col3, #T_793a5_row10_col4, #T_793a5_row10_col5, #T_793a5_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_793a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_793a5_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_793a5_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_793a5_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_793a5_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_793a5_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_793a5_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_793a5_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_793a5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_793a5_row0_col0" class="data row0 col0" >0.4555</td>
#       <td id="T_793a5_row0_col1" class="data row0 col1" >0.9092</td>
#       <td id="T_793a5_row0_col2" class="data row0 col2" >0.4555</td>
#       <td id="T_793a5_row0_col3" class="data row0 col3" >0.4583</td>
#       <td id="T_793a5_row0_col4" class="data row0 col4" >0.4562</td>
#       <td id="T_793a5_row0_col5" class="data row0 col5" >0.3990</td>
#       <td id="T_793a5_row0_col6" class="data row0 col6" >0.3991</td>
#     </tr>
#     <tr>
#       <th id="T_793a5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_793a5_row1_col0" class="data row1 col0" >0.4541</td>
#       <td id="T_793a5_row1_col1" class="data row1 col1" >0.9090</td>
#       <td id="T_793a5_row1_col2" class="data row1 col2" >0.4541</td>
#       <td id="T_793a5_row1_col3" class="data row1 col3" >0.4591</td>
#       <td id="T_793a5_row1_col4" class="data row1 col4" >0.4548</td>
#       <td id="T_793a5_row1_col5" class="data row1 col5" >0.3974</td>
#       <td id="T_793a5_row1_col6" class="data row1 col6" >0.3976</td>
#     </tr>
#     <tr>
#       <th id="T_793a5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_793a5_row2_col0" class="data row2 col0" >0.4539</td>
#       <td id="T_793a5_row2_col1" class="data row2 col1" >0.9098</td>
#       <td id="T_793a5_row2_col2" class="data row2 col2" >0.4539</td>
#       <td id="T_793a5_row2_col3" class="data row2 col3" >0.4592</td>
#       <td id="T_793a5_row2_col4" class="data row2 col4" >0.4556</td>
#       <td id="T_793a5_row2_col5" class="data row2 col5" >0.3966</td>
#       <td id="T_793a5_row2_col6" class="data row2 col6" >0.3967</td>
#     </tr>
#     <tr>
#       <th id="T_793a5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_793a5_row3_col0" class="data row3 col0" >0.4581</td>
#       <td id="T_793a5_row3_col1" class="data row3 col1" >0.9106</td>
#       <td id="T_793a5_row3_col2" class="data row3 col2" >0.4581</td>
#       <td id="T_793a5_row3_col3" class="data row3 col3" >0.4609</td>
#       <td id="T_793a5_row3_col4" class="data row3 col4" >0.4591</td>
#       <td id="T_793a5_row3_col5" class="data row3 col5" >0.4009</td>
#       <td id="T_793a5_row3_col6" class="data row3 col6" >0.4010</td>
#     </tr>
#     <tr>
#       <th id="T_793a5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_793a5_row4_col0" class="data row4 col0" >0.4528</td>
#       <td id="T_793a5_row4_col1" class="data row4 col1" >0.9094</td>
#       <td id="T_793a5_row4_col2" class="data row4 col2" >0.4528</td>
#       <td id="T_793a5_row4_col3" class="data row4 col3" >0.4620</td>
#       <td id="T_793a5_row4_col4" class="data row4 col4" >0.4564</td>
#       <td id="T_793a5_row4_col5" class="data row4 col5" >0.3964</td>
#       <td id="T_793a5_row4_col6" class="data row4 col6" >0.3966</td>
#     </tr>
#     <tr>
#       <th id="T_793a5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_793a5_row5_col0" class="data row5 col0" >0.4530</td>
#       <td id="T_793a5_row5_col1" class="data row5 col1" >0.9087</td>
#       <td id="T_793a5_row5_col2" class="data row5 col2" >0.4530</td>
#       <td id="T_793a5_row5_col3" class="data row5 col3" >0.4574</td>
#       <td id="T_793a5_row5_col4" class="data row5 col4" >0.4542</td>
#       <td id="T_793a5_row5_col5" class="data row5 col5" >0.3963</td>
#       <td id="T_793a5_row5_col6" class="data row5 col6" >0.3964</td>
#     </tr>
#     <tr>
#       <th id="T_793a5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_793a5_row6_col0" class="data row6 col0" >0.4530</td>
#       <td id="T_793a5_row6_col1" class="data row6 col1" >0.9086</td>
#       <td id="T_793a5_row6_col2" class="data row6 col2" >0.4530</td>
#       <td id="T_793a5_row6_col3" class="data row6 col3" >0.4531</td>
#       <td id="T_793a5_row6_col4" class="data row6 col4" >0.4522</td>
#       <td id="T_793a5_row6_col5" class="data row6 col5" >0.3954</td>
#       <td id="T_793a5_row6_col6" class="data row6 col6" >0.3955</td>
#     </tr>
#     <tr>
#       <th id="T_793a5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_793a5_row7_col0" class="data row7 col0" >0.4540</td>
#       <td id="T_793a5_row7_col1" class="data row7 col1" >0.9100</td>
#       <td id="T_793a5_row7_col2" class="data row7 col2" >0.4540</td>
#       <td id="T_793a5_row7_col3" class="data row7 col3" >0.4566</td>
#       <td id="T_793a5_row7_col4" class="data row7 col4" >0.4546</td>
#       <td id="T_793a5_row7_col5" class="data row7 col5" >0.3965</td>
#       <td id="T_793a5_row7_col6" class="data row7 col6" >0.3967</td>
#     </tr>
#     <tr>
#       <th id="T_793a5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_793a5_row8_col0" class="data row8 col0" >0.4536</td>
#       <td id="T_793a5_row8_col1" class="data row8 col1" >0.9083</td>
#       <td id="T_793a5_row8_col2" class="data row8 col2" >0.4536</td>
#       <td id="T_793a5_row8_col3" class="data row8 col3" >0.4578</td>
#       <td id="T_793a5_row8_col4" class="data row8 col4" >0.4550</td>
#       <td id="T_793a5_row8_col5" class="data row8 col5" >0.3968</td>
#       <td id="T_793a5_row8_col6" class="data row8 col6" >0.3969</td>
#     </tr>
#     <tr>
#       <th id="T_793a5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_793a5_row9_col0" class="data row9 col0" >0.4539</td>
#       <td id="T_793a5_row9_col1" class="data row9 col1" >0.9086</td>
#       <td id="T_793a5_row9_col2" class="data row9 col2" >0.4539</td>
#       <td id="T_793a5_row9_col3" class="data row9 col3" >0.4537</td>
#       <td id="T_793a5_row9_col4" class="data row9 col4" >0.4534</td>
#       <td id="T_793a5_row9_col5" class="data row9 col5" >0.3963</td>
#       <td id="T_793a5_row9_col6" class="data row9 col6" >0.3963</td>
#     </tr>
#     <tr>
#       <th id="T_793a5_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_793a5_row10_col0" class="data row10 col0" >0.4542</td>
#       <td id="T_793a5_row10_col1" class="data row10 col1" >0.9092</td>
#       <td id="T_793a5_row10_col2" class="data row10 col2" >0.4542</td>
#       <td id="T_793a5_row10_col3" class="data row10 col3" >0.4578</td>
#       <td id="T_793a5_row10_col4" class="data row10 col4" >0.4551</td>
#       <td id="T_793a5_row10_col5" class="data row10 col5" >0.3972</td>
#       <td id="T_793a5_row10_col6" class="data row10 col6" >0.3973</td>
#     </tr>
#     <tr>
#       <th id="T_793a5_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_793a5_row11_col0" class="data row11 col0" >0.0015</td>
#       <td id="T_793a5_row11_col1" class="data row11 col1" >0.0007</td>
#       <td id="T_793a5_row11_col2" class="data row11 col2" >0.0015</td>
#       <td id="T_793a5_row11_col3" class="data row11 col3" >0.0027</td>
#       <td id="T_793a5_row11_col4
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# Even when we increase the number of iterations the model doesn't improve. So let's customise the grid and parameters using custom_grid.
#
# For decision trees, the hyperparameters decided to use are:
# - max_depth
# - min_samples_split
# - min_samples_leaf
# - criterion

# %%
# Optimize and tune model using custom grid and Random Grid Search
params = {'max_depth': [None, 3, 5, 10, 15],
          'min_samples_split': [2, 5, 10],
          'min_samples_leaf': [1, 2, 5],
          'criterion': ['gini', 'entropy', 'log_loss']
} 

decision_tree_model_tuned = tune_model(decision_tree_model, custom_grid=params) # chose_better=False
# Out:
# <style type="text/css">
# #T_5803d_row10_col0, #T_5803d_row10_col1, #T_5803d_row10_col2, #T_5803d_row10_col3, #T_5803d_row10_col4, #T_5803d_row10_col5, #T_5803d_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_5803d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5803d_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_5803d_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_5803d_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_5803d_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_5803d_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_5803d_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_5803d_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5803d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5803d_row0_col0" class="data row0 col0" >0.6685</td>
#       <td id="T_5803d_row0_col1" class="data row0 col1" >0.8207</td>
#       <td id="T_5803d_row0_col2" class="data row0 col2" >0.6685</td>
#       <td id="T_5803d_row0_col3" class="data row0 col3" >0.6691</td>
#       <td id="T_5803d_row0_col4" class="data row0 col4" >0.6687</td>
#       <td id="T_5803d_row0_col5" class="data row0 col5" >0.6331</td>
#       <td id="T_5803d_row0_col6" class="data row0 col6" >0.6331</td>
#     </tr>
#     <tr>
#       <th id="T_5803d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5803d_row1_col0" class="data row1 col0" >0.6712</td>
#       <td id="T_5803d_row1_col1" class="data row1 col1" >0.8223</td>
#       <td id="T_5803d_row1_col2" class="data row1 col2" >0.6712</td>
#       <td id="T_5803d_row1_col3" class="data row1 col3" >0.6717</td>
#       <td id="T_5803d_row1_col4" class="data row1 col4" >0.6714</td>
#       <td id="T_5803d_row1_col5" class="data row1 col5" >0.6360</td>
#       <td id="T_5803d_row1_col6" class="data row1 col6" >0.6361</td>
#     </tr>
#     <tr>
#       <th id="T_5803d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5803d_row2_col0" class="data row2 col0" >0.6697</td>
#       <td id="T_5803d_row2_col1" class="data row2 col1" >0.8216</td>
#       <td id="T_5803d_row2_col2" class="data row2 col2" >0.6697</td>
#       <td id="T_5803d_row2_col3" class="data row2 col3" >0.6695</td>
#       <td id="T_5803d_row2_col4" class="data row2 col4" >0.6696</td>
#       <td id="T_5803d_row2_col5" class="data row2 col5" >0.6344</td>
#       <td id="T_5803d_row2_col6" class="data row2 col6" >0.6344</td>
#     </tr>
#     <tr>
#       <th id="T_5803d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5803d_row3_col0" class="data row3 col0" >0.6715</td>
#       <td id="T_5803d_row3_col1" class="data row3 col1" >0.8222</td>
#       <td id="T_5803d_row3_col2" class="data row3 col2" >0.6715</td>
#       <td id="T_5803d_row3_col3" class="data row3 col3" >0.6719</td>
#       <td id="T_5803d_row3_col4" class="data row3 col4" >0.6716</td>
#       <td id="T_5803d_row3_col5" class="data row3 col5" >0.6364</td>
#       <td id="T_5803d_row3_col6" class="data row3 col6" >0.6364</td>
#     </tr>
#     <tr>
#       <th id="T_5803d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5803d_row4_col0" class="data row4 col0" >0.6699</td>
#       <td id="T_5803d_row4_col1" class="data row4 col1" >0.8215</td>
#       <td id="T_5803d_row4_col2" class="data row4 col2" >0.6699</td>
#       <td id="T_5803d_row4_col3" class="data row4 col3" >0.6705</td>
#       <td id="T_5803d_row4_col4" class="data row4 col4" >0.6701</td>
#       <td id="T_5803d_row4_col5" class="data row4 col5" >0.6345</td>
#       <td id="T_5803d_row4_col6" class="data row4 col6" >0.6345</td>
#     </tr>
#     <tr>
#       <th id="T_5803d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5803d_row5_col0" class="data row5 col0" >0.6711</td>
#       <td id="T_5803d_row5_col1" class="data row5 col1" >0.8223</td>
#       <td id="T_5803d_row5_col2" class="data row5 col2" >0.6711</td>
#       <td id="T_5803d_row5_col3" class="data row5 col3" >0.6717</td>
#       <td id="T_5803d_row5_col4" class="data row5 col4" >0.6713</td>
#       <td id="T_5803d_row5_col5" class="data row5 col5" >0.6360</td>
#       <td id="T_5803d_row5_col6" class="data row5 col6" >0.6360</td>
#     </tr>
#     <tr>
#       <th id="T_5803d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5803d_row6_col0" class="data row6 col0" >0.6683</td>
#       <td id="T_5803d_row6_col1" class="data row6 col1" >0.8205</td>
#       <td id="T_5803d_row6_col2" class="data row6 col2" >0.6683</td>
#       <td id="T_5803d_row6_col3" class="data row6 col3" >0.6685</td>
#       <td id="T_5803d_row6_col4" class="data row6 col4" >0.6684</td>
#       <td id="T_5803d_row6_col5" class="data row6 col5" >0.6329</td>
#       <td id="T_5803d_row6_col6" class="data row6 col6" >0.6329</td>
#     </tr>
#     <tr>
#       <th id="T_5803d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5803d_row7_col0" class="data row7 col0" >0.6707</td>
#       <td id="T_5803d_row7_col1" class="data row7 col1" >0.8222</td>
#       <td id="T_5803d_row7_col2" class="data row7 col2" >0.6707</td>
#       <td id="T_5803d_row7_col3" class="data row7 col3" >0.6711</td>
#       <td id="T_5803d_row7_col4" class="data row7 col4" >0.6708</td>
#       <td id="T_5803d_row7_col5" class="data row7 col5" >0.6356</td>
#       <td id="T_5803d_row7_col6" class="data row7 col6" >0.6356</td>
#     </tr>
#     <tr>
#       <th id="T_5803d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5803d_row8_col0" class="data row8 col0" >0.6673</td>
#       <td id="T_5803d_row8_col1" class="data row8 col1" >0.8202</td>
#       <td id="T_5803d_row8_col2" class="data row8 col2" >0.6673</td>
#       <td id="T_5803d_row8_col3" class="data row8 col3" >0.6680</td>
#       <td id="T_5803d_row8_col4" class="data row8 col4" >0.6676</td>
#       <td id="T_5803d_row8_col5" class="data row8 col5" >0.6318</td>
#       <td id="T_5803d_row8_col6" class="data row8 col6" >0.6318</td>
#     </tr>
#     <tr>
#       <th id="T_5803d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5803d_row9_col0" class="data row9 col0" >0.6655</td>
#       <td id="T_5803d_row9_col1" class="data row9 col1" >0.8191</td>
#       <td id="T_5803d_row9_col2" class="data row9 col2" >0.6655</td>
#       <td id="T_5803d_row9_col3" class="data row9 col3" >0.6666</td>
#       <td id="T_5803d_row9_col4" class="data row9 col4" >0.6660</td>
#       <td id="T_5803d_row9_col5" class="data row9 col5" >0.6299</td>
#       <td id="T_5803d_row9_col6" class="data row9 col6" >0.6299</td>
#     </tr>
#     <tr>
#       <th id="T_5803d_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_5803d_row10_col0" class="data row10 col0" >0.6694</td>
#       <td id="T_5803d_row10_col1" class="data row10 col1" >0.8213</td>
#       <td id="T_5803d_row10_col2" class="data row10 col2" >0.6694</td>
#       <td id="T_5803d_row10_col3" class="data row10 col3" >0.6699</td>
#       <td id="T_5803d_row10_col4" class="data row10 col4" >0.6696</td>
#       <td id="T_5803d_row10_col5" class="data row10 col5" >0.6341</td>
#       <td id="T_5803d_row10_col6" class="data row10 col6" >0.6341</td>
#     </tr>
#     <tr>
#       <th id="T_5803d_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_5803d_row11_col0" class="data row11 col0" >0.0018</td>
#       <td id="T_5803d_row11_col1" class="data row11 col1" >0.0010</td>
#       <td id="T_5803d_row11_col2" class="data row11 col2" >0.0018</td>
#       <td id="T_5803d_row11_col3" class="data row11 col3" >0.0017</td>
#       <td id="T_5803d_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
# Optimize and tune model using custom grid and GridSearchCV
params = {'max_depth': [None, 3, 5, 10, 15],
          'min_samples_split': [2, 5, 10],
          'min_samples_leaf': [1, 2, 5],
          'criterion': ['gini', 'entropy', 'log_loss']
}

decision_tree_model_tuned = tune_model(decision_tree_model, custom_grid=params, search_library='scikit-learn', search_algorithm='grid')
# Out:
# <style type="text/css">
# #T_69ae6_row10_col0, #T_69ae6_row10_col1, #T_69ae6_row10_col2, #T_69ae6_row10_col3, #T_69ae6_row10_col4, #T_69ae6_row10_col5, #T_69ae6_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_69ae6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69ae6_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_69ae6_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_69ae6_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_69ae6_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_69ae6_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_69ae6_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_69ae6_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69ae6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69ae6_row0_col0" class="data row0 col0" >0.6685</td>
#       <td id="T_69ae6_row0_col1" class="data row0 col1" >0.8207</td>
#       <td id="T_69ae6_row0_col2" class="data row0 col2" >0.6685</td>
#       <td id="T_69ae6_row0_col3" class="data row0 col3" >0.6691</td>
#       <td id="T_69ae6_row0_col4" class="data row0 col4" >0.6687</td>
#       <td id="T_69ae6_row0_col5" class="data row0 col5" >0.6331</td>
#       <td id="T_69ae6_row0_col6" class="data row0 col6" >0.6331</td>
#     </tr>
#     <tr>
#       <th id="T_69ae6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_69ae6_row1_col0" class="data row1 col0" >0.6712</td>
#       <td id="T_69ae6_row1_col1" class="data row1 col1" >0.8223</td>
#       <td id="T_69ae6_row1_col2" class="data row1 col2" >0.6712</td>
#       <td id="T_69ae6_row1_col3" class="data row1 col3" >0.6717</td>
#       <td id="T_69ae6_row1_col4" class="data row1 col4" >0.6714</td>
#       <td id="T_69ae6_row1_col5" class="data row1 col5" >0.6360</td>
#       <td id="T_69ae6_row1_col6" class="data row1 col6" >0.6361</td>
#     </tr>
#     <tr>
#       <th id="T_69ae6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_69ae6_row2_col0" class="data row2 col0" >0.6697</td>
#       <td id="T_69ae6_row2_col1" class="data row2 col1" >0.8216</td>
#       <td id="T_69ae6_row2_col2" class="data row2 col2" >0.6697</td>
#       <td id="T_69ae6_row2_col3" class="data row2 col3" >0.6695</td>
#       <td id="T_69ae6_row2_col4" class="data row2 col4" >0.6696</td>
#       <td id="T_69ae6_row2_col5" class="data row2 col5" >0.6344</td>
#       <td id="T_69ae6_row2_col6" class="data row2 col6" >0.6344</td>
#     </tr>
#     <tr>
#       <th id="T_69ae6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_69ae6_row3_col0" class="data row3 col0" >0.6715</td>
#       <td id="T_69ae6_row3_col1" class="data row3 col1" >0.8222</td>
#       <td id="T_69ae6_row3_col2" class="data row3 col2" >0.6715</td>
#       <td id="T_69ae6_row3_col3" class="data row3 col3" >0.6719</td>
#       <td id="T_69ae6_row3_col4" class="data row3 col4" >0.6716</td>
#       <td id="T_69ae6_row3_col5" class="data row3 col5" >0.6364</td>
#       <td id="T_69ae6_row3_col6" class="data row3 col6" >0.6364</td>
#     </tr>
#     <tr>
#       <th id="T_69ae6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_69ae6_row4_col0" class="data row4 col0" >0.6699</td>
#       <td id="T_69ae6_row4_col1" class="data row4 col1" >0.8215</td>
#       <td id="T_69ae6_row4_col2" class="data row4 col2" >0.6699</td>
#       <td id="T_69ae6_row4_col3" class="data row4 col3" >0.6705</td>
#       <td id="T_69ae6_row4_col4" class="data row4 col4" >0.6701</td>
#       <td id="T_69ae6_row4_col5" class="data row4 col5" >0.6345</td>
#       <td id="T_69ae6_row4_col6" class="data row4 col6" >0.6345</td>
#     </tr>
#     <tr>
#       <th id="T_69ae6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_69ae6_row5_col0" class="data row5 col0" >0.6711</td>
#       <td id="T_69ae6_row5_col1" class="data row5 col1" >0.8223</td>
#       <td id="T_69ae6_row5_col2" class="data row5 col2" >0.6711</td>
#       <td id="T_69ae6_row5_col3" class="data row5 col3" >0.6717</td>
#       <td id="T_69ae6_row5_col4" class="data row5 col4" >0.6713</td>
#       <td id="T_69ae6_row5_col5" class="data row5 col5" >0.6360</td>
#       <td id="T_69ae6_row5_col6" class="data row5 col6" >0.6360</td>
#     </tr>
#     <tr>
#       <th id="T_69ae6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_69ae6_row6_col0" class="data row6 col0" >0.6683</td>
#       <td id="T_69ae6_row6_col1" class="data row6 col1" >0.8205</td>
#       <td id="T_69ae6_row6_col2" class="data row6 col2" >0.6683</td>
#       <td id="T_69ae6_row6_col3" class="data row6 col3" >0.6685</td>
#       <td id="T_69ae6_row6_col4" class="data row6 col4" >0.6684</td>
#       <td id="T_69ae6_row6_col5" class="data row6 col5" >0.6329</td>
#       <td id="T_69ae6_row6_col6" class="data row6 col6" >0.6329</td>
#     </tr>
#     <tr>
#       <th id="T_69ae6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_69ae6_row7_col0" class="data row7 col0" >0.6707</td>
#       <td id="T_69ae6_row7_col1" class="data row7 col1" >0.8222</td>
#       <td id="T_69ae6_row7_col2" class="data row7 col2" >0.6707</td>
#       <td id="T_69ae6_row7_col3" class="data row7 col3" >0.6711</td>
#       <td id="T_69ae6_row7_col4" class="data row7 col4" >0.6708</td>
#       <td id="T_69ae6_row7_col5" class="data row7 col5" >0.6356</td>
#       <td id="T_69ae6_row7_col6" class="data row7 col6" >0.6356</td>
#     </tr>
#     <tr>
#       <th id="T_69ae6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_69ae6_row8_col0" class="data row8 col0" >0.6673</td>
#       <td id="T_69ae6_row8_col1" class="data row8 col1" >0.8202</td>
#       <td id="T_69ae6_row8_col2" class="data row8 col2" >0.6673</td>
#       <td id="T_69ae6_row8_col3" class="data row8 col3" >0.6680</td>
#       <td id="T_69ae6_row8_col4" class="data row8 col4" >0.6676</td>
#       <td id="T_69ae6_row8_col5" class="data row8 col5" >0.6318</td>
#       <td id="T_69ae6_row8_col6" class="data row8 col6" >0.6318</td>
#     </tr>
#     <tr>
#       <th id="T_69ae6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_69ae6_row9_col0" class="data row9 col0" >0.6655</td>
#       <td id="T_69ae6_row9_col1" class="data row9 col1" >0.8191</td>
#       <td id="T_69ae6_row9_col2" class="data row9 col2" >0.6655</td>
#       <td id="T_69ae6_row9_col3" class="data row9 col3" >0.6666</td>
#       <td id="T_69ae6_row9_col4" class="data row9 col4" >0.6660</td>
#       <td id="T_69ae6_row9_col5" class="data row9 col5" >0.6299</td>
#       <td id="T_69ae6_row9_col6" class="data row9 col6" >0.6299</td>
#     </tr>
#     <tr>
#       <th id="T_69ae6_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_69ae6_row10_col0" class="data row10 col0" >0.6694</td>
#       <td id="T_69ae6_row10_col1" class="data row10 col1" >0.8213</td>
#       <td id="T_69ae6_row10_col2" class="data row10 col2" >0.6694</td>
#       <td id="T_69ae6_row10_col3" class="data row10 col3" >0.6699</td>
#       <td id="T_69ae6_row10_col4" class="data row10 col4" >0.6696</td>
#       <td id="T_69ae6_row10_col5" class="data row10 col5" >0.6341</td>
#       <td id="T_69ae6_row10_col6" class="data row10 col6" >0.6341</td>
#     </tr>
#     <tr>
#       <th id="T_69ae6_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_69ae6_row11_col0" class="data row11 col0" >0.0018</td>
#       <td id="T_69ae6_row11_col1" class="data row11 col1" >0.0010</td>
#       <td id="T_69ae6_row11_col2" class="data row11 col2" >0.0018</td>
#       <td id="T_69ae6_row11_col3" class="data row11 col3" >0.0017</td>
#       <td id="T_69ae6_row11_col4
# Fitting 10 folds for each of 135 candidates, totalling 1350 fits

# %% [markdown]
# As we can see, the model improved all the metrics except AUC quite a bit.

# %%
# Save tuned model
save_model(decision_tree_model_tuned, 'S2_best_model_dt_tuned')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['episode_duration',
#                                               'care_level_duration',
#                                               'no_administration_reason_ref',
#                                               'drg_mdc_ref', 'age',
#                                               'snomed_code', 'drg_ref',
#                                               'prescription_freq_ref',
#                                               'drg_weight', 'adm_drug_dose_mean',
#                                               'diag_class_ref_S',
#                                               'num_health_issues',
#                                               'cr_meas_type_ref',
#                                               'lab_result...
#                                                                missing_values=nan,
#                                                                strategy='most_frequent'))),
#                  ('trained_model',
#                   DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                          criterion='log_loss', max_depth=None,
#                                          max_features=None, max_leaf_nodes=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          monotonic_cst=None, random_state=123,
#                                          splitter='best'))],
#           verbose=False),
#  'S2_best_model_dt_tuned.pkl')

# %%
# Load tuned model
decision_tree_model_tuned = load_model("C:/Users/Cindy Chen/Desktop/TFG/plots/04/S2/S2_best_model_dt_tuned")
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
# Hyperparameters before tunning
print(decision_tree_model)
# Out:
# Pipeline(memory=FastMemory(location=C:\Users\CINDYC~1\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['episode_duration',
#                                              'care_level_duration',
#                                              'no_administration_reason_ref',
#                                              'drg_mdc_ref', 'age',
#                                              'snomed_code', 'drg_ref',
#                                              'prescription_freq_ref',
#                                              'drg_weight', 'adm_drug_dose_mean',
#                                              'diag_class_ref_S',
#                                              'num_he...
#                                                               missing_values=nan,
#                                                               strategy='most_frequent'))),
#                 ('trained_model',
#                  DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                         criterion='gini', max_depth=None,
#                                         max_features=None, max_leaf_nodes=None,
#                                         min_impurity_decrease=0.0,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         monotonic_cst=None, random_state=123,
#                                         splitter='best'))],
#          verbose=False)

# %%
# Hyperparameters after tunning
print(decision_tree_model_tuned)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='log_loss',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, random_state=123, splitter='best')

# %% [markdown]
# In this case, the hyperparameter of criterion changed from gini to log_loss.

# %% [markdown]
# ## **Predictions**
#
# Using the ```predict_model``` function, we can predicts the performance of the model on the test set.

# %%
# Predict on the test set
predict_model(decision_tree_model_tuned)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1bfba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bfba_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1bfba_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1bfba_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1bfba_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1bfba_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1bfba_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1bfba_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1bfba_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bfba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1bfba_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_1bfba_row0_col1" class="data row0 col1" >0.6875</td>
#       <td id="T_1bfba_row0_col2" class="data row0 col2" >0.8320</td>
#       <td id="T_1bfba_row0_col3" class="data row0 col3" >0.6875</td>
#       <td id="T_1bfba_row0_col4" class="data row0 col4" >0.6881</td>
#       <td id="T_1bfba_row0_col5" class="data row0 col5" >0.6878</td>
#       <td id="T_1bfba_row0_col6" class="data row0 col6" >0.6541</td>
#       <td id="T_1bfba_row0_col7" class="data row0 col7" >0.6541</td>
#     </tr>
#   </tbody>
# </table>
#          episode_duration  care_level_duration  no_administration_reason_ref  \
# 218191        1358.753296           181.709442                           0.0
# 863976        1651.416626           789.266663                           5.0
# 961023         355.107513           219.366394                           0.0
# 916955         116.547226            46.750000                           5.0
# 1013913       1358.753296           481.936676                           0.0
# ...                   ...                  ...                           ...
# 842210        1401.687744           937.500000                           5.0
# 999667        1512.166626           116.433334                           0.0
# 323441        1358.753296           481.936676                           0.0
# 882856        2222.074951            29.608889                           6.0
# 586894         732.129456           571.786133                           0.0
#
#          drg_mdc_ref   age   snomed_code  drg_ref  prescription_freq_ref  \
# 218191           6.0  74.0  6.540401e+07    231.0              10.653914
# 863976           7.0  79.0  6.004601e+07    260.0              10.653914
# 961023           9.0  56.0  9.532600e+07    385.0              10.764503
# 916955          21.0  51.0  1.162900e+08    793.0              10.844776
# 1013913          6.0  74.0  2.147484e+09    231.0              10.764503
# ...              ...   ...           ...      ...                    ...
# 842210           7.0  41.0  1.392001e+07    284.0              10.653914
# 999667          17.0  45.0  8.238501e+07      7.0              10.653914
# 323441           6.0  74.0  3.074960e+08    231.0              10.764503
# 882856           7.0  73.0  3.121040e+08    260.0              10.844776
# 586894          11.0  69.0  7.377401e+07    440.0              10.645352
#
#          drg_weight  adm_drug_dose_mean  ...  lab_result_num_mean  adm_prn  \
# 218191       2.3206                 1.0  ...             0.966667      0.0
# 863976       5.9280               100.0  ...             1.661905      0.0
# 961023       0.5537               100.0  ...           137.666672      1.0
# 916955       0.9261               100.0  ...             0.366667      0.0
# 1013913      2.3206                 5.0  ...            16.258333      1.0
# ...             ...                 ...  ...                  ...      ...
# 842210       2.0301               100.0  ...             6.772000      0.0
# 999667      17.9363               495.0  ...             1.517759      0.0
# 323441       2.3206                 2.0  ...             0.300000      1.0
# 882856       5.9280                 2.0  ...             1.740909      0.0
# 586894       5.1383                 1.0  ...            90.038460      0.0
#
#          adm_given  clinical_records_result_num_mean  \
# 218191         0.0                         17.965517
# 863976         1.0                         89.620689
# 961023         0.0                        132.425919
# 916955         1.0                        156.122452
# 1013913        0.0                         86.611115
# ...            ...                               ...
# 842210         1.0                         35.799999
# 999667         0.0                         36.165573
# 323441         0.0                         55.170731
# 882856         1.0                         95.695656
# 586894         0.0                         20.179487
#
#          prescription_drug_dose_mean  adm_route_ref  health_issue_ou_med_ref  \
# 218191                    495.399994          100.0                 9.533010
# 863976                    100.000000          150.0                13.740342
# 961023                    500.000000          150.0                10.077813
# 916955                      1.000000          150.0                14.636505
# 1013913                   500.000000          150.0                 9.321969
# ...                              ...            ...                      ...
# 842210                      2.000000          150.0                 9.321969
# 999667                      1.333333          350.0                 9.520975
# 323441                    495.399994          100.0                10.600161
# 882856                      2.000000          150.0                 9.377646
# 586894                      6.000000          100.0                 9.654046
#
#          icd10_capitulo  prediction_label  prediction_score
# 218191                1                15               1.0
# 863976               12                17               1.0
# 961023               14                14               1.0
# 916955               14                14               1.0
# 1013913              16                16               1.0
# ...                 ...               ...               ...
# 842210               14                 0               1.0
# 999667               14                14               1.0
# 323441                1                 1               1.0
# 882856               15                12               0.5
# 586894               13                13               1.0
#
# [313796 rows x 23 columns]

# %%
# Get the performance metrics
pull()
# Out:
#                       Model  Accuracy    AUC  Recall   Prec.      F1   Kappa  \
# 0  Decision Tree Classifier    0.6875  0.832  0.6875  0.6881  0.6878  0.6541
#
#       MCC
# 0  0.6541

# %% [markdown]
# ## **Analyse Model**
#
# Plots to analyse the performance of the model on the test set.

# %% [markdown]
# ### **Confusion Matrix**

# %%
# Confusion Matrix
plt.figure(figsize=(25, 25))
plot_model(decision_tree_model_tuned, plot = 'confusion_matrix') # save=True, use_train_data=False

# %% [markdown]
# ### **Area Under the Curve (AUC)**

# %%
# Area Under the Curve (AUC)
plt.figure(figsize=(25, 25))
plot_model(decision_tree_model_tuned, plot = 'auc') # save=True

# %% [markdown]
# ### **Class Prediction Error**

# %%
# Class Prediction Error
plt.figure(figsize=(10, 5))
plot_model(decision_tree_model_tuned, plot = 'error') # save=True

# %% [markdown]
# ### **Classification Report**

# %%
# Classification Report
plt.figure(figsize=(10, 10))
plot_model(decision_tree_model_tuned, plot = 'class_report') # save=True

# %% [markdown]
# ### **Feature Importance**

# %%
# Feature importance
plt.figure(figsize=(10, 10))
plot_model(decision_tree_model_tuned, plot = 'feature') # save=True
