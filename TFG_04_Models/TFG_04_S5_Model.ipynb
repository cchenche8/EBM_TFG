# %% [markdown]
# # **TFG**
#
# ***Machine Learning-Based Classification of Hospital Discharge Diagnoses Using SNOMED-CT Encoded Health Problems and Clinical Data***
#
# Cindy Chen
#
# Universitat de Barcelona
#
# 2024-2025

# %%
# Import modules 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display 
import gradio as gr
import os
from pycaret.classification import *
from pycaret.classification import plot_model
from pycaret.classification import predict_model, pull, load_model

# %matplotlib inline

# %% [markdown]
# ## **Data Importation**
#
# Import Subset 5 to find the best model, train the model, tune it and evaluate.

# %%
# Import data
data = pd.read_csv("C:/Users/Cindy Chen/Desktop/TFG/data/04_data/subset_5.csv")
data
# Out:
#          diag_class_ref_S  diag_class_ref_H  health_issue_ou_med_ref  \
# 0                     1.0               0.0                11.859204
# 1                     1.0               0.0                10.077813
# 2                     1.0               0.0                 9.377647
# 3                     1.0               0.0                10.600160
# 4                     1.0               0.0                10.600160
# ...                   ...               ...                      ...
# 1045979               1.0               0.0                10.965332
# 1045980               1.0               0.0                12.826443
# 1045981               1.0               0.0                10.077813
# 1045982               0.0               1.0                 9.260414
# 1045983               1.0               0.0                10.077813
#
#          drg_rom_ref  sex_atr  drg_mdc_ref  drg_soi_ref  episode_duration  \
# 0                4.0      2.0         11.0          4.0        706.924438
# 1                3.0      1.0         16.0          3.0        287.425842
# 2                4.0      1.0          7.0          4.0       2222.074951
# 3                2.0      2.0          6.0          3.0       1358.753296
# 4                2.0      2.0          6.0          3.0       1358.753296
# ...              ...      ...          ...          ...               ...
# 1045979          4.0      2.0         18.0          4.0       1842.586670
# 1045980          1.0      1.0          7.0          2.0        163.000000
# 1045981          3.0      2.0         17.0          4.0       1512.166626
# 1045982          1.0      2.0          8.0          2.0       1311.468872
# 1045983          3.0      2.0         17.0          3.0        904.000000
#
#          num_health_issues  drg_ref  icd10_capitulo
# 0                      3.0    469.0              17
# 1                      3.0    662.0              17
# 2                      5.0    260.0               1
# 3                      8.0    231.0               9
# 4                      8.0    231.0              16
# ...                    ...      ...             ...
# 1045979                4.0    710.0              14
# 1045980                2.0    260.0              14
# 1045981                3.0      7.0               1
# 1045982                1.0    320.0              15
# 1045983                5.0      7.0              13
#
# [1045984 rows x 11 columns]

# %% [markdown]
# Setup the pycaret environment and select the target column, in our case is the 'icd10_capitulo' column. This function also splits the data into training (70%) and testing set (30%).

# %%
# Configuración del entorno de PyCaret
clf = setup(data=data, target='icd10_capitulo', session_id=123, verbose=True)
# Out:
# <style type="text/css">
# #T_f924d_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f924d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f924d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f924d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f924d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f924d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f924d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f924d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f924d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f924d_row1_col1" class="data row1 col1" >icd10_capitulo</td>
#     </tr>
#     <tr>
#       <th id="T_f924d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f924d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f924d_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_f924d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f924d_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f924d_row3_col1" class="data row3 col1" >(1045984, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_f924d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f924d_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f924d_row4_col1" class="data row4 col1" >(1045984, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_f924d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f924d_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f924d_row5_col1" class="data row5 col1" >(732188, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_f924d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f924d_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f924d_row6_col1" class="data row6 col1" >(313796, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_f924d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f924d_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_f924d_row7_col1" class="data row7 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f924d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f924d_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_f924d_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f924d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f924d_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_f924d_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f924d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f924d_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_f924d_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f924d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f924d_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_f924d_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f924d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f924d_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_f924d_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_f924d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f924d_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_f924d_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f924d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f924d_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_f924d_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f924d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f924d_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_f924d_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f924d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f924d_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_f924d_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f924d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f924d_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_f924d_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f924d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f924d_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_f924d_row18_col1" class="data row18 col1" >2204</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Get preprocessing pipeline
get_config('pipeline')
# Out:
# Pipeline(memory=FastMemory(location=C:\Users\CINDYC~1\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['diag_class_ref_S',
#                                              'diag_class_ref_H',
#                                              'health_issue_ou_med_ref',
#                                              'drg_rom_ref', 'sex_atr',
#                                              'drg_mdc_ref', 'drg_soi_ref',
#                                              'episode_duration',
#                                              'num_health_issues', 'drg_ref'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='mean'))),
#                 ('categorical_imputer',
#                  TransformerWrapper(exclude=None, include=[],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='most_frequent')))],
#          verbose=False)

# %% [markdown]
# ## **Model Comparison**
#
# Using the ```compare_models``` function to compare the selected models: Logistic Regression, Decision Trees, Random Forest, XGBoost, SVM, KNN and MLP.
#
# This function trains and evaluates the performance of all estimators available in the model library using cross-validation. The output of this function is a scoring grid with average cross-validated scores.

# %%
# Compare models
model_comparison = compare_models(include=["lr", 'dt', 'rf', 'xgboost', 'svm', 'knn', 'mlp'])
# Out:
# <style type="text/css">
# #T_ebeaf th {
#   text-align: left;
# }
# #T_ebeaf_row0_col0, #T_ebeaf_row0_col4, #T_ebeaf_row0_col5, #T_ebeaf_row0_col6, #T_ebeaf_row0_col7, #T_ebeaf_row1_col0, #T_ebeaf_row1_col4, #T_ebeaf_row1_col5, #T_ebeaf_row1_col6, #T_ebeaf_row1_col7, #T_ebeaf_row2_col0, #T_ebeaf_row2_col1, #T_ebeaf_row2_col3, #T_ebeaf_row2_col4, #T_ebeaf_row2_col5, #T_ebeaf_row3_col0, #T_ebeaf_row3_col1, #T_ebeaf_row3_col2, #T_ebeaf_row3_col3, #T_ebeaf_row3_col6, #T_ebeaf_row3_col7, #T_ebeaf_row4_col0, #T_ebeaf_row4_col1, #T_ebeaf_row4_col2, #T_ebeaf_row4_col3, #T_ebeaf_row4_col4, #T_ebeaf_row4_col5, #T_ebeaf_row4_col6, #T_ebeaf_row4_col7, #T_ebeaf_row5_col0, #T_ebeaf_row5_col1, #T_ebeaf_row5_col2, #T_ebeaf_row5_col3, #T_ebeaf_row5_col4, #T_ebeaf_row5_col5, #T_ebeaf_row5_col6, #T_ebeaf_row5_col7, #T_ebeaf_row6_col0, #T_ebeaf_row6_col1, #T_ebeaf_row6_col2, #T_ebeaf_row6_col3, #T_ebeaf_row6_col4, #T_ebeaf_row6_col5, #T_ebeaf_row6_col6, #T_ebeaf_row6_col7 {
#   text-align: left;
# }
# #T_ebeaf_row0_col1, #T_ebeaf_row0_col2, #T_ebeaf_row0_col3, #T_ebeaf_row1_col1, #T_ebeaf_row1_col2, #T_ebeaf_row1_col3, #T_ebeaf_row2_col2, #T_ebeaf_row2_col6, #T_ebeaf_row2_col7, #T_ebeaf_row3_col4, #T_ebeaf_row3_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ebeaf_row0_col8, #T_ebeaf_row1_col8, #T_ebeaf_row3_col8, #T_ebeaf_row4_col8, #T_ebeaf_row5_col8, #T_ebeaf_row6_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ebeaf_row2_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ebeaf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebeaf_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ebeaf_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ebeaf_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ebeaf_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ebeaf_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ebeaf_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ebeaf_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ebeaf_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ebeaf_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebeaf_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_ebeaf_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_ebeaf_row0_col1" class="data row0 col1" >0.4014</td>
#       <td id="T_ebeaf_row0_col2" class="data row0 col2" >0.8985</td>
#       <td id="T_ebeaf_row0_col3" class="data row0 col3" >0.4014</td>
#       <td id="T_ebeaf_row0_col4" class="data row0 col4" >0.4455</td>
#       <td id="T_ebeaf_row0_col5" class="data row0 col5" >0.4004</td>
#       <td id="T_ebeaf_row0_col6" class="data row0 col6" >0.3450</td>
#       <td id="T_ebeaf_row0_col7" class="data row0 col7" >0.3478</td>
#       <td id="T_ebeaf_row0_col8" class="data row0 col8" >19.3850</td>
#     </tr>
#     <tr>
#       <th id="T_ebeaf_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_ebeaf_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_ebeaf_row1_col1" class="data row1 col1" >0.4014</td>
#       <td id="T_ebeaf_row1_col2" class="data row1 col2" >0.8985</td>
#       <td id="T_ebeaf_row1_col3" class="data row1 col3" >0.4014</td>
#       <td id="T_ebeaf_row1_col4" class="data row1 col4" >0.4407</td>
#       <td id="T_ebeaf_row1_col5" class="data row1 col5" >0.3975</td>
#       <td id="T_ebeaf_row1_col6" class="data row1 col6" >0.3445</td>
#       <td id="T_ebeaf_row1_col7" class="data row1 col7" >0.3474</td>
#       <td id="T_ebeaf_row1_col8" class="data row1 col8" >45.4930</td>
#     </tr>
#     <tr>
#       <th id="T_ebeaf_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_ebeaf_row2_col0" class="data row2 col0" >Decision Tree Classifier</td>
#       <td id="T_ebeaf_row2_col1" class="data row2 col1" >0.4013</td>
#       <td id="T_ebeaf_row2_col2" class="data row2 col2" >0.8985</td>
#       <td id="T_ebeaf_row2_col3" class="data row2 col3" >0.4013</td>
#       <td id="T_ebeaf_row2_col4" class="data row2 col4" >0.4458</td>
#       <td id="T_ebeaf_row2_col5" class="data row2 col5" >0.4006</td>
#       <td id="T_ebeaf_row2_col6" class="data row2 col6" >0.3453</td>
#       <td id="T_ebeaf_row2_col7" class="data row2 col7" >0.3481</td>
#       <td id="T_ebeaf_row2_col8" class="data row2 col8" >0.7100</td>
#     </tr>
#     <tr>
#       <th id="T_ebeaf_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_ebeaf_row3_col0" class="data row3 col0" >K Neighbors Classifier</td>
#       <td id="T_ebeaf_row3_col1" class="data row3 col1" >0.3960</td>
#       <td id="T_ebeaf_row3_col2" class="data row3 col2" >0.7831</td>
#       <td id="T_ebeaf_row3_col3" class="data row3 col3" >0.3960</td>
#       <td id="T_ebeaf_row3_col4" class="data row3 col4" >0.4836</td>
#       <td id="T_ebeaf_row3_col5" class="data row3 col5" >0.4070</td>
#       <td id="T_ebeaf_row3_col6" class="data row3 col6" >0.3385</td>
#       <td id="T_ebeaf_row3_col7" class="data row3 col7" >0.3437</td>
#       <td id="T_ebeaf_row3_col8" class="data row3 col8" >28.3150</td>
#     </tr>
#     <tr>
#       <th id="T_ebeaf_level0_row4" class="row_heading level0 row4" >mlp</th>
#       <td id="T_ebeaf_row4_col0" class="data row4 col0" >MLP Classifier</td>
#       <td id="T_ebeaf_row4_col1" class="data row4 col1" >0.3869</td>
#       <td id="T_ebeaf_row4_col2" class="data row4 col2" >0.8854</td>
#       <td id="T_ebeaf_row4_col3" class="data row4 col3" >0.3869</td>
#       <td id="T_ebeaf_row4_col4" class="data row4 col4" >0.4818</td>
#       <td id="T_ebeaf_row4_col5" class="data row4 col5" >0.3779</td>
#       <td id="T_ebeaf_row4_col6" class="data row4 col6" >0.3219</td>
#       <td id="T_ebeaf_row4_col7" class="data row4 col7" >0.3287</td>
#       <td id="T_ebeaf_row4_col8" class="data row4 col8" >78.1330</td>
#     </tr>
#     <tr>
#       <th id="T_ebeaf_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_ebeaf_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_ebeaf_row5_col1" class="data row5 col1" >0.2588</td>
#       <td id="T_ebeaf_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_ebeaf_row5_col3" class="data row5 col3" >0.2588</td>
#       <td id="T_ebeaf_row5_col4" class="data row5 col4" >0.1901</td>
#       <td id="T_ebeaf_row5_col5" class="data row5 col5" >0.1916</td>
#       <td id="T_ebeaf_row5_col6" class="data row5 col6" >0.1249</td>
#       <td id="T_ebeaf_row5_col7" class="data row5 col7" >0.1409</td>
#       <td id="T_ebeaf_row5_col8" class="data row5 col8" >106.4250</td>
#     </tr>
#     <tr>
#       <th id="T_ebeaf_level0_row6" class="row_heading level0 row6" >svm</th>
#       <td id="T_ebeaf_row6_col0" class="data row6 col0" >SVM - Linear Kernel</td>
#       <td id="T_ebeaf_row6_col1" class="data row6 col1" >0.2009</td>
#       <td id="T_ebeaf_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_ebeaf_row6_col3" class="data row6 col3" >0.2009</td>
#       <td id="T_ebeaf_row6_col4" class="data row6 col4" >0.2018</td>
#       <td id="T_ebeaf_row6_col5" class="data row6 col5" >0.1600</td>
#       <td id="T_ebeaf_row6_col6" class="data row6 col6" >0.1068</td>
#       <td id="T_ebeaf_row6_col7" class="data row6 col7" >0.1206</td>
#       <td id="T_ebeaf_row6_col8" class="data row6 col8" >183.5410</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Save results table
model_comparison_df = pull()
model_comparison_df.to_csv('S5_model_comparison_df.csv', index=False)

# Save best_model
save_model(model_comparison, 'S5_model_comparison')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['diag_class_ref_S',
#                                               'diag_class_ref_H',
#                                               'health_issue_ou_med_ref',
#                                               'drg_rom_ref', 'sex_atr',
#                                               'drg_mdc_ref', 'drg_soi_ref',
#                                               'episode_duration',
#                                               'num_health_issues', 'drg_ref'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_...
#                   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                          class_weight=None, criterion='gini',
#                                          max_depth=None, max_features='sqrt',
#                                          max_leaf_nodes=None, max_samples=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          monotonic_cst=None, n_estimators=100,
#                                          n_jobs=-1, oob_score=False,
#                                          random_state=123, verbose=0,
#                                          warm_start=False))],
#           verbose=False),
#  'S5_model_comparison.pkl')

# %% [markdown]
# ## **Best Model**
#
# Once we have compared the different models, we select the best one. Then using the ```create_model``` function we train and evaluate the performance of the model using cross-validation. By default, it uses the 10 fold.

# %%
# Model evaluation: cross validation 10 folds
random_forest_model = create_model('rf')  
evaluate_model(random_forest_model)
# Out:
# <style type="text/css">
# #T_20164_row10_col0, #T_20164_row10_col1, #T_20164_row10_col2, #T_20164_row10_col3, #T_20164_row10_col4, #T_20164_row10_col5, #T_20164_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_20164">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20164_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_20164_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_20164_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_20164_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_20164_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_20164_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_20164_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20164_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20164_row0_col0" class="data row0 col0" >0.4018</td>
#       <td id="T_20164_row0_col1" class="data row0 col1" >0.8990</td>
#       <td id="T_20164_row0_col2" class="data row0 col2" >0.4018</td>
#       <td id="T_20164_row0_col3" class="data row0 col3" >0.4438</td>
#       <td id="T_20164_row0_col4" class="data row0 col4" >0.4006</td>
#       <td id="T_20164_row0_col5" class="data row0 col5" >0.3456</td>
#       <td id="T_20164_row0_col6" class="data row0 col6" >0.3486</td>
#     </tr>
#     <tr>
#       <th id="T_20164_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_20164_row1_col0" class="data row1 col0" >0.4007</td>
#       <td id="T_20164_row1_col1" class="data row1 col1" >0.8977</td>
#       <td id="T_20164_row1_col2" class="data row1 col2" >0.4007</td>
#       <td id="T_20164_row1_col3" class="data row1 col3" >0.4379</td>
#       <td id="T_20164_row1_col4" class="data row1 col4" >0.3969</td>
#       <td id="T_20164_row1_col5" class="data row1 col5" >0.3439</td>
#       <td id="T_20164_row1_col6" class="data row1 col6" >0.3469</td>
#     </tr>
#     <tr>
#       <th id="T_20164_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_20164_row2_col0" class="data row2 col0" >0.4016</td>
#       <td id="T_20164_row2_col1" class="data row2 col1" >0.8993</td>
#       <td id="T_20164_row2_col2" class="data row2 col2" >0.4016</td>
#       <td id="T_20164_row2_col3" class="data row2 col3" >0.4634</td>
#       <td id="T_20164_row2_col4" class="data row2 col4" >0.4052</td>
#       <td id="T_20164_row2_col5" class="data row2 col5" >0.3460</td>
#       <td id="T_20164_row2_col6" class="data row2 col6" >0.3498</td>
#     </tr>
#     <tr>
#       <th id="T_20164_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_20164_row3_col0" class="data row3 col0" >0.4041</td>
#       <td id="T_20164_row3_col1" class="data row3 col1" >0.8996</td>
#       <td id="T_20164_row3_col2" class="data row3 col2" >0.4041</td>
#       <td id="T_20164_row3_col3" class="data row3 col3" >0.4420</td>
#       <td id="T_20164_row3_col4" class="data row3 col4" >0.4007</td>
#       <td id="T_20164_row3_col5" class="data row3 col5" >0.3469</td>
#       <td id="T_20164_row3_col6" class="data row3 col6" >0.3497</td>
#     </tr>
#     <tr>
#       <th id="T_20164_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_20164_row4_col0" class="data row4 col0" >0.4010</td>
#       <td id="T_20164_row4_col1" class="data row4 col1" >0.8986</td>
#       <td id="T_20164_row4_col2" class="data row4 col2" >0.4010</td>
#       <td id="T_20164_row4_col3" class="data row4 col3" >0.4520</td>
#       <td id="T_20164_row4_col4" class="data row4 col4" >0.3991</td>
#       <td id="T_20164_row4_col5" class="data row4 col5" >0.3445</td>
#       <td id="T_20164_row4_col6" class="data row4 col6" >0.3475</td>
#     </tr>
#     <tr>
#       <th id="T_20164_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_20164_row5_col0" class="data row5 col0" >0.3989</td>
#       <td id="T_20164_row5_col1" class="data row5 col1" >0.8981</td>
#       <td id="T_20164_row5_col2" class="data row5 col2" >0.3989</td>
#       <td id="T_20164_row5_col3" class="data row5 col3" >0.4432</td>
#       <td id="T_20164_row5_col4" class="data row5 col4" >0.3962</td>
#       <td id="T_20164_row5_col5" class="data row5 col5" >0.3416</td>
#       <td id="T_20164_row5_col6" class="data row5 col6" >0.3441</td>
#     </tr>
#     <tr>
#       <th id="T_20164_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_20164_row6_col0" class="data row6 col0" >0.4005</td>
#       <td id="T_20164_row6_col1" class="data row6 col1" >0.8981</td>
#       <td id="T_20164_row6_col2" class="data row6 col2" >0.4005</td>
#       <td id="T_20164_row6_col3" class="data row6 col3" >0.4448</td>
#       <td id="T_20164_row6_col4" class="data row6 col4" >0.4057</td>
#       <td id="T_20164_row6_col5" class="data row6 col5" >0.3448</td>
#       <td id="T_20164_row6_col6" class="data row6 col6" >0.3471</td>
#     </tr>
#     <tr>
#       <th id="T_20164_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_20164_row7_col0" class="data row7 col0" >0.4015</td>
#       <td id="T_20164_row7_col1" class="data row7 col1" >0.8995</td>
#       <td id="T_20164_row7_col2" class="data row7 col2" >0.4015</td>
#       <td id="T_20164_row7_col3" class="data row7 col3" >0.4511</td>
#       <td id="T_20164_row7_col4" class="data row7 col4" >0.3975</td>
#       <td id="T_20164_row7_col5" class="data row7 col5" >0.3450</td>
#       <td id="T_20164_row7_col6" class="data row7 col6" >0.3479</td>
#     </tr>
#     <tr>
#       <th id="T_20164_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_20164_row8_col0" class="data row8 col0" >0.4028</td>
#       <td id="T_20164_row8_col1" class="data row8 col1" >0.8973</td>
#       <td id="T_20164_row8_col2" class="data row8 col2" >0.4028</td>
#       <td id="T_20164_row8_col3" class="data row8 col3" >0.4433</td>
#       <td id="T_20164_row8_col4" class="data row8 col4" >0.3960</td>
#       <td id="T_20164_row8_col5" class="data row8 col5" >0.3461</td>
#       <td id="T_20164_row8_col6" class="data row8 col6" >0.3493</td>
#     </tr>
#     <tr>
#       <th id="T_20164_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_20164_row9_col0" class="data row9 col0" >0.4009</td>
#       <td id="T_20164_row9_col1" class="data row9 col1" >0.8981</td>
#       <td id="T_20164_row9_col2" class="data row9 col2" >0.4009</td>
#       <td id="T_20164_row9_col3" class="data row9 col3" >0.4332</td>
#       <td id="T_20164_row9_col4" class="data row9 col4" >0.4059</td>
#       <td id="T_20164_row9_col5" class="data row9 col5" >0.3454</td>
#       <td id="T_20164_row9_col6" class="data row9 col6" >0.3475</td>
#     </tr>
#     <tr>
#       <th id="T_20164_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_20164_row10_col0" class="data row10 col0" >0.4014</td>
#       <td id="T_20164_row10_col1" class="data row10 col1" >0.8985</td>
#       <td id="T_20164_row10_col2" class="data row10 col2" >0.4014</td>
#       <td id="T_20164_row10_col3" class="data row10 col3" >0.4455</td>
#       <td id="T_20164_row10_col4" class="data row10 col4" >0.4004</td>
#       <td id="T_20164_row10_col5" class="data row10 col5" >0.3450</td>
#       <td id="T_20164_row10_col6" class="data row10 col6" >0.3478</td>
#     </tr>
#     <tr>
#       <th id="T_20164_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_20164_row11_col0" class="data row11 col0" >0.0013</td>
#       <td id="T_20164_row11_col1" class="data row11 col1" >0.0007</td>
#       <td id="T_20164_row11_col2" class="data row11 col2" >0.0013</td>
#       <td id="T_20164_row11_col3" class="data row11 col3" >0.0079</td>
#       <td id="T_20164_row11_col4
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# Save model
save_model(random_forest_model, 'S5_best_model_rf')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['diag_class_ref_S',
#                                               'diag_class_ref_H',
#                                               'health_issue_ou_med_ref',
#                                               'drg_rom_ref', 'sex_atr',
#                                               'drg_mdc_ref', 'drg_soi_ref',
#                                               'episode_duration',
#                                               'num_health_issues', 'drg_ref'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_...
#                   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                          class_weight=None, criterion='gini',
#                                          max_depth=None, max_features='sqrt',
#                                          max_leaf_nodes=None, max_samples=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          monotonic_cst=None, n_estimators=100,
#                                          n_jobs=-1, oob_score=False,
#                                          random_state=123, verbose=0,
#                                          warm_start=False))],
#           verbose=False),
#  'S5_best_model_rf.pkl')

# %%
# Load model
random_forest_model = load_model("C:/Users/Cindy Chen/Desktop/TFG/plots/04/S5/S5_best_model_rf")
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# ## **Optimize and Tune Model**
#
# The ```tune_model``` function tunes the hyperparameters of the model. The output of this function is a scoring grid with cross-validated scores by fold.
#
# By default, it uses RandomGridSearch from the sklearn and the number of iterations (n_iter) is set to 10.

# %%
# Optimize and tune model using Random Grid Search 
random_forest_model_tuned = tune_model(random_forest_model)
# Out:
# <style type="text/css">
# #T_b26e2_row10_col0, #T_b26e2_row10_col1, #T_b26e2_row10_col2, #T_b26e2_row10_col3, #T_b26e2_row10_col4, #T_b26e2_row10_col5, #T_b26e2_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b26e2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b26e2_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b26e2_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b26e2_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b26e2_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b26e2_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b26e2_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b26e2_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b26e2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b26e2_row0_col0" class="data row0 col0" >0.3464</td>
#       <td id="T_b26e2_row0_col1" class="data row0 col1" >0.8353</td>
#       <td id="T_b26e2_row0_col2" class="data row0 col2" >0.3464</td>
#       <td id="T_b26e2_row0_col3" class="data row0 col3" >0.3996</td>
#       <td id="T_b26e2_row0_col4" class="data row0 col4" >0.2879</td>
#       <td id="T_b26e2_row0_col5" class="data row0 col5" >0.2427</td>
#       <td id="T_b26e2_row0_col6" class="data row0 col6" >0.2654</td>
#     </tr>
#     <tr>
#       <th id="T_b26e2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b26e2_row1_col0" class="data row1 col0" >0.3447</td>
#       <td id="T_b26e2_row1_col1" class="data row1 col1" >0.8333</td>
#       <td id="T_b26e2_row1_col2" class="data row1 col2" >0.3447</td>
#       <td id="T_b26e2_row1_col3" class="data row1 col3" >0.4018</td>
#       <td id="T_b26e2_row1_col4" class="data row1 col4" >0.2870</td>
#       <td id="T_b26e2_row1_col5" class="data row1 col5" >0.2405</td>
#       <td id="T_b26e2_row1_col6" class="data row1 col6" >0.2633</td>
#     </tr>
#     <tr>
#       <th id="T_b26e2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b26e2_row2_col0" class="data row2 col0" >0.3454</td>
#       <td id="T_b26e2_row2_col1" class="data row2 col1" >0.8348</td>
#       <td id="T_b26e2_row2_col2" class="data row2 col2" >0.3454</td>
#       <td id="T_b26e2_row2_col3" class="data row2 col3" >0.4038</td>
#       <td id="T_b26e2_row2_col4" class="data row2 col4" >0.2893</td>
#       <td id="T_b26e2_row2_col5" class="data row2 col5" >0.2418</td>
#       <td id="T_b26e2_row2_col6" class="data row2 col6" >0.2641</td>
#     </tr>
#     <tr>
#       <th id="T_b26e2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b26e2_row3_col0" class="data row3 col0" >0.3458</td>
#       <td id="T_b26e2_row3_col1" class="data row3 col1" >0.8346</td>
#       <td id="T_b26e2_row3_col2" class="data row3 col2" >0.3458</td>
#       <td id="T_b26e2_row3_col3" class="data row3 col3" >0.3978</td>
#       <td id="T_b26e2_row3_col4" class="data row3 col4" >0.2883</td>
#       <td id="T_b26e2_row3_col5" class="data row3 col5" >0.2421</td>
#       <td id="T_b26e2_row3_col6" class="data row3 col6" >0.2646</td>
#     </tr>
#     <tr>
#       <th id="T_b26e2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b26e2_row4_col0" class="data row4 col0" >0.3460</td>
#       <td id="T_b26e2_row4_col1" class="data row4 col1" >0.8347</td>
#       <td id="T_b26e2_row4_col2" class="data row4 col2" >0.3460</td>
#       <td id="T_b26e2_row4_col3" class="data row4 col3" >0.4039</td>
#       <td id="T_b26e2_row4_col4" class="data row4 col4" >0.2893</td>
#       <td id="T_b26e2_row4_col5" class="data row4 col5" >0.2424</td>
#       <td id="T_b26e2_row4_col6" class="data row4 col6" >0.2650</td>
#     </tr>
#     <tr>
#       <th id="T_b26e2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b26e2_row5_col0" class="data row5 col0" >0.3451</td>
#       <td id="T_b26e2_row5_col1" class="data row5 col1" >0.8332</td>
#       <td id="T_b26e2_row5_col2" class="data row5 col2" >0.3451</td>
#       <td id="T_b26e2_row5_col3" class="data row5 col3" >0.3975</td>
#       <td id="T_b26e2_row5_col4" class="data row5 col4" >0.2870</td>
#       <td id="T_b26e2_row5_col5" class="data row5 col5" >0.2404</td>
#       <td id="T_b26e2_row5_col6" class="data row5 col6" >0.2632</td>
#     </tr>
#     <tr>
#       <th id="T_b26e2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b26e2_row6_col0" class="data row6 col0" >0.3440</td>
#       <td id="T_b26e2_row6_col1" class="data row6 col1" >0.8327</td>
#       <td id="T_b26e2_row6_col2" class="data row6 col2" >0.3440</td>
#       <td id="T_b26e2_row6_col3" class="data row6 col3" >0.3965</td>
#       <td id="T_b26e2_row6_col4" class="data row6 col4" >0.2870</td>
#       <td id="T_b26e2_row6_col5" class="data row6 col5" >0.2392</td>
#       <td id="T_b26e2_row6_col6" class="data row6 col6" >0.2616</td>
#     </tr>
#     <tr>
#       <th id="T_b26e2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b26e2_row7_col0" class="data row7 col0" >0.3472</td>
#       <td id="T_b26e2_row7_col1" class="data row7 col1" >0.8348</td>
#       <td id="T_b26e2_row7_col2" class="data row7 col2" >0.3472</td>
#       <td id="T_b26e2_row7_col3" class="data row7 col3" >0.3980</td>
#       <td id="T_b26e2_row7_col4" class="data row7 col4" >0.2891</td>
#       <td id="T_b26e2_row7_col5" class="data row7 col5" >0.2438</td>
#       <td id="T_b26e2_row7_col6" class="data row7 col6" >0.2663</td>
#     </tr>
#     <tr>
#       <th id="T_b26e2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b26e2_row8_col0" class="data row8 col0" >0.3455</td>
#       <td id="T_b26e2_row8_col1" class="data row8 col1" >0.8326</td>
#       <td id="T_b26e2_row8_col2" class="data row8 col2" >0.3455</td>
#       <td id="T_b26e2_row8_col3" class="data row8 col3" >0.4010</td>
#       <td id="T_b26e2_row8_col4" class="data row8 col4" >0.2879</td>
#       <td id="T_b26e2_row8_col5" class="data row8 col5" >0.2417</td>
#       <td id="T_b26e2_row8_col6" class="data row8 col6" >0.2643</td>
#     </tr>
#     <tr>
#       <th id="T_b26e2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b26e2_row9_col0" class="data row9 col0" >0.3431</td>
#       <td id="T_b26e2_row9_col1" class="data row9 col1" >0.8331</td>
#       <td id="T_b26e2_row9_col2" class="data row9 col2" >0.3431</td>
#       <td id="T_b26e2_row9_col3" class="data row9 col3" >0.3950</td>
#       <td id="T_b26e2_row9_col4" class="data row9 col4" >0.2864</td>
#       <td id="T_b26e2_row9_col5" class="data row9 col5" >0.2385</td>
#       <td id="T_b26e2_row9_col6" class="data row9 col6" >0.2607</td>
#     </tr>
#     <tr>
#       <th id="T_b26e2_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b26e2_row10_col0" class="data row10 col0" >0.3453</td>
#       <td id="T_b26e2_row10_col1" class="data row10 col1" >0.8339</td>
#       <td id="T_b26e2_row10_col2" class="data row10 col2" >0.3453</td>
#       <td id="T_b26e2_row10_col3" class="data row10 col3" >0.3995</td>
#       <td id="T_b26e2_row10_col4" class="data row10 col4" >0.2879</td>
#       <td id="T_b26e2_row10_col5" class="data row10 col5" >0.2413</td>
#       <td id="T_b26e2_row10_col6" class="data row10 col6" >0.2638</td>
#     </tr>
#     <tr>
#       <th id="T_b26e2_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_b26e2_row11_col0" class="data row11 col0" >0.0011</td>
#       <td id="T_b26e2_row11_col1" class="data row11 col1" >0.0010</td>
#       <td id="T_b26e2_row11_col2" class="data row11 col2" >0.0011</td>
#       <td id="T_b26e2_row11_col3" class="data row11 col3" >0.0029</td>
#       <td id="T_b26e2_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# As we can see, the Random Grid Search didn't obtain better results than the original model, so let's customise the grid and parameters using custom_grid.
#
# For random forest, the hyperparameters decided to use are:
# - max_depth
# - n_estimators
# - criterion

# %%
# Optimize and tune model using custom grid and Random Grid Search
params = {'max_depth': [None, 5, 10, 15],
          'n_estimators': [100, 200, 300],
          'criterion': ['gini', 'entropy', 'log_loss']
} 

random_forest_model_tuned = tune_model(random_forest_model, custom_grid=params) # chose_better=False
# Out:
# <style type="text/css">
# #T_18745_row10_col0, #T_18745_row10_col1, #T_18745_row10_col2, #T_18745_row10_col3, #T_18745_row10_col4, #T_18745_row10_col5, #T_18745_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_18745">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18745_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_18745_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_18745_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_18745_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_18745_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_18745_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_18745_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18745_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18745_row0_col0" class="data row0 col0" >0.4018</td>
#       <td id="T_18745_row0_col1" class="data row0 col1" >0.8990</td>
#       <td id="T_18745_row0_col2" class="data row0 col2" >0.4018</td>
#       <td id="T_18745_row0_col3" class="data row0 col3" >0.4438</td>
#       <td id="T_18745_row0_col4" class="data row0 col4" >0.4006</td>
#       <td id="T_18745_row0_col5" class="data row0 col5" >0.3456</td>
#       <td id="T_18745_row0_col6" class="data row0 col6" >0.3486</td>
#     </tr>
#     <tr>
#       <th id="T_18745_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_18745_row1_col0" class="data row1 col0" >0.4008</td>
#       <td id="T_18745_row1_col1" class="data row1 col1" >0.8977</td>
#       <td id="T_18745_row1_col2" class="data row1 col2" >0.4008</td>
#       <td id="T_18745_row1_col3" class="data row1 col3" >0.4416</td>
#       <td id="T_18745_row1_col4" class="data row1 col4" >0.3979</td>
#       <td id="T_18745_row1_col5" class="data row1 col5" >0.3445</td>
#       <td id="T_18745_row1_col6" class="data row1 col6" >0.3475</td>
#     </tr>
#     <tr>
#       <th id="T_18745_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_18745_row2_col0" class="data row2 col0" >0.4015</td>
#       <td id="T_18745_row2_col1" class="data row2 col1" >0.8993</td>
#       <td id="T_18745_row2_col2" class="data row2 col2" >0.4015</td>
#       <td id="T_18745_row2_col3" class="data row2 col3" >0.4644</td>
#       <td id="T_18745_row2_col4" class="data row2 col4" >0.4061</td>
#       <td id="T_18745_row2_col5" class="data row2 col5" >0.3474</td>
#       <td id="T_18745_row2_col6" class="data row2 col6" >0.3513</td>
#     </tr>
#     <tr>
#       <th id="T_18745_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_18745_row3_col0" class="data row3 col0" >0.4040</td>
#       <td id="T_18745_row3_col1" class="data row3 col1" >0.8996</td>
#       <td id="T_18745_row3_col2" class="data row3 col2" >0.4040</td>
#       <td id="T_18745_row3_col3" class="data row3 col3" >0.4403</td>
#       <td id="T_18745_row3_col4" class="data row3 col4" >0.3996</td>
#       <td id="T_18745_row3_col5" class="data row3 col5" >0.3466</td>
#       <td id="T_18745_row3_col6" class="data row3 col6" >0.3494</td>
#     </tr>
#     <tr>
#       <th id="T_18745_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_18745_row4_col0" class="data row4 col0" >0.4016</td>
#       <td id="T_18745_row4_col1" class="data row4 col1" >0.8986</td>
#       <td id="T_18745_row4_col2" class="data row4 col2" >0.4016</td>
#       <td id="T_18745_row4_col3" class="data row4 col3" >0.4524</td>
#       <td id="T_18745_row4_col4" class="data row4 col4" >0.3999</td>
#       <td id="T_18745_row4_col5" class="data row4 col5" >0.3451</td>
#       <td id="T_18745_row4_col6" class="data row4 col6" >0.3481</td>
#     </tr>
#     <tr>
#       <th id="T_18745_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_18745_row5_col0" class="data row5 col0" >0.3987</td>
#       <td id="T_18745_row5_col1" class="data row5 col1" >0.8981</td>
#       <td id="T_18745_row5_col2" class="data row5 col2" >0.3987</td>
#       <td id="T_18745_row5_col3" class="data row5 col3" >0.4434</td>
#       <td id="T_18745_row5_col4" class="data row5 col4" >0.3963</td>
#       <td id="T_18745_row5_col5" class="data row5 col5" >0.3414</td>
#       <td id="T_18745_row5_col6" class="data row5 col6" >0.3439</td>
#     </tr>
#     <tr>
#       <th id="T_18745_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_18745_row6_col0" class="data row6 col0" >0.4005</td>
#       <td id="T_18745_row6_col1" class="data row6 col1" >0.8982</td>
#       <td id="T_18745_row6_col2" class="data row6 col2" >0.4005</td>
#       <td id="T_18745_row6_col3" class="data row6 col3" >0.4428</td>
#       <td id="T_18745_row6_col4" class="data row6 col4" >0.4048</td>
#       <td id="T_18745_row6_col5" class="data row6 col5" >0.3446</td>
#       <td id="T_18745_row6_col6" class="data row6 col6" >0.3468</td>
#     </tr>
#     <tr>
#       <th id="T_18745_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_18745_row7_col0" class="data row7 col0" >0.4015</td>
#       <td id="T_18745_row7_col1" class="data row7 col1" >0.8995</td>
#       <td id="T_18745_row7_col2" class="data row7 col2" >0.4015</td>
#       <td id="T_18745_row7_col3" class="data row7 col3" >0.4514</td>
#       <td id="T_18745_row7_col4" class="data row7 col4" >0.3972</td>
#       <td id="T_18745_row7_col5" class="data row7 col5" >0.3454</td>
#       <td id="T_18745_row7_col6" class="data row7 col6" >0.3483</td>
#     </tr>
#     <tr>
#       <th id="T_18745_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_18745_row8_col0" class="data row8 col0" >0.4028</td>
#       <td id="T_18745_row8_col1" class="data row8 col1" >0.8973</td>
#       <td id="T_18745_row8_col2" class="data row8 col2" >0.4028</td>
#       <td id="T_18745_row8_col3" class="data row8 col3" >0.4466</td>
#       <td id="T_18745_row8_col4" class="data row8 col4" >0.3975</td>
#       <td id="T_18745_row8_col5" class="data row8 col5" >0.3457</td>
#       <td id="T_18745_row8_col6" class="data row8 col6" >0.3488</td>
#     </tr>
#     <tr>
#       <th id="T_18745_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_18745_row9_col0" class="data row9 col0" >0.4007</td>
#       <td id="T_18745_row9_col1" class="data row9 col1" >0.8981</td>
#       <td id="T_18745_row9_col2" class="data row9 col2" >0.4007</td>
#       <td id="T_18745_row9_col3" class="data row9 col3" >0.4329</td>
#       <td id="T_18745_row9_col4" class="data row9 col4" >0.4058</td>
#       <td id="T_18745_row9_col5" class="data row9 col5" >0.3452</td>
#       <td id="T_18745_row9_col6" class="data row9 col6" >0.3473</td>
#     </tr>
#     <tr>
#       <th id="T_18745_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_18745_row10_col0" class="data row10 col0" >0.4014</td>
#       <td id="T_18745_row10_col1" class="data row10 col1" >0.8985</td>
#       <td id="T_18745_row10_col2" class="data row10 col2" >0.4014</td>
#       <td id="T_18745_row10_col3" class="data row10 col3" >0.4460</td>
#       <td id="T_18745_row10_col4" class="data row10 col4" >0.4006</td>
#       <td id="T_18745_row10_col5" class="data row10 col5" >0.3452</td>
#       <td id="T_18745_row10_col6" class="data row10 col6" >0.3480</td>
#     </tr>
#     <tr>
#       <th id="T_18745_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_18745_row11_col0" class="data row11 col0" >0.0013</td>
#       <td id="T_18745_row11_col1" class="data row11 col1" >0.0007</td>
#       <td id="T_18745_row11_col2" class="data row11 col2" >0.0013</td>
#       <td id="T_18745_row11_col3" class="data row11 col3" >0.0081</td>
#       <td id="T_18745_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
# Optimize and tune model using custom grid and GridSearchCV
params = {'max_depth': [None, 5, 10, 15],
          'n_estimators': [100, 200, 300],
          'criterion': ['gini', 'entropy', 'log_loss']
}

random_forest_model_tuned = tune_model(random_forest_model, custom_grid=params, search_library='scikit-learn', search_algorithm='grid')
# Out:
# <style type="text/css">
# #T_cae37_row10_col0, #T_cae37_row10_col1, #T_cae37_row10_col2, #T_cae37_row10_col3, #T_cae37_row10_col4, #T_cae37_row10_col5, #T_cae37_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_cae37">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cae37_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_cae37_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_cae37_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_cae37_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_cae37_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_cae37_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_cae37_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cae37_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cae37_row0_col0" class="data row0 col0" >0.4017</td>
#       <td id="T_cae37_row0_col1" class="data row0 col1" >0.8990</td>
#       <td id="T_cae37_row0_col2" class="data row0 col2" >0.4017</td>
#       <td id="T_cae37_row0_col3" class="data row0 col3" >0.4443</td>
#       <td id="T_cae37_row0_col4" class="data row0 col4" >0.3998</td>
#       <td id="T_cae37_row0_col5" class="data row0 col5" >0.3451</td>
#       <td id="T_cae37_row0_col6" class="data row0 col6" >0.3479</td>
#     </tr>
#     <tr>
#       <th id="T_cae37_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cae37_row1_col0" class="data row1 col0" >0.4015</td>
#       <td id="T_cae37_row1_col1" class="data row1 col1" >0.8977</td>
#       <td id="T_cae37_row1_col2" class="data row1 col2" >0.4015</td>
#       <td id="T_cae37_row1_col3" class="data row1 col3" >0.4406</td>
#       <td id="T_cae37_row1_col4" class="data row1 col4" >0.3973</td>
#       <td id="T_cae37_row1_col5" class="data row1 col5" >0.3443</td>
#       <td id="T_cae37_row1_col6" class="data row1 col6" >0.3473</td>
#     </tr>
#     <tr>
#       <th id="T_cae37_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cae37_row2_col0" class="data row2 col0" >0.4019</td>
#       <td id="T_cae37_row2_col1" class="data row2 col1" >0.8993</td>
#       <td id="T_cae37_row2_col2" class="data row2 col2" >0.4019</td>
#       <td id="T_cae37_row2_col3" class="data row2 col3" >0.4647</td>
#       <td id="T_cae37_row2_col4" class="data row2 col4" >0.4059</td>
#       <td id="T_cae37_row2_col5" class="data row2 col5" >0.3465</td>
#       <td id="T_cae37_row2_col6" class="data row2 col6" >0.3501</td>
#     </tr>
#     <tr>
#       <th id="T_cae37_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cae37_row3_col0" class="data row3 col0" >0.4040</td>
#       <td id="T_cae37_row3_col1" class="data row3 col1" >0.8996</td>
#       <td id="T_cae37_row3_col2" class="data row3 col2" >0.4040</td>
#       <td id="T_cae37_row3_col3" class="data row3 col3" >0.4397</td>
#       <td id="T_cae37_row3_col4" class="data row3 col4" >0.3995</td>
#       <td id="T_cae37_row3_col5" class="data row3 col5" >0.3465</td>
#       <td id="T_cae37_row3_col6" class="data row3 col6" >0.3492</td>
#     </tr>
#     <tr>
#       <th id="T_cae37_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cae37_row4_col0" class="data row4 col0" >0.4015</td>
#       <td id="T_cae37_row4_col1" class="data row4 col1" >0.8986</td>
#       <td id="T_cae37_row4_col2" class="data row4 col2" >0.4015</td>
#       <td id="T_cae37_row4_col3" class="data row4 col3" >0.4526</td>
#       <td id="T_cae37_row4_col4" class="data row4 col4" >0.3989</td>
#       <td id="T_cae37_row4_col5" class="data row4 col5" >0.3446</td>
#       <td id="T_cae37_row4_col6" class="data row4 col6" >0.3475</td>
#     </tr>
#     <tr>
#       <th id="T_cae37_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cae37_row5_col0" class="data row5 col0" >0.3988</td>
#       <td id="T_cae37_row5_col1" class="data row5 col1" >0.8981</td>
#       <td id="T_cae37_row5_col2" class="data row5 col2" >0.3988</td>
#       <td id="T_cae37_row5_col3" class="data row5 col3" >0.4433</td>
#       <td id="T_cae37_row5_col4" class="data row5 col4" >0.3964</td>
#       <td id="T_cae37_row5_col5" class="data row5 col5" >0.3415</td>
#       <td id="T_cae37_row5_col6" class="data row5 col6" >0.3440</td>
#     </tr>
#     <tr>
#       <th id="T_cae37_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cae37_row6_col0" class="data row6 col0" >0.4005</td>
#       <td id="T_cae37_row6_col1" class="data row6 col1" >0.8982</td>
#       <td id="T_cae37_row6_col2" class="data row6 col2" >0.4005</td>
#       <td id="T_cae37_row6_col3" class="data row6 col3" >0.4419</td>
#       <td id="T_cae37_row6_col4" class="data row6 col4" >0.4044</td>
#       <td id="T_cae37_row6_col5" class="data row6 col5" >0.3443</td>
#       <td id="T_cae37_row6_col6" class="data row6 col6" >0.3465</td>
#     </tr>
#     <tr>
#       <th id="T_cae37_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cae37_row7_col0" class="data row7 col0" >0.4014</td>
#       <td id="T_cae37_row7_col1" class="data row7 col1" >0.8995</td>
#       <td id="T_cae37_row7_col2" class="data row7 col2" >0.4014</td>
#       <td id="T_cae37_row7_col3" class="data row7 col3" >0.4521</td>
#       <td id="T_cae37_row7_col4" class="data row7 col4" >0.3970</td>
#       <td id="T_cae37_row7_col5" class="data row7 col5" >0.3452</td>
#       <td id="T_cae37_row7_col6" class="data row7 col6" >0.3481</td>
#     </tr>
#     <tr>
#       <th id="T_cae37_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cae37_row8_col0" class="data row8 col0" >0.4031</td>
#       <td id="T_cae37_row8_col1" class="data row8 col1" >0.8973</td>
#       <td id="T_cae37_row8_col2" class="data row8 col2" >0.4031</td>
#       <td id="T_cae37_row8_col3" class="data row8 col3" >0.4450</td>
#       <td id="T_cae37_row8_col4" class="data row8 col4" >0.3975</td>
#       <td id="T_cae37_row8_col5" class="data row8 col5" >0.3455</td>
#       <td id="T_cae37_row8_col6" class="data row8 col6" >0.3485</td>
#     </tr>
#     <tr>
#       <th id="T_cae37_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cae37_row9_col0" class="data row9 col0" >0.4010</td>
#       <td id="T_cae37_row9_col1" class="data row9 col1" >0.8982</td>
#       <td id="T_cae37_row9_col2" class="data row9 col2" >0.4010</td>
#       <td id="T_cae37_row9_col3" class="data row9 col3" >0.4388</td>
#       <td id="T_cae37_row9_col4" class="data row9 col4" >0.4055</td>
#       <td id="T_cae37_row9_col5" class="data row9 col5" >0.3451</td>
#       <td id="T_cae37_row9_col6" class="data row9 col6" >0.3472</td>
#     </tr>
#     <tr>
#       <th id="T_cae37_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_cae37_row10_col0" class="data row10 col0" >0.4015</td>
#       <td id="T_cae37_row10_col1" class="data row10 col1" >0.8985</td>
#       <td id="T_cae37_row10_col2" class="data row10 col2" >0.4015</td>
#       <td id="T_cae37_row10_col3" class="data row10 col3" >0.4463</td>
#       <td id="T_cae37_row10_col4" class="data row10 col4" >0.4002</td>
#       <td id="T_cae37_row10_col5" class="data row10 col5" >0.3449</td>
#       <td id="T_cae37_row10_col6" class="data row10 col6" >0.3476</td>
#     </tr>
#     <tr>
#       <th id="T_cae37_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_cae37_row11_col0" class="data row11 col0" >0.0013</td>
#       <td id="T_cae37_row11_col1" class="data row11 col1" >0.0007</td>
#       <td id="T_cae37_row11_col2" class="data row11 col2" >0.0013</td>
#       <td id="T_cae37_row11_col3" class="data row11 col3" >0.0076</td>
#       <td id="T_cae37_row11_col4
# Fitting 10 folds for each of 36 candidates, totalling 360 fits

# %% [markdown]
# As we can see, the model improved a little bit compared to the original model.

# %%
# Save tuned model
save_model(random_forest_model_tuned, 'S5_best_model_rf_tuned')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['diag_class_ref_S',
#                                               'diag_class_ref_H',
#                                               'health_issue_ou_med_ref',
#                                               'drg_rom_ref', 'sex_atr',
#                                               'drg_mdc_ref', 'drg_soi_ref',
#                                               'episode_duration',
#                                               'num_health_issues', 'drg_ref'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_...
#                   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                          class_weight=None, criterion='gini',
#                                          max_depth=15, max_features='sqrt',
#                                          max_leaf_nodes=None, max_samples=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          monotonic_cst=None, n_estimators=300,
#                                          n_jobs=-1, oob_score=False,
#                                          random_state=123, verbose=0,
#                                          warm_start=False))],
#           verbose=False),
#  'S5_best_model_rf_tuned_2.pkl')

# %%
# Load tuned model
random_forest_model_tuned = load_model("C:/Users/Cindy Chen/Desktop/TFG/plots/04/S5/S5_best_model_rf_tuned")

# %%
# Hyperparameters before tunning
print(random_forest_model)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, n_estimators=100, n_jobs=-1,
#                        oob_score=False, random_state=123, verbose=0,
#                        warm_start=False)

# %%
# Hyperparameters after tunning
print(random_forest_model_tuned)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=15, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, n_estimators=300, n_jobs=-1,
#                        oob_score=False, random_state=123, verbose=0,
#                        warm_start=False)

# %% [markdown]
# In this case, the hyperparameters max_depth and n_estimators changed.

# %% [markdown]
# ## **Predictions**
#
# Using the ```predict_model``` function, we can predicts the performance of the model on the test set.

# %%
# Predict on the test set
predict_model(random_forest_model_tuned)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a157c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a157c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a157c_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a157c_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a157c_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a157c_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a157c_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a157c_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a157c_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a157c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a157c_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_a157c_row0_col1" class="data row0 col1" >0.4032</td>
#       <td id="T_a157c_row0_col2" class="data row0 col2" >0.8985</td>
#       <td id="T_a157c_row0_col3" class="data row0 col3" >0.4032</td>
#       <td id="T_a157c_row0_col4" class="data row0 col4" >0.4500</td>
#       <td id="T_a157c_row0_col5" class="data row0 col5" >0.3991</td>
#       <td id="T_a157c_row0_col6" class="data row0 col6" >0.3457</td>
#       <td id="T_a157c_row0_col7" class="data row0 col7" >0.3484</td>
#     </tr>
#   </tbody>
# </table>
#          diag_class_ref_S  diag_class_ref_H  health_issue_ou_med_ref  \
# 218191                1.0               0.0                 9.533010
# 863976                1.0               0.0                13.740342
# 961023                1.0               0.0                10.077813
# 916955                1.0               0.0                14.636505
# 1013913               1.0               0.0                 9.321969
# ...                   ...               ...                      ...
# 842210                1.0               0.0                 9.321969
# 999667                1.0               0.0                 9.520975
# 323441                1.0               0.0                10.600161
# 882856                1.0               0.0                 9.377646
# 586894                1.0               0.0                 9.654046
#
#          drg_rom_ref  sex_atr  drg_mdc_ref  drg_soi_ref  episode_duration  \
# 218191           2.0      2.0          6.0          3.0       1358.753296
# 863976           4.0      2.0          7.0          4.0       1651.416626
# 961023           2.0      1.0          9.0          2.0        355.107513
# 916955           2.0      2.0         21.0          1.0        116.547226
# 1013913          2.0      2.0          6.0          3.0       1358.753296
# ...              ...      ...          ...          ...               ...
# 842210           3.0      1.0          7.0          4.0       1401.687744
# 999667           3.0      2.0         17.0          4.0       1512.166626
# 323441           2.0      2.0          6.0          3.0       1358.753296
# 882856           4.0      1.0          7.0          4.0       2222.074951
# 586894           2.0      2.0         11.0          3.0        732.129456
#
#          num_health_issues  drg_ref  icd10_capitulo  prediction_label  \
# 218191                 8.0    231.0               1                14
# 863976                 9.0    260.0              12                17
# 961023                 7.0    385.0              14                14
# 916955                 3.0    793.0              14                14
# 1013913                8.0    231.0              16                15
# ...                    ...      ...             ...               ...
# 842210                 8.0    284.0              14                13
# 999667                 3.0      7.0              14                17
# 323441                 8.0    231.0               1                16
# 882856                 5.0    260.0              15                12
# 586894                 7.0    440.0              13                 0
#
#          prediction_score
# 218191             0.2197
# 863976             0.3415
# 961023             0.9998
# 916955             0.9934
# 1013913            0.2088
# ...                   ...
# 842210             0.1306
# 999667             0.1785
# 323441             0.2055
# 882856             0.1510
# 586894             0.2159
#
# [313796 rows x 13 columns]

# %%
# Get the performance metrics
pull()
# Out:
#                       Model  Accuracy     AUC  Recall  Prec.      F1   Kappa  \
# 0  Random Forest Classifier    0.4032  0.8985  0.4032   0.45  0.3991  0.3457
#
#       MCC
# 0  0.3484

# %% [markdown]
# ## **Analyse Model**
#
# Plots to analyse the performance of the model on the test set.

# %% [markdown]
# ### **Confusion Matrix**

# %%
# Confusion Matrix
plt.figure(figsize=(25, 25))
plot_model(random_forest_model_tuned, plot = 'confusion_matrix') # save=True, use_train_data=False

# %% [markdown]
# ### **Area Under the Curve (AUC)**

# %%
# Area Under the Curve (AUC)
plt.figure(figsize=(25, 25))
plot_model(random_forest_model_tuned, plot = 'auc') # save=True

# %% [markdown]
# ### **Class Prediction Error**

# %%
# Class Prediction Error
plt.figure(figsize=(10, 5))
plot_model(random_forest_model_tuned, plot = 'error') # save=True

# %% [markdown]
# ### **Classification Report**

# %%
# Classification Report
plt.figure(figsize=(10, 10))
plot_model(random_forest_model_tuned, plot = 'class_report') # save=True
