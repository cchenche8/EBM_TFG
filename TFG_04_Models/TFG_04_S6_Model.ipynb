# %% [markdown]
# # **TFG**
#
# ***Machine Learning-Based Classification of Hospital Discharge Diagnoses Using SNOMED-CT Encoded Health Problems and Clinical Data***
#
# Cindy Chen
#
# Universitat de Barcelona
#
# 2024-2025

# %%
# Import modules 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display 
import gradio as gr
import os
from pycaret.classification import *
from pycaret.classification import plot_model
from pycaret.classification import predict_model, pull, load_model

# %matplotlib inline

# %% [markdown]
# ## **Data Importation**
#
# Import Subset 6 to find the best model, train the model, tune it and evaluate.

# %%
# Import data
data = pd.read_csv("C:/Users/Cindy Chen/Desktop/TFG/data/04_data/subset_6.csv")
data
# Out:
#          episode_duration  care_level_duration  drg_mdc_ref   age  \
# 0              706.924438           706.924438         11.0  81.0
# 1              287.425842           146.750000         16.0  47.0
# 2             2222.074951          1703.783569          7.0  73.0
# 3             1358.753296           433.244171          6.0  74.0
# 4             1358.753296           481.936676          6.0  74.0
# ...                   ...                  ...          ...   ...
# 1045979       1842.586670             2.855278         18.0  67.0
# 1045980        163.000000            94.935280          7.0  77.0
# 1045981       1512.166626           107.043053         17.0  45.0
# 1045982       1311.468872          1306.877197          8.0  54.0
# 1045983        904.000000            55.612221         17.0  73.0
#
#          snomed_code  drg_ref  drg_weight  diag_class_ref_S  \
# 0        240131006.0    469.0      1.7913               1.0
# 1        109989006.0    662.0      0.9884               1.0
# 2        439740005.0    260.0      5.9280               1.0
# 3        433146000.0    231.0      2.3206               1.0
# 4        307496006.0    231.0      2.3206               1.0
# ...              ...      ...         ...               ...
# 1045979  409623005.0    710.0      4.4717               1.0
# 1045980  230690007.0    260.0      2.0237               1.0
# 1045981  307651005.0      7.0     17.9363               1.0
# 1045982   77493009.0    320.0      1.3415               0.0
# 1045983   51387008.0      7.0      9.0648               1.0
#
#          num_health_issues  clinical_records_result_num_mean  \
# 0                      3.0                         94.131577
# 1                      3.0                         68.900002
# 2                      5.0                        110.247528
# 3                      8.0                         36.254166
# 4                      8.0                         55.170731
# ...                    ...                               ...
# 1045979                4.0                         91.694443
# 1045980                2.0                         67.321426
# 1045981                3.0                         77.400002
# 1045982                1.0                         96.349998
# 1045983                5.0                         80.052635
#
#          health_issue_ou_med_ref  icd10_capitulo
# 0                      11.859204              17
# 1                      10.077813              17
# 2                       9.377647               1
# 3                      10.600160               9
# 4                      10.600160              16
# ...                          ...             ...
# 1045979                10.965332              14
# 1045980                12.826443              14
# 1045981                10.077813               1
# 1045982                 9.260414              15
# 1045983                10.077813              13
#
# [1045984 rows x 12 columns]

# %% [markdown]
# Setup the pycaret environment and select the target column, in our case is the 'icd10_capitulo' column. This function also splits the data into training (70%) and testing set (30%).

# %%
# Configuración del entorno de PyCaret
clf = setup(data=data, target='icd10_capitulo', session_id=123, verbose=True)
# Out:
# <style type="text/css">
# #T_50a2e_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_50a2e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50a2e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_50a2e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50a2e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_50a2e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_50a2e_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_50a2e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_50a2e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_50a2e_row1_col1" class="data row1 col1" >icd10_capitulo</td>
#     </tr>
#     <tr>
#       <th id="T_50a2e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_50a2e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_50a2e_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_50a2e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_50a2e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_50a2e_row3_col1" class="data row3 col1" >(1045984, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_50a2e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_50a2e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_50a2e_row4_col1" class="data row4 col1" >(1045984, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_50a2e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_50a2e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_50a2e_row5_col1" class="data row5 col1" >(732188, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_50a2e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_50a2e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_50a2e_row6_col1" class="data row6 col1" >(313796, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_50a2e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_50a2e_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_50a2e_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_50a2e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_50a2e_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_50a2e_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_50a2e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_50a2e_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_50a2e_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_50a2e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_50a2e_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_50a2e_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_50a2e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_50a2e_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_50a2e_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_50a2e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_50a2e_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_50a2e_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_50a2e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_50a2e_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_50a2e_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_50a2e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_50a2e_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_50a2e_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_50a2e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_50a2e_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_50a2e_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_50a2e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_50a2e_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_50a2e_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_50a2e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_50a2e_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_50a2e_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_50a2e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_50a2e_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_50a2e_row18_col1" class="data row18 col1" >2f56</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Get preprocessing pipeline
get_config('pipeline')
# Out:
# Pipeline(memory=FastMemory(location=C:\Users\CINDYC~1\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['episode_duration',
#                                              'care_level_duration',
#                                              'drg_mdc_ref', 'age',
#                                              'snomed_code', 'drg_ref',
#                                              'drg_weight', 'diag_class_ref_S',
#                                              'num_health_issues',
#                                              'clinical_records_result_num_mean',
#                                              'health_issue_ou_med_ref'],
#                                     t...SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='mean'))),
#                 ('categorical_imputer',
#                  TransformerWrapper(exclude=None, include=[],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='most_frequent')))],
#          verbose=False)

# %% [markdown]
# ## **Model Comparison**
#
# Using the ```compare_models``` function to compare the selected models: Logistic Regression, Decision Trees, Random Forest, XGBoost, SVM, KNN and MLP.
#
# This function trains and evaluates the performance of all estimators available in the model library using cross-validation. The output of this function is a scoring grid with average cross-validated scores.

# %%
# Compare models
model_comparison = compare_models(include=["lr", 'dt', 'rf', 'xgboost', 'svm', 'knn', 'mlp'])
# Out:
# <style type="text/css">
# #T_9e54a th {
#   text-align: left;
# }
# #T_9e54a_row0_col0, #T_9e54a_row0_col2, #T_9e54a_row1_col0, #T_9e54a_row1_col4, #T_9e54a_row1_col5, #T_9e54a_row1_col6, #T_9e54a_row1_col7, #T_9e54a_row2_col0, #T_9e54a_row2_col1, #T_9e54a_row2_col2, #T_9e54a_row2_col3, #T_9e54a_row2_col4, #T_9e54a_row2_col5, #T_9e54a_row2_col6, #T_9e54a_row2_col7, #T_9e54a_row3_col0, #T_9e54a_row3_col1, #T_9e54a_row3_col2, #T_9e54a_row3_col3, #T_9e54a_row3_col4, #T_9e54a_row3_col5, #T_9e54a_row3_col6, #T_9e54a_row3_col7, #T_9e54a_row4_col0, #T_9e54a_row4_col1, #T_9e54a_row4_col2, #T_9e54a_row4_col3, #T_9e54a_row4_col4, #T_9e54a_row4_col5, #T_9e54a_row4_col6, #T_9e54a_row4_col7, #T_9e54a_row5_col0, #T_9e54a_row5_col1, #T_9e54a_row5_col2, #T_9e54a_row5_col3, #T_9e54a_row5_col4, #T_9e54a_row5_col5, #T_9e54a_row5_col6, #T_9e54a_row5_col7, #T_9e54a_row6_col0, #T_9e54a_row6_col1, #T_9e54a_row6_col2, #T_9e54a_row6_col3, #T_9e54a_row6_col4, #T_9e54a_row6_col5, #T_9e54a_row6_col6, #T_9e54a_row6_col7 {
#   text-align: left;
# }
# #T_9e54a_row0_col1, #T_9e54a_row0_col3, #T_9e54a_row0_col4, #T_9e54a_row0_col5, #T_9e54a_row0_col6, #T_9e54a_row0_col7, #T_9e54a_row1_col1, #T_9e54a_row1_col2, #T_9e54a_row1_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_9e54a_row0_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_9e54a_row1_col8, #T_9e54a_row2_col8, #T_9e54a_row3_col8, #T_9e54a_row4_col8, #T_9e54a_row5_col8, #T_9e54a_row6_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_9e54a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e54a_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9e54a_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_9e54a_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_9e54a_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_9e54a_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_9e54a_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_9e54a_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_9e54a_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_9e54a_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e54a_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_9e54a_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_9e54a_row0_col1" class="data row0 col1" >0.4422</td>
#       <td id="T_9e54a_row0_col2" class="data row0 col2" >0.9050</td>
#       <td id="T_9e54a_row0_col3" class="data row0 col3" >0.4422</td>
#       <td id="T_9e54a_row0_col4" class="data row0 col4" >0.4424</td>
#       <td id="T_9e54a_row0_col5" class="data row0 col5" >0.4420</td>
#       <td id="T_9e54a_row0_col6" class="data row0 col6" >0.3832</td>
#       <td id="T_9e54a_row0_col7" class="data row0 col7" >0.3833</td>
#       <td id="T_9e54a_row0_col8" class="data row0 col8" >0.9560</td>
#     </tr>
#     <tr>
#       <th id="T_9e54a_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_9e54a_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_9e54a_row1_col1" class="data row1 col1" >0.4422</td>
#       <td id="T_9e54a_row1_col2" class="data row1 col2" >0.9054</td>
#       <td id="T_9e54a_row1_col3" class="data row1 col3" >0.4422</td>
#       <td id="T_9e54a_row1_col4" class="data row1 col4" >0.4410</td>
#       <td id="T_9e54a_row1_col5" class="data row1 col5" >0.4413</td>
#       <td id="T_9e54a_row1_col6" class="data row1 col6" >0.3829</td>
#       <td id="T_9e54a_row1_col7" class="data row1 col7" >0.3829</td>
#       <td id="T_9e54a_row1_col8" class="data row1 col8" >26.3730</td>
#     </tr>
#     <tr>
#       <th id="T_9e54a_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_9e54a_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_9e54a_row2_col1" class="data row2 col1" >0.4268</td>
#       <td id="T_9e54a_row2_col2" class="data row2 col2" >0.9021</td>
#       <td id="T_9e54a_row2_col3" class="data row2 col3" >0.4268</td>
#       <td id="T_9e54a_row2_col4" class="data row2 col4" >0.4413</td>
#       <td id="T_9e54a_row2_col5" class="data row2 col5" >0.4311</td>
#       <td id="T_9e54a_row2_col6" class="data row2 col6" >0.3710</td>
#       <td id="T_9e54a_row2_col7" class="data row2 col7" >0.3716</td>
#       <td id="T_9e54a_row2_col8" class="data row2 col8" >47.2330</td>
#     </tr>
#     <tr>
#       <th id="T_9e54a_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_9e54a_row3_col0" class="data row3 col0" >K Neighbors Classifier</td>
#       <td id="T_9e54a_row3_col1" class="data row3 col1" >0.4099</td>
#       <td id="T_9e54a_row3_col2" class="data row3 col2" >0.8032</td>
#       <td id="T_9e54a_row3_col3" class="data row3 col3" >0.4099</td>
#       <td id="T_9e54a_row3_col4" class="data row3 col4" >0.4242</td>
#       <td id="T_9e54a_row3_col5" class="data row3 col5" >0.4137</td>
#       <td id="T_9e54a_row3_col6" class="data row3 col6" >0.3479</td>
#       <td id="T_9e54a_row3_col7" class="data row3 col7" >0.3486</td>
#       <td id="T_9e54a_row3_col8" class="data row3 col8" >3.9450</td>
#     </tr>
#     <tr>
#       <th id="T_9e54a_level0_row4" class="row_heading level0 row4" >mlp</th>
#       <td id="T_9e54a_row4_col0" class="data row4 col0" >MLP Classifier</td>
#       <td id="T_9e54a_row4_col1" class="data row4 col1" >0.2026</td>
#       <td id="T_9e54a_row4_col2" class="data row4 col2" >0.5000</td>
#       <td id="T_9e54a_row4_col3" class="data row4 col3" >0.2026</td>
#       <td id="T_9e54a_row4_col4" class="data row4 col4" >0.0411</td>
#       <td id="T_9e54a_row4_col5" class="data row4 col5" >0.0683</td>
#       <td id="T_9e54a_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_9e54a_row4_col7" class="data row4 col7" >0.0000</td>
#       <td id="T_9e54a_row4_col8" class="data row4 col8" >9.3370</td>
#     </tr>
#     <tr>
#       <th id="T_9e54a_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_9e54a_row5_col0" class="data row5 col0" >Logistic Regression</td>
#       <td id="T_9e54a_row5_col1" class="data row5 col1" >0.2004</td>
#       <td id="T_9e54a_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_9e54a_row5_col3" class="data row5 col3" >0.2004</td>
#       <td id="T_9e54a_row5_col4" class="data row5 col4" >0.0409</td>
#       <td id="T_9e54a_row5_col5" class="data row5 col5" >0.0679</td>
#       <td id="T_9e54a_row5_col6" class="data row5 col6" >-0.0020</td>
#       <td id="T_9e54a_row5_col7" class="data row5 col7" >-0.0151</td>
#       <td id="T_9e54a_row5_col8" class="data row5 col8" >110.9370</td>
#     </tr>
#     <tr>
#       <th id="T_9e54a_level0_row6" class="row_heading level0 row6" >svm</th>
#       <td id="T_9e54a_row6_col0" class="data row6 col0" >SVM - Linear Kernel</td>
#       <td id="T_9e54a_row6_col1" class="data row6 col1" >0.0980</td>
#       <td id="T_9e54a_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_9e54a_row6_col3" class="data row6 col3" >0.0980</td>
#       <td id="T_9e54a_row6_col4" class="data row6 col4" >0.0155</td>
#       <td id="T_9e54a_row6_col5" class="data row6 col5" >0.0261</td>
#       <td id="T_9e54a_row6_col6" class="data row6 col6" >0.0002</td>
#       <td id="T_9e54a_row6_col7" class="data row6 col7" >0.0004</td>
#       <td id="T_9e54a_row6_col8" class="data row6 col8" >97.4230</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Save results table
model_comparison_df = pull()
model_comparison_df.to_csv('S6_model_comparison_df.csv', index=False)

# Save best_model
save_model(model_comparison, 'S6_model_comparison')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['episode_duration',
#                                               'care_level_duration',
#                                               'drg_mdc_ref', 'age',
#                                               'snomed_code', 'drg_ref',
#                                               'drg_weight', 'diag_class_ref_S',
#                                               'num_health_issues',
#                                               'clinical_records_result_num_mean',
#                                               'health_issue_ou_med_ref'],
#                                      transformer=SimpleImputer(add_indicator=Fals...
#                                                                missing_values=nan,
#                                                                strategy='most_frequent'))),
#                  ('trained_model',
#                   DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                          criterion='gini', max_depth=None,
#                                          max_features=None, max_leaf_nodes=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          monotonic_cst=None, random_state=123,
#                                          splitter='best'))],
#           verbose=False),
#  'S6_model_comparison.pkl')

# %% [markdown]
# ## **Best Model**
#
# Once we have compared the different models, we select the best one. Then using the ```create_model``` function we train and evaluate the performance of the model using cross-validation. By default, it uses the 10 fold.

# %%
# Model evaluation: cross validation 10 folds
decision_tree_model = create_model('dt')  
evaluate_model(decision_tree_model)
# Out:
# <style type="text/css">
# #T_523a0_row10_col0, #T_523a0_row10_col1, #T_523a0_row10_col2, #T_523a0_row10_col3, #T_523a0_row10_col4, #T_523a0_row10_col5, #T_523a0_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_523a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_523a0_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_523a0_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_523a0_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_523a0_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_523a0_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_523a0_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_523a0_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_523a0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_523a0_row0_col0" class="data row0 col0" >0.4431</td>
#       <td id="T_523a0_row0_col1" class="data row0 col1" >0.9054</td>
#       <td id="T_523a0_row0_col2" class="data row0 col2" >0.4431</td>
#       <td id="T_523a0_row0_col3" class="data row0 col3" >0.4435</td>
#       <td id="T_523a0_row0_col4" class="data row0 col4" >0.4430</td>
#       <td id="T_523a0_row0_col5" class="data row0 col5" >0.3842</td>
#       <td id="T_523a0_row0_col6" class="data row0 col6" >0.3842</td>
#     </tr>
#     <tr>
#       <th id="T_523a0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_523a0_row1_col0" class="data row1 col0" >0.4381</td>
#       <td id="T_523a0_row1_col1" class="data row1 col1" >0.9041</td>
#       <td id="T_523a0_row1_col2" class="data row1 col2" >0.4381</td>
#       <td id="T_523a0_row1_col3" class="data row1 col3" >0.4381</td>
#       <td id="T_523a0_row1_col4" class="data row1 col4" >0.4377</td>
#       <td id="T_523a0_row1_col5" class="data row1 col5" >0.3788</td>
#       <td id="T_523a0_row1_col6" class="data row1 col6" >0.3788</td>
#     </tr>
#     <tr>
#       <th id="T_523a0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_523a0_row2_col0" class="data row2 col0" >0.4432</td>
#       <td id="T_523a0_row2_col1" class="data row2 col1" >0.9059</td>
#       <td id="T_523a0_row2_col2" class="data row2 col2" >0.4432</td>
#       <td id="T_523a0_row2_col3" class="data row2 col3" >0.4425</td>
#       <td id="T_523a0_row2_col4" class="data row2 col4" >0.4424</td>
#       <td id="T_523a0_row2_col5" class="data row2 col5" >0.3843</td>
#       <td id="T_523a0_row2_col6" class="data row2 col6" >0.3844</td>
#     </tr>
#     <tr>
#       <th id="T_523a0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_523a0_row3_col0" class="data row3 col0" >0.4455</td>
#       <td id="T_523a0_row3_col1" class="data row3 col1" >0.9058</td>
#       <td id="T_523a0_row3_col2" class="data row3 col2" >0.4455</td>
#       <td id="T_523a0_row3_col3" class="data row3 col3" >0.4461</td>
#       <td id="T_523a0_row3_col4" class="data row3 col4" >0.4454</td>
#       <td id="T_523a0_row3_col5" class="data row3 col5" >0.3871</td>
#       <td id="T_523a0_row3_col6" class="data row3 col6" >0.3872</td>
#     </tr>
#     <tr>
#       <th id="T_523a0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_523a0_row4_col0" class="data row4 col0" >0.4438</td>
#       <td id="T_523a0_row4_col1" class="data row4 col1" >0.9054</td>
#       <td id="T_523a0_row4_col2" class="data row4 col2" >0.4438</td>
#       <td id="T_523a0_row4_col3" class="data row4 col3" >0.4445</td>
#       <td id="T_523a0_row4_col4" class="data row4 col4" >0.4439</td>
#       <td id="T_523a0_row4_col5" class="data row4 col5" >0.3849</td>
#       <td id="T_523a0_row4_col6" class="data row4 col6" >0.3850</td>
#     </tr>
#     <tr>
#       <th id="T_523a0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_523a0_row5_col0" class="data row5 col0" >0.4427</td>
#       <td id="T_523a0_row5_col1" class="data row5 col1" >0.9046</td>
#       <td id="T_523a0_row5_col2" class="data row5 col2" >0.4427</td>
#       <td id="T_523a0_row5_col3" class="data row5 col3" >0.4445</td>
#       <td id="T_523a0_row5_col4" class="data row5 col4" >0.4432</td>
#       <td id="T_523a0_row5_col5" class="data row5 col5" >0.3840</td>
#       <td id="T_523a0_row5_col6" class="data row5 col6" >0.3840</td>
#     </tr>
#     <tr>
#       <th id="T_523a0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_523a0_row6_col0" class="data row6 col0" >0.4398</td>
#       <td id="T_523a0_row6_col1" class="data row6 col1" >0.9045</td>
#       <td id="T_523a0_row6_col2" class="data row6 col2" >0.4398</td>
#       <td id="T_523a0_row6_col3" class="data row6 col3" >0.4396</td>
#       <td id="T_523a0_row6_col4" class="data row6 col4" >0.4394</td>
#       <td id="T_523a0_row6_col5" class="data row6 col5" >0.3807</td>
#       <td id="T_523a0_row6_col6" class="data row6 col6" >0.3808</td>
#     </tr>
#     <tr>
#       <th id="T_523a0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_523a0_row7_col0" class="data row7 col0" >0.4435</td>
#       <td id="T_523a0_row7_col1" class="data row7 col1" >0.9059</td>
#       <td id="T_523a0_row7_col2" class="data row7 col2" >0.4435</td>
#       <td id="T_523a0_row7_col3" class="data row7 col3" >0.4434</td>
#       <td id="T_523a0_row7_col4" class="data row7 col4" >0.4431</td>
#       <td id="T_523a0_row7_col5" class="data row7 col5" >0.3845</td>
#       <td id="T_523a0_row7_col6" class="data row7 col6" >0.3846</td>
#     </tr>
#     <tr>
#       <th id="T_523a0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_523a0_row8_col0" class="data row8 col0" >0.4405</td>
#       <td id="T_523a0_row8_col1" class="data row8 col1" >0.9038</td>
#       <td id="T_523a0_row8_col2" class="data row8 col2" >0.4405</td>
#       <td id="T_523a0_row8_col3" class="data row8 col3" >0.4403</td>
#       <td id="T_523a0_row8_col4" class="data row8 col4" >0.4401</td>
#       <td id="T_523a0_row8_col5" class="data row8 col5" >0.3811</td>
#       <td id="T_523a0_row8_col6" class="data row8 col6" >0.3811</td>
#     </tr>
#     <tr>
#       <th id="T_523a0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_523a0_row9_col0" class="data row9 col0" >0.4419</td>
#       <td id="T_523a0_row9_col1" class="data row9 col1" >0.9045</td>
#       <td id="T_523a0_row9_col2" class="data row9 col2" >0.4419</td>
#       <td id="T_523a0_row9_col3" class="data row9 col3" >0.4418</td>
#       <td id="T_523a0_row9_col4" class="data row9 col4" >0.4415</td>
#       <td id="T_523a0_row9_col5" class="data row9 col5" >0.3826</td>
#       <td id="T_523a0_row9_col6" class="data row9 col6" >0.3827</td>
#     </tr>
#     <tr>
#       <th id="T_523a0_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_523a0_row10_col0" class="data row10 col0" >0.4422</td>
#       <td id="T_523a0_row10_col1" class="data row10 col1" >0.9050</td>
#       <td id="T_523a0_row10_col2" class="data row10 col2" >0.4422</td>
#       <td id="T_523a0_row10_col3" class="data row10 col3" >0.4424</td>
#       <td id="T_523a0_row10_col4" class="data row10 col4" >0.4420</td>
#       <td id="T_523a0_row10_col5" class="data row10 col5" >0.3832</td>
#       <td id="T_523a0_row10_col6" class="data row10 col6" >0.3833</td>
#     </tr>
#     <tr>
#       <th id="T_523a0_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_523a0_row11_col0" class="data row11 col0" >0.0021</td>
#       <td id="T_523a0_row11_col1" class="data row11 col1" >0.0007</td>
#       <td id="T_523a0_row11_col2" class="data row11 col2" >0.0021</td>
#       <td id="T_523a0_row11_col3" class="data row11 col3" >0.0024</td>
#       <td id="T_523a0_row11_col4
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# Save model
save_model(decision_tree_model, 'S6_best_model_dt')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['episode_duration',
#                                               'care_level_duration',
#                                               'drg_mdc_ref', 'age',
#                                               'snomed_code', 'drg_ref',
#                                               'drg_weight', 'diag_class_ref_S',
#                                               'num_health_issues',
#                                               'clinical_records_result_num_mean',
#                                               'health_issue_ou_med_ref'],
#                                      transformer=SimpleImputer(add_indicator=Fals...
#                                                                missing_values=nan,
#                                                                strategy='most_frequent'))),
#                  ('trained_model',
#                   DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                          criterion='gini', max_depth=None,
#                                          max_features=None, max_leaf_nodes=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          monotonic_cst=None, random_state=123,
#                                          splitter='best'))],
#           verbose=False),
#  'S6_best_model_dt.pkl')

# %%
# Load model
decision_tree_model = load_model("C:/Users/Cindy Chen/Desktop/TFG/plots/04/S6/S6_best_model_dt")
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# ## **Optimize and Tune Model**
#
# The ```tune_model``` function tunes the hyperparameters of the model. The output of this function is a scoring grid with cross-validated scores by fold.
#
# By default, it uses RandomGridSearch from the sklearn and the number of iterations (n_iter) is set to 10.

# %%
# Optimize and tune model using Random Grid Search 
decision_tree_model_tuned = tune_model(decision_tree_model)
# Out:
# <style type="text/css">
# #T_cb3d5_row10_col0, #T_cb3d5_row10_col1, #T_cb3d5_row10_col2, #T_cb3d5_row10_col3, #T_cb3d5_row10_col4, #T_cb3d5_row10_col5, #T_cb3d5_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_cb3d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb3d5_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_cb3d5_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_cb3d5_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_cb3d5_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_cb3d5_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_cb3d5_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_cb3d5_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb3d5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb3d5_row0_col0" class="data row0 col0" >0.4205</td>
#       <td id="T_cb3d5_row0_col1" class="data row0 col1" >0.9015</td>
#       <td id="T_cb3d5_row0_col2" class="data row0 col2" >0.4205</td>
#       <td id="T_cb3d5_row0_col3" class="data row0 col3" >0.4273</td>
#       <td id="T_cb3d5_row0_col4" class="data row0 col4" >0.4210</td>
#       <td id="T_cb3d5_row0_col5" class="data row0 col5" >0.3601</td>
#       <td id="T_cb3d5_row0_col6" class="data row0 col6" >0.3605</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cb3d5_row1_col0" class="data row1 col0" >0.4229</td>
#       <td id="T_cb3d5_row1_col1" class="data row1 col1" >0.9014</td>
#       <td id="T_cb3d5_row1_col2" class="data row1 col2" >0.4229</td>
#       <td id="T_cb3d5_row1_col3" class="data row1 col3" >0.4232</td>
#       <td id="T_cb3d5_row1_col4" class="data row1 col4" >0.4221</td>
#       <td id="T_cb3d5_row1_col5" class="data row1 col5" >0.3619</td>
#       <td id="T_cb3d5_row1_col6" class="data row1 col6" >0.3621</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cb3d5_row2_col0" class="data row2 col0" >0.4215</td>
#       <td id="T_cb3d5_row2_col1" class="data row2 col1" >0.9009</td>
#       <td id="T_cb3d5_row2_col2" class="data row2 col2" >0.4215</td>
#       <td id="T_cb3d5_row2_col3" class="data row2 col3" >0.4178</td>
#       <td id="T_cb3d5_row2_col4" class="data row2 col4" >0.4174</td>
#       <td id="T_cb3d5_row2_col5" class="data row2 col5" >0.3572</td>
#       <td id="T_cb3d5_row2_col6" class="data row2 col6" >0.3575</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cb3d5_row3_col0" class="data row3 col0" >0.4251</td>
#       <td id="T_cb3d5_row3_col1" class="data row3 col1" >0.9018</td>
#       <td id="T_cb3d5_row3_col2" class="data row3 col2" >0.4251</td>
#       <td id="T_cb3d5_row3_col3" class="data row3 col3" >0.4248</td>
#       <td id="T_cb3d5_row3_col4" class="data row3 col4" >0.4232</td>
#       <td id="T_cb3d5_row3_col5" class="data row3 col5" >0.3639</td>
#       <td id="T_cb3d5_row3_col6" class="data row3 col6" >0.3641</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cb3d5_row4_col0" class="data row4 col0" >0.4197</td>
#       <td id="T_cb3d5_row4_col1" class="data row4 col1" >0.8994</td>
#       <td id="T_cb3d5_row4_col2" class="data row4 col2" >0.4197</td>
#       <td id="T_cb3d5_row4_col3" class="data row4 col3" >0.4271</td>
#       <td id="T_cb3d5_row4_col4" class="data row4 col4" >0.4217</td>
#       <td id="T_cb3d5_row4_col5" class="data row4 col5" >0.3599</td>
#       <td id="T_cb3d5_row4_col6" class="data row4 col6" >0.3602</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cb3d5_row5_col0" class="data row5 col0" >0.4114</td>
#       <td id="T_cb3d5_row5_col1" class="data row5 col1" >0.8959</td>
#       <td id="T_cb3d5_row5_col2" class="data row5 col2" >0.4114</td>
#       <td id="T_cb3d5_row5_col3" class="data row5 col3" >0.4108</td>
#       <td id="T_cb3d5_row5_col4" class="data row5 col4" >0.4093</td>
#       <td id="T_cb3d5_row5_col5" class="data row5 col5" >0.3463</td>
#       <td id="T_cb3d5_row5_col6" class="data row5 col6" >0.3465</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cb3d5_row6_col0" class="data row6 col0" >0.4200</td>
#       <td id="T_cb3d5_row6_col1" class="data row6 col1" >0.9006</td>
#       <td id="T_cb3d5_row6_col2" class="data row6 col2" >0.4200</td>
#       <td id="T_cb3d5_row6_col3" class="data row6 col3" >0.4206</td>
#       <td id="T_cb3d5_row6_col4" class="data row6 col4" >0.4182</td>
#       <td id="T_cb3d5_row6_col5" class="data row6 col5" >0.3594</td>
#       <td id="T_cb3d5_row6_col6" class="data row6 col6" >0.3597</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cb3d5_row7_col0" class="data row7 col0" >0.4238</td>
#       <td id="T_cb3d5_row7_col1" class="data row7 col1" >0.9019</td>
#       <td id="T_cb3d5_row7_col2" class="data row7 col2" >0.4238</td>
#       <td id="T_cb3d5_row7_col3" class="data row7 col3" >0.4284</td>
#       <td id="T_cb3d5_row7_col4" class="data row7 col4" >0.4245</td>
#       <td id="T_cb3d5_row7_col5" class="data row7 col5" >0.3625</td>
#       <td id="T_cb3d5_row7_col6" class="data row7 col6" >0.3627</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cb3d5_row8_col0" class="data row8 col0" >0.4164</td>
#       <td id="T_cb3d5_row8_col1" class="data row8 col1" >0.8992</td>
#       <td id="T_cb3d5_row8_col2" class="data row8 col2" >0.4164</td>
#       <td id="T_cb3d5_row8_col3" class="data row8 col3" >0.4197</td>
#       <td id="T_cb3d5_row8_col4" class="data row8 col4" >0.4153</td>
#       <td id="T_cb3d5_row8_col5" class="data row8 col5" >0.3559</td>
#       <td id="T_cb3d5_row8_col6" class="data row8 col6" >0.3564</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cb3d5_row9_col0" class="data row9 col0" >0.4195</td>
#       <td id="T_cb3d5_row9_col1" class="data row9 col1" >0.8999</td>
#       <td id="T_cb3d5_row9_col2" class="data row9 col2" >0.4195</td>
#       <td id="T_cb3d5_row9_col3" class="data row9 col3" >0.4356</td>
#       <td id="T_cb3d5_row9_col4" class="data row9 col4" >0.4222</td>
#       <td id="T_cb3d5_row9_col5" class="data row9 col5" >0.3605</td>
#       <td id="T_cb3d5_row9_col6" class="data row9 col6" >0.3613</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d5_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_cb3d5_row10_col0" class="data row10 col0" >0.4201</td>
#       <td id="T_cb3d5_row10_col1" class="data row10 col1" >0.9002</td>
#       <td id="T_cb3d5_row10_col2" class="data row10 col2" >0.4201</td>
#       <td id="T_cb3d5_row10_col3" class="data row10 col3" >0.4235</td>
#       <td id="T_cb3d5_row10_col4" class="data row10 col4" >0.4195</td>
#       <td id="T_cb3d5_row10_col5" class="data row10 col5" >0.3588</td>
#       <td id="T_cb3d5_row10_col6" class="data row10 col6" >0.3591</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d5_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_cb3d5_row11_col0" class="data row11 col0" >0.0037</td>
#       <td id="T_cb3d5_row11_col1" class="data row11 col1" >0.0017</td>
#       <td id="T_cb3d5_row11_col2" class="data row11 col2" >0.0037</td>
#       <td id="T_cb3d5_row11_col3" class="data row11 col3" >0.0064</td>
#       <td id="T_cb3d5_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# As we can see, the Random Grid Search didn't obtain better results than the original model, so let's try increasing the number of iterations to 100.

# %%
# Optimize and tune model using Random Grid Search and increasing the number of iterations
decision_tree_model_tuned = tune_model(decision_tree_model, n_iter=100) # chose_better=False
# Out:
# <style type="text/css">
# #T_d590b_row10_col0, #T_d590b_row10_col1, #T_d590b_row10_col2, #T_d590b_row10_col3, #T_d590b_row10_col4, #T_d590b_row10_col5, #T_d590b_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_d590b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d590b_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_d590b_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_d590b_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_d590b_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_d590b_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_d590b_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_d590b_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d590b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d590b_row0_col0" class="data row0 col0" >0.4326</td>
#       <td id="T_d590b_row0_col1" class="data row0 col1" >0.9043</td>
#       <td id="T_d590b_row0_col2" class="data row0 col2" >0.4326</td>
#       <td id="T_d590b_row0_col3" class="data row0 col3" >0.4336</td>
#       <td id="T_d590b_row0_col4" class="data row0 col4" >0.4325</td>
#       <td id="T_d590b_row0_col5" class="data row0 col5" >0.3729</td>
#       <td id="T_d590b_row0_col6" class="data row0 col6" >0.3730</td>
#     </tr>
#     <tr>
#       <th id="T_d590b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d590b_row1_col0" class="data row1 col0" >0.4297</td>
#       <td id="T_d590b_row1_col1" class="data row1 col1" >0.9032</td>
#       <td id="T_d590b_row1_col2" class="data row1 col2" >0.4297</td>
#       <td id="T_d590b_row1_col3" class="data row1 col3" >0.4327</td>
#       <td id="T_d590b_row1_col4" class="data row1 col4" >0.4304</td>
#       <td id="T_d590b_row1_col5" class="data row1 col5" >0.3698</td>
#       <td id="T_d590b_row1_col6" class="data row1 col6" >0.3699</td>
#     </tr>
#     <tr>
#       <th id="T_d590b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d590b_row2_col0" class="data row2 col0" >0.4305</td>
#       <td id="T_d590b_row2_col1" class="data row2 col1" >0.9047</td>
#       <td id="T_d590b_row2_col2" class="data row2 col2" >0.4305</td>
#       <td id="T_d590b_row2_col3" class="data row2 col3" >0.4334</td>
#       <td id="T_d590b_row2_col4" class="data row2 col4" >0.4313</td>
#       <td id="T_d590b_row2_col5" class="data row2 col5" >0.3711</td>
#       <td id="T_d590b_row2_col6" class="data row2 col6" >0.3712</td>
#     </tr>
#     <tr>
#       <th id="T_d590b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d590b_row3_col0" class="data row3 col0" >0.4360</td>
#       <td id="T_d590b_row3_col1" class="data row3 col1" >0.9050</td>
#       <td id="T_d590b_row3_col2" class="data row3 col2" >0.4360</td>
#       <td id="T_d590b_row3_col3" class="data row3 col3" >0.4343</td>
#       <td id="T_d590b_row3_col4" class="data row3 col4" >0.4345</td>
#       <td id="T_d590b_row3_col5" class="data row3 col5" >0.3761</td>
#       <td id="T_d590b_row3_col6" class="data row3 col6" >0.3762</td>
#     </tr>
#     <tr>
#       <th id="T_d590b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d590b_row4_col0" class="data row4 col0" >0.4345</td>
#       <td id="T_d590b_row4_col1" class="data row4 col1" >0.9039</td>
#       <td id="T_d590b_row4_col2" class="data row4 col2" >0.4345</td>
#       <td id="T_d590b_row4_col3" class="data row4 col3" >0.4327</td>
#       <td id="T_d590b_row4_col4" class="data row4 col4" >0.4329</td>
#       <td id="T_d590b_row4_col5" class="data row4 col5" >0.3753</td>
#       <td id="T_d590b_row4_col6" class="data row4 col6" >0.3754</td>
#     </tr>
#     <tr>
#       <th id="T_d590b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d590b_row5_col0" class="data row5 col0" >0.4302</td>
#       <td id="T_d590b_row5_col1" class="data row5 col1" >0.9036</td>
#       <td id="T_d590b_row5_col2" class="data row5 col2" >0.4302</td>
#       <td id="T_d590b_row5_col3" class="data row5 col3" >0.4353</td>
#       <td id="T_d590b_row5_col4" class="data row5 col4" >0.4321</td>
#       <td id="T_d590b_row5_col5" class="data row5 col5" >0.3714</td>
#       <td id="T_d590b_row5_col6" class="data row5 col6" >0.3715</td>
#     </tr>
#     <tr>
#       <th id="T_d590b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d590b_row6_col0" class="data row6 col0" >0.4296</td>
#       <td id="T_d590b_row6_col1" class="data row6 col1" >0.9035</td>
#       <td id="T_d590b_row6_col2" class="data row6 col2" >0.4296</td>
#       <td id="T_d590b_row6_col3" class="data row6 col3" >0.4308</td>
#       <td id="T_d590b_row6_col4" class="data row6 col4" >0.4298</td>
#       <td id="T_d590b_row6_col5" class="data row6 col5" >0.3701</td>
#       <td id="T_d590b_row6_col6" class="data row6 col6" >0.3702</td>
#     </tr>
#     <tr>
#       <th id="T_d590b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d590b_row7_col0" class="data row7 col0" >0.4339</td>
#       <td id="T_d590b_row7_col1" class="data row7 col1" >0.9051</td>
#       <td id="T_d590b_row7_col2" class="data row7 col2" >0.4339</td>
#       <td id="T_d590b_row7_col3" class="data row7 col3" >0.4354</td>
#       <td id="T_d590b_row7_col4" class="data row7 col4" >0.4337</td>
#       <td id="T_d590b_row7_col5" class="data row7 col5" >0.3737</td>
#       <td id="T_d590b_row7_col6" class="data row7 col6" >0.3739</td>
#     </tr>
#     <tr>
#       <th id="T_d590b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d590b_row8_col0" class="data row8 col0" >0.4298</td>
#       <td id="T_d590b_row8_col1" class="data row8 col1" >0.9025</td>
#       <td id="T_d590b_row8_col2" class="data row8 col2" >0.4298</td>
#       <td id="T_d590b_row8_col3" class="data row8 col3" >0.4295</td>
#       <td id="T_d590b_row8_col4" class="data row8 col4" >0.4292</td>
#       <td id="T_d590b_row8_col5" class="data row8 col5" >0.3701</td>
#       <td id="T_d590b_row8_col6" class="data row8 col6" >0.3702</td>
#     </tr>
#     <tr>
#       <th id="T_d590b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d590b_row9_col0" class="data row9 col0" >0.4334</td>
#       <td id="T_d590b_row9_col1" class="data row9 col1" >0.9036</td>
#       <td id="T_d590b_row9_col2" class="data row9 col2" >0.4334</td>
#       <td id="T_d590b_row9_col3" class="data row9 col3" >0.4335</td>
#       <td id="T_d590b_row9_col4" class="data row9 col4" >0.4329</td>
#       <td id="T_d590b_row9_col5" class="data row9 col5" >0.3739</td>
#       <td id="T_d590b_row9_col6" class="data row9 col6" >0.3739</td>
#     </tr>
#     <tr>
#       <th id="T_d590b_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_d590b_row10_col0" class="data row10 col0" >0.4320</td>
#       <td id="T_d590b_row10_col1" class="data row10 col1" >0.9039</td>
#       <td id="T_d590b_row10_col2" class="data row10 col2" >0.4320</td>
#       <td id="T_d590b_row10_col3" class="data row10 col3" >0.4331</td>
#       <td id="T_d590b_row10_col4" class="data row10 col4" >0.4319</td>
#       <td id="T_d590b_row10_col5" class="data row10 col5" >0.3724</td>
#       <td id="T_d590b_row10_col6" class="data row10 col6" >0.3725</td>
#     </tr>
#     <tr>
#       <th id="T_d590b_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_d590b_row11_col0" class="data row11 col0" >0.0022</td>
#       <td id="T_d590b_row11_col1" class="data row11 col1" >0.0008</td>
#       <td id="T_d590b_row11_col2" class="data row11 col2" >0.0022</td>
#       <td id="T_d590b_row11_col3" class="data row11 col3" >0.0017</td>
#       <td id="T_d590b_row11_col4
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# Even when we increase the number of iterations the model doesn't improve. So let's customise the grid and parameters using custom_grid.
#
# For decision trees, the hyperparameters decided to use are:
# - max_depth
# - min_samples_split
# - min_samples_leaf
# - criterion

# %%
# Optimize and tune model using custom grid and Random Grid Search
params = {'max_depth': [None, 3, 5, 10, 15],
          'min_samples_split': [2, 5, 10],
          'min_samples_leaf': [1, 2, 5],
          'criterion': ['gini', 'entropy', 'log_loss']
} 

decision_tree_model_tuned = tune_model(decision_tree_model, custom_grid=params) # chose_better=False
# Out:
# <style type="text/css">
# #T_6ad35_row10_col0, #T_6ad35_row10_col1, #T_6ad35_row10_col2, #T_6ad35_row10_col3, #T_6ad35_row10_col4, #T_6ad35_row10_col5, #T_6ad35_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_6ad35">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ad35_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_6ad35_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_6ad35_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_6ad35_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_6ad35_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_6ad35_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_6ad35_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ad35_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ad35_row0_col0" class="data row0 col0" >0.4432</td>
#       <td id="T_6ad35_row0_col1" class="data row0 col1" >0.9058</td>
#       <td id="T_6ad35_row0_col2" class="data row0 col2" >0.4432</td>
#       <td id="T_6ad35_row0_col3" class="data row0 col3" >0.4437</td>
#       <td id="T_6ad35_row0_col4" class="data row0 col4" >0.4431</td>
#       <td id="T_6ad35_row0_col5" class="data row0 col5" >0.3843</td>
#       <td id="T_6ad35_row0_col6" class="data row0 col6" >0.3844</td>
#     </tr>
#     <tr>
#       <th id="T_6ad35_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6ad35_row1_col0" class="data row1 col0" >0.4380</td>
#       <td id="T_6ad35_row1_col1" class="data row1 col1" >0.9045</td>
#       <td id="T_6ad35_row1_col2" class="data row1 col2" >0.4380</td>
#       <td id="T_6ad35_row1_col3" class="data row1 col3" >0.4379</td>
#       <td id="T_6ad35_row1_col4" class="data row1 col4" >0.4376</td>
#       <td id="T_6ad35_row1_col5" class="data row1 col5" >0.3786</td>
#       <td id="T_6ad35_row1_col6" class="data row1 col6" >0.3786</td>
#     </tr>
#     <tr>
#       <th id="T_6ad35_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6ad35_row2_col0" class="data row2 col0" >0.4429</td>
#       <td id="T_6ad35_row2_col1" class="data row2 col1" >0.9063</td>
#       <td id="T_6ad35_row2_col2" class="data row2 col2" >0.4429</td>
#       <td id="T_6ad35_row2_col3" class="data row2 col3" >0.4421</td>
#       <td id="T_6ad35_row2_col4" class="data row2 col4" >0.4421</td>
#       <td id="T_6ad35_row2_col5" class="data row2 col5" >0.3839</td>
#       <td id="T_6ad35_row2_col6" class="data row2 col6" >0.3840</td>
#     </tr>
#     <tr>
#       <th id="T_6ad35_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6ad35_row3_col0" class="data row3 col0" >0.4453</td>
#       <td id="T_6ad35_row3_col1" class="data row3 col1" >0.9061</td>
#       <td id="T_6ad35_row3_col2" class="data row3 col2" >0.4453</td>
#       <td id="T_6ad35_row3_col3" class="data row3 col3" >0.4458</td>
#       <td id="T_6ad35_row3_col4" class="data row3 col4" >0.4452</td>
#       <td id="T_6ad35_row3_col5" class="data row3 col5" >0.3869</td>
#       <td id="T_6ad35_row3_col6" class="data row3 col6" >0.3869</td>
#     </tr>
#     <tr>
#       <th id="T_6ad35_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6ad35_row4_col0" class="data row4 col0" >0.4439</td>
#       <td id="T_6ad35_row4_col1" class="data row4 col1" >0.9058</td>
#       <td id="T_6ad35_row4_col2" class="data row4 col2" >0.4439</td>
#       <td id="T_6ad35_row4_col3" class="data row4 col3" >0.4444</td>
#       <td id="T_6ad35_row4_col4" class="data row4 col4" >0.4439</td>
#       <td id="T_6ad35_row4_col5" class="data row4 col5" >0.3849</td>
#       <td id="T_6ad35_row4_col6" class="data row4 col6" >0.3850</td>
#     </tr>
#     <tr>
#       <th id="T_6ad35_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6ad35_row5_col0" class="data row5 col0" >0.4426</td>
#       <td id="T_6ad35_row5_col1" class="data row5 col1" >0.9051</td>
#       <td id="T_6ad35_row5_col2" class="data row5 col2" >0.4426</td>
#       <td id="T_6ad35_row5_col3" class="data row5 col3" >0.4443</td>
#       <td id="T_6ad35_row5_col4" class="data row5 col4" >0.4431</td>
#       <td id="T_6ad35_row5_col5" class="data row5 col5" >0.3838</td>
#       <td id="T_6ad35_row5_col6" class="data row5 col6" >0.3838</td>
#     </tr>
#     <tr>
#       <th id="T_6ad35_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6ad35_row6_col0" class="data row6 col0" >0.4398</td>
#       <td id="T_6ad35_row6_col1" class="data row6 col1" >0.9050</td>
#       <td id="T_6ad35_row6_col2" class="data row6 col2" >0.4398</td>
#       <td id="T_6ad35_row6_col3" class="data row6 col3" >0.4395</td>
#       <td id="T_6ad35_row6_col4" class="data row6 col4" >0.4393</td>
#       <td id="T_6ad35_row6_col5" class="data row6 col5" >0.3806</td>
#       <td id="T_6ad35_row6_col6" class="data row6 col6" >0.3806</td>
#     </tr>
#     <tr>
#       <th id="T_6ad35_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6ad35_row7_col0" class="data row7 col0" >0.4432</td>
#       <td id="T_6ad35_row7_col1" class="data row7 col1" >0.9063</td>
#       <td id="T_6ad35_row7_col2" class="data row7 col2" >0.4432</td>
#       <td id="T_6ad35_row7_col3" class="data row7 col3" >0.4431</td>
#       <td id="T_6ad35_row7_col4" class="data row7 col4" >0.4428</td>
#       <td id="T_6ad35_row7_col5" class="data row7 col5" >0.3841</td>
#       <td id="T_6ad35_row7_col6" class="data row7 col6" >0.3842</td>
#     </tr>
#     <tr>
#       <th id="T_6ad35_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6ad35_row8_col0" class="data row8 col0" >0.4405</td>
#       <td id="T_6ad35_row8_col1" class="data row8 col1" >0.9042</td>
#       <td id="T_6ad35_row8_col2" class="data row8 col2" >0.4405</td>
#       <td id="T_6ad35_row8_col3" class="data row8 col3" >0.4401</td>
#       <td id="T_6ad35_row8_col4" class="data row8 col4" >0.4400</td>
#       <td id="T_6ad35_row8_col5" class="data row8 col5" >0.3809</td>
#       <td id="T_6ad35_row8_col6" class="data row8 col6" >0.3810</td>
#     </tr>
#     <tr>
#       <th id="T_6ad35_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6ad35_row9_col0" class="data row9 col0" >0.4419</td>
#       <td id="T_6ad35_row9_col1" class="data row9 col1" >0.9049</td>
#       <td id="T_6ad35_row9_col2" class="data row9 col2" >0.4419</td>
#       <td id="T_6ad35_row9_col3" class="data row9 col3" >0.4418</td>
#       <td id="T_6ad35_row9_col4" class="data row9 col4" >0.4415</td>
#       <td id="T_6ad35_row9_col5" class="data row9 col5" >0.3827</td>
#       <td id="T_6ad35_row9_col6" class="data row9 col6" >0.3827</td>
#     </tr>
#     <tr>
#       <th id="T_6ad35_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6ad35_row10_col0" class="data row10 col0" >0.4421</td>
#       <td id="T_6ad35_row10_col1" class="data row10 col1" >0.9054</td>
#       <td id="T_6ad35_row10_col2" class="data row10 col2" >0.4421</td>
#       <td id="T_6ad35_row10_col3" class="data row10 col3" >0.4423</td>
#       <td id="T_6ad35_row10_col4" class="data row10 col4" >0.4419</td>
#       <td id="T_6ad35_row10_col5" class="data row10 col5" >0.3831</td>
#       <td id="T_6ad35_row10_col6" class="data row10 col6" >0.3831</td>
#     </tr>
#     <tr>
#       <th id="T_6ad35_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_6ad35_row11_col0" class="data row11 col0" >0.0020</td>
#       <td id="T_6ad35_row11_col1" class="data row11 col1" >0.0007</td>
#       <td id="T_6ad35_row11_col2" class="data row11 col2" >0.0020</td>
#       <td id="T_6ad35_row11_col3" class="data row11 col3" >0.0024</td>
#       <td id="T_6ad35_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %%
# Optimize and tune model using custom grid and GridSearchCV
params = {'max_depth': [None, 3, 5, 10, 15],
          'min_samples_split': [2, 5, 10],
          'min_samples_leaf': [1, 2, 5],
          'criterion': ['gini', 'entropy', 'log_loss']
}

decision_tree_model_tuned = tune_model(decision_tree_model, custom_grid=params, search_library='scikit-learn', search_algorithm='grid', choose_better=False)
# Out:
# <style type="text/css">
# #T_fd250_row10_col0, #T_fd250_row10_col1, #T_fd250_row10_col2, #T_fd250_row10_col3, #T_fd250_row10_col4, #T_fd250_row10_col5, #T_fd250_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_fd250">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd250_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_fd250_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_fd250_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_fd250_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_fd250_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_fd250_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_fd250_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd250_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fd250_row0_col0" class="data row0 col0" >0.4431</td>
#       <td id="T_fd250_row0_col1" class="data row0 col1" >0.9054</td>
#       <td id="T_fd250_row0_col2" class="data row0 col2" >0.4431</td>
#       <td id="T_fd250_row0_col3" class="data row0 col3" >0.4435</td>
#       <td id="T_fd250_row0_col4" class="data row0 col4" >0.4430</td>
#       <td id="T_fd250_row0_col5" class="data row0 col5" >0.3842</td>
#       <td id="T_fd250_row0_col6" class="data row0 col6" >0.3843</td>
#     </tr>
#     <tr>
#       <th id="T_fd250_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fd250_row1_col0" class="data row1 col0" >0.4381</td>
#       <td id="T_fd250_row1_col1" class="data row1 col1" >0.9041</td>
#       <td id="T_fd250_row1_col2" class="data row1 col2" >0.4381</td>
#       <td id="T_fd250_row1_col3" class="data row1 col3" >0.4382</td>
#       <td id="T_fd250_row1_col4" class="data row1 col4" >0.4378</td>
#       <td id="T_fd250_row1_col5" class="data row1 col5" >0.3788</td>
#       <td id="T_fd250_row1_col6" class="data row1 col6" >0.3789</td>
#     </tr>
#     <tr>
#       <th id="T_fd250_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fd250_row2_col0" class="data row2 col0" >0.4432</td>
#       <td id="T_fd250_row2_col1" class="data row2 col1" >0.9059</td>
#       <td id="T_fd250_row2_col2" class="data row2 col2" >0.4432</td>
#       <td id="T_fd250_row2_col3" class="data row2 col3" >0.4425</td>
#       <td id="T_fd250_row2_col4" class="data row2 col4" >0.4424</td>
#       <td id="T_fd250_row2_col5" class="data row2 col5" >0.3843</td>
#       <td id="T_fd250_row2_col6" class="data row2 col6" >0.3844</td>
#     </tr>
#     <tr>
#       <th id="T_fd250_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fd250_row3_col0" class="data row3 col0" >0.4455</td>
#       <td id="T_fd250_row3_col1" class="data row3 col1" >0.9058</td>
#       <td id="T_fd250_row3_col2" class="data row3 col2" >0.4455</td>
#       <td id="T_fd250_row3_col3" class="data row3 col3" >0.4461</td>
#       <td id="T_fd250_row3_col4" class="data row3 col4" >0.4454</td>
#       <td id="T_fd250_row3_col5" class="data row3 col5" >0.3871</td>
#       <td id="T_fd250_row3_col6" class="data row3 col6" >0.3872</td>
#     </tr>
#     <tr>
#       <th id="T_fd250_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fd250_row4_col0" class="data row4 col0" >0.4438</td>
#       <td id="T_fd250_row4_col1" class="data row4 col1" >0.9054</td>
#       <td id="T_fd250_row4_col2" class="data row4 col2" >0.4438</td>
#       <td id="T_fd250_row4_col3" class="data row4 col3" >0.4444</td>
#       <td id="T_fd250_row4_col4" class="data row4 col4" >0.4438</td>
#       <td id="T_fd250_row4_col5" class="data row4 col5" >0.3849</td>
#       <td id="T_fd250_row4_col6" class="data row4 col6" >0.3850</td>
#     </tr>
#     <tr>
#       <th id="T_fd250_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fd250_row5_col0" class="data row5 col0" >0.4427</td>
#       <td id="T_fd250_row5_col1" class="data row5 col1" >0.9046</td>
#       <td id="T_fd250_row5_col2" class="data row5 col2" >0.4427</td>
#       <td id="T_fd250_row5_col3" class="data row5 col3" >0.4444</td>
#       <td id="T_fd250_row5_col4" class="data row5 col4" >0.4432</td>
#       <td id="T_fd250_row5_col5" class="data row5 col5" >0.3839</td>
#       <td id="T_fd250_row5_col6" class="data row5 col6" >0.3840</td>
#     </tr>
#     <tr>
#       <th id="T_fd250_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fd250_row6_col0" class="data row6 col0" >0.4398</td>
#       <td id="T_fd250_row6_col1" class="data row6 col1" >0.9045</td>
#       <td id="T_fd250_row6_col2" class="data row6 col2" >0.4398</td>
#       <td id="T_fd250_row6_col3" class="data row6 col3" >0.4396</td>
#       <td id="T_fd250_row6_col4" class="data row6 col4" >0.4394</td>
#       <td id="T_fd250_row6_col5" class="data row6 col5" >0.3807</td>
#       <td id="T_fd250_row6_col6" class="data row6 col6" >0.3808</td>
#     </tr>
#     <tr>
#       <th id="T_fd250_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fd250_row7_col0" class="data row7 col0" >0.4435</td>
#       <td id="T_fd250_row7_col1" class="data row7 col1" >0.9059</td>
#       <td id="T_fd250_row7_col2" class="data row7 col2" >0.4435</td>
#       <td id="T_fd250_row7_col3" class="data row7 col3" >0.4435</td>
#       <td id="T_fd250_row7_col4" class="data row7 col4" >0.4431</td>
#       <td id="T_fd250_row7_col5" class="data row7 col5" >0.3845</td>
#       <td id="T_fd250_row7_col6" class="data row7 col6" >0.3846</td>
#     </tr>
#     <tr>
#       <th id="T_fd250_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fd250_row8_col0" class="data row8 col0" >0.4405</td>
#       <td id="T_fd250_row8_col1" class="data row8 col1" >0.9037</td>
#       <td id="T_fd250_row8_col2" class="data row8 col2" >0.4405</td>
#       <td id="T_fd250_row8_col3" class="data row8 col3" >0.4402</td>
#       <td id="T_fd250_row8_col4" class="data row8 col4" >0.4400</td>
#       <td id="T_fd250_row8_col5" class="data row8 col5" >0.3810</td>
#       <td id="T_fd250_row8_col6" class="data row8 col6" >0.3810</td>
#     </tr>
#     <tr>
#       <th id="T_fd250_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fd250_row9_col0" class="data row9 col0" >0.4419</td>
#       <td id="T_fd250_row9_col1" class="data row9 col1" >0.9045</td>
#       <td id="T_fd250_row9_col2" class="data row9 col2" >0.4419</td>
#       <td id="T_fd250_row9_col3" class="data row9 col3" >0.4418</td>
#       <td id="T_fd250_row9_col4" class="data row9 col4" >0.4415</td>
#       <td id="T_fd250_row9_col5" class="data row9 col5" >0.3826</td>
#       <td id="T_fd250_row9_col6" class="data row9 col6" >0.3827</td>
#     </tr>
#     <tr>
#       <th id="T_fd250_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_fd250_row10_col0" class="data row10 col0" >0.4422</td>
#       <td id="T_fd250_row10_col1" class="data row10 col1" >0.9050</td>
#       <td id="T_fd250_row10_col2" class="data row10 col2" >0.4422</td>
#       <td id="T_fd250_row10_col3" class="data row10 col3" >0.4424</td>
#       <td id="T_fd250_row10_col4" class="data row10 col4" >0.4420</td>
#       <td id="T_fd250_row10_col5" class="data row10 col5" >0.3832</td>
#       <td id="T_fd250_row10_col6" class="data row10 col6" >0.3833</td>
#     </tr>
#     <tr>
#       <th id="T_fd250_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_fd250_row11_col0" class="data row11 col0" >0.0021</td>
#       <td id="T_fd250_row11_col1" class="data row11 col1" >0.0008</td>
#       <td id="T_fd250_row11_col2" class="data row11 col2" >0.0021</td>
#       <td id="T_fd250_row11_col3" class="data row11 col3" >0.0023</td>
#       <td id="T_fd250_row11_col4
# Fitting 10 folds for each of 135 candidates, totalling 1350 fits

# %% [markdown]
# As we can see, the performance after tuning didn't improve much.

# %%
# Save tuned model
save_model(decision_tree_model_tuned, 'S6_best_model_dt_tuned')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['episode_duration',
#                                               'care_level_duration',
#                                               'drg_mdc_ref', 'age',
#                                               'snomed_code', 'drg_ref',
#                                               'drg_weight', 'diag_class_ref_S',
#                                               'num_health_issues',
#                                               'clinical_records_result_num_mean',
#                                               'health_issue_ou_med_ref'],
#                                      transformer=SimpleImputer(add_indicator=Fals...
#                                                                missing_values=nan,
#                                                                strategy='most_frequent'))),
#                  ('trained_model',
#                   DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                          criterion='entropy', max_depth=None,
#                                          max_features=None, max_leaf_nodes=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          monotonic_cst=None, random_state=123,
#                                          splitter='best'))],
#           verbose=False),
#  'S6_best_model_dt_tuned.pkl')

# %%
# Load tuned model
decision_tree_model_tuned = load_model("C:/Users/Cindy Chen/Desktop/TFG/plots/04/S6/S6_best_model_dt_tuned")

# %%
# Hyperparameters before tunning
print(decision_tree_model)
# Out:
# Pipeline(memory=FastMemory(location=C:\Users\CINDYC~1\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['episode_duration',
#                                              'care_level_duration',
#                                              'drg_mdc_ref', 'age',
#                                              'snomed_code', 'drg_ref',
#                                              'drg_weight', 'diag_class_ref_S',
#                                              'num_health_issues',
#                                              'clinical_records_result_num_mean',
#                                              'health_issue_ou_med_ref'],
#                                     t...
#                                                               missing_values=nan,
#                                                               strategy='most_frequent'))),
#                 ('trained_model',
#                  DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                         criterion='gini', max_depth=None,
#                                         max_features=None, max_leaf_nodes=None,
#                                         min_impurity_decrease=0.0,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         monotonic_cst=None, random_state=123,
#                                         splitter='best'))],
#          verbose=False)

# %%
# Hyperparameters after tunning
print(decision_tree_model_tuned)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, random_state=123, splitter='best')

# %% [markdown]
# In this case, the hyperparameter of criterion changed from gini to entropy.

# %% [markdown]
# ## **Predictions**
#
# Using the ```predict_model``` function, we can predicts the performance of the model on the test set.

# %%
predict_model(decision_tree_model_tuned)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a3175">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3175_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a3175_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a3175_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a3175_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a3175_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a3175_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a3175_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a3175_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3175_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a3175_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_a3175_row0_col1" class="data row0 col1" >0.4446</td>
#       <td id="T_a3175_row0_col2" class="data row0 col2" >0.9054</td>
#       <td id="T_a3175_row0_col3" class="data row0 col3" >0.4446</td>
#       <td id="T_a3175_row0_col4" class="data row0 col4" >0.4433</td>
#       <td id="T_a3175_row0_col5" class="data row0 col5" >0.4437</td>
#       <td id="T_a3175_row0_col6" class="data row0 col6" >0.3856</td>
#       <td id="T_a3175_row0_col7" class="data row0 col7" >0.3856</td>
#     </tr>
#   </tbody>
# </table>
#          episode_duration  care_level_duration  drg_mdc_ref   age  \
# 218191        1358.753296           181.709442          6.0  74.0
# 863976        1651.416626           789.266663          7.0  79.0
# 961023         355.107513           219.366394          9.0  56.0
# 916955         116.547226            46.750000         21.0  51.0
# 1013913       1358.753296           481.936676          6.0  74.0
# ...                   ...                  ...          ...   ...
# 842210        1401.687744           937.500000          7.0  41.0
# 999667        1512.166626           116.433334         17.0  45.0
# 323441        1358.753296           481.936676          6.0  74.0
# 882856        2222.074951            29.608889          7.0  73.0
# 586894         732.129456           571.786133         11.0  69.0
#
#           snomed_code  drg_ref  drg_weight  diag_class_ref_S  \
# 218191   6.540401e+07    231.0      2.3206               1.0
# 863976   6.004601e+07    260.0      5.9280               1.0
# 961023   9.532600e+07    385.0      0.5537               1.0
# 916955   1.162900e+08    793.0      0.9261               1.0
# 1013913  2.147484e+09    231.0      2.3206               1.0
# ...               ...      ...         ...               ...
# 842210   1.392001e+07    284.0      2.0301               1.0
# 999667   8.238501e+07      7.0     17.9363               1.0
# 323441   3.074960e+08    231.0      2.3206               1.0
# 882856   3.121040e+08    260.0      5.9280               1.0
# 586894   7.377401e+07    440.0      5.1383               1.0
#
#          num_health_issues  clinical_records_result_num_mean  \
# 218191                 8.0                         17.965517
# 863976                 9.0                         89.620689
# 961023                 7.0                        132.425919
# 916955                 3.0                        156.122452
# 1013913                8.0                         86.611115
# ...                    ...                               ...
# 842210                 8.0                         35.799999
# 999667                 3.0                         36.165573
# 323441                 8.0                         55.170731
# 882856                 5.0                         95.695656
# 586894                 7.0                         20.179487
#
#          health_issue_ou_med_ref  icd10_capitulo  prediction_label  \
# 218191                  9.533010               1                15
# 863976                 13.740342              12                14
# 961023                 10.077813              14                14
# 916955                 14.636505              14                14
# 1013913                 9.321969              16                 1
# ...                          ...             ...               ...
# 842210                  9.321969              14                 9
# 999667                  9.520975              14                 1
# 323441                 10.600161               1                15
# 882856                  9.377646              15                12
# 586894                  9.654046              13                 0
#
#          prediction_score
# 218191             0.3064
# 863976             0.4559
# 961023             1.0000
# 916955             1.0000
# 1013913            0.3023
# ...                   ...
# 842210             0.1625
# 999667             0.1949
# 323441             0.2531
# 882856             0.2097
# 586894             0.2960
#
# [313796 rows x 14 columns]

# %%
# Get the performance metrics
pull()
# Out:
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# 0  Decision Tree Classifier    0.4446  0.9054  0.4446  0.4433  0.4437  0.3856
#
#       MCC
# 0  0.3856

# %% [markdown]
# ## **Analyse Model**
#
# Plots to analyse the performance of the model on the test set.

# %% [markdown]
# ### **Confusion Matrix**

# %%
# Confusion Matrix
plt.figure(figsize=(25, 25))
plot_model(decision_tree_model_tuned, plot = 'confusion_matrix') # save=True, use_train_data=False

# %% [markdown]
# ### **Area Under the Curve (AUC)**

# %%
# Area Under the Curve (AUC)
plt.figure(figsize=(25, 25))
plot_model(decision_tree_model_tuned, plot = 'auc') # save=True

# %% [markdown]
# ### **Class Prediction Error**

# %%
# Class Prediction Error
plt.figure(figsize=(10, 5))
plot_model(decision_tree_model_tuned, plot = 'error') # save=True

# %% [markdown]
# ### **Classification Report**

# %%
# Classification Report
plt.figure(figsize=(10, 10))
plot_model(decision_tree_model_tuned, plot = 'class_report') # save=True
